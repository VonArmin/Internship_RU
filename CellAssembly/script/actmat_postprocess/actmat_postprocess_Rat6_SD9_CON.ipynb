# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
import pickle

# %%
import sys
sys.path.append('../../')

# %%
from src.actmat_postprocess import *

# %% [markdown]
# ### Change the path

# %%
path = "/media/irene/Data/Rat_OS_EPhys_RGS14_Cell_Assembly/Rat6_SD9_CON"
project_name = 'RGS_PROJECT'
condition = 'CON'
study_day = 'SD9'
rat_nr = 'Rn6'
RGS14_or_Veh = "pyramidal_neurons_vehicle.txt"
os.chdir(path)

# %%
load_dict = load_data();
# load_dict

# %%
actmat_dict, neuron_name_dict = clean_actmat(load_dict)

# %% [markdown]
# ##### Only if the name is incorrect, uncomment the code below:
# aim to get: RGS_PROJECT_RGS14_PFC_Rn4_OD_SD5_T6_UID8

# %%
neuron_name_dict
# Out:
# {0: 'RGS_PROJECT_RGS14_CON_Rn6_SD9_T11_UID0',
#  1: 'RGS_PROJECT_RGS14_CON_Rn6_SD9_T11_UID1',
#  2: 'RGS_PROJECT_RGS14_CON_Rn6_SD9_T11_UID2',
#  3: 'RGS_PROJECT_RGS14_CON_Rn6_SD9_T11_UID3',
#  4: 'RGS_PROJECT_RGS14_CON_Rn6_SD9_T11_UID4',
#  5: 'RGS_PROJECT_RGS14_CON_Rn6_SD9_T12_UID1'}

# %%
for key, value in neuron_name_dict.items():
#     print(value)
    name_list = value.split('_')
    Rat = name_list[4]
    SD = name_list[5]
    condition = name_list[3]
    T_number = name_list[6]
    UID_number = name_list[7]
    new_name = "RGS_PROJECT_RGS14_PFC_" + Rat + "_" + condition + "_"+ SD +"_" + T_number + "_" + UID_number
    neuron_name_dict[key] = new_name
#     print(new_name)

# %%
neuron_name_dict
# Out:
# {0: 'RGS_PROJECT_RGS14_PFC_Rn6_CON_SD9_T11_UID0',
#  1: 'RGS_PROJECT_RGS14_PFC_Rn6_CON_SD9_T11_UID1',
#  2: 'RGS_PROJECT_RGS14_PFC_Rn6_CON_SD9_T11_UID2',
#  3: 'RGS_PROJECT_RGS14_PFC_Rn6_CON_SD9_T11_UID3',
#  4: 'RGS_PROJECT_RGS14_PFC_Rn6_CON_SD9_T11_UID4',
#  5: 'RGS_PROJECT_RGS14_PFC_Rn6_CON_SD9_T12_UID1'}

# %% [markdown]
# ### Only leave pyramidal neuron

# %%
path_pyramidal_neuron = "/home/irene/Desktop/CellAssembly/get_pyramid"
os.chdir(path_pyramidal_neuron)
pyramidal_neurons_RGS14, pyramidal_neuron_all = get_interneurons_list(RGS14_or_Veh, 
                                                                   project_name, condition, study_day, rat_nr)

# %%
pyramidal_neurons_RGS14
# Out:
# ['RGS_PROJECT_VEHICLE_PFC_Rn6_CON_SD9_T11_UID0',
#  'RGS_PROJECT_VEHICLE_PFC_Rn6_CON_SD9_T11_UID1',
#  'RGS_PROJECT_VEHICLE_PFC_Rn6_CON_SD9_T11_UID2',
#  'RGS_PROJECT_VEHICLE_PFC_Rn6_CON_SD9_T11_UID3',
#  'RGS_PROJECT_VEHICLE_PFC_Rn6_CON_SD9_T11_UID4',
#  'RGS_PROJECT_VEHICLE_PFC_Rn6_CON_SD9_T12_UID1']

# %%
os.chdir(path)

# %%
neuron_index_list = find_index_neurons(pyramidal_neurons_RGS14, neuron_name_dict)
print(neuron_index_list)
actmat_dict_new, neuron_name_dict_new = get_pyramid_neuron(neuron_index_list, neuron_name_dict, actmat_dict)
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
# assert len(actmat_dict_new['Post_Trial1']) == len(neuron_name_dict_new)
# print(neuron_name_dict_new)

# %% [markdown]
# ### The file will saved in the path previously defined

# %%
act_mat_file = open("actmat_dict.pkl", "wb")
pickle.dump(actmat_dict, act_mat_file)                     
act_mat_file.close()

neuron_name_file = open("neuron_name_dict.pkl", "wb")
pickle.dump(neuron_name_dict, neuron_name_file)
neuron_name_file.close()
