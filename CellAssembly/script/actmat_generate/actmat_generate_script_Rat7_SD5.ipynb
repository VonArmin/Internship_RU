# %%
from actmat_generate import *
import os
import pandas as pd

# %% [markdown]
# ### Run the following script to generate actmat matrix
#
# - Change the path into the folder where you put the Trial_durations.xls file
# - Çhange the date into actual date performing the experiment

# %%
# path = "D:\Internship_Radbound\Cell_assembly_yuqin"
path = "/media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged"
date = "Rat7_SD5_OD"
project_folder_name = "RGS_PROJECT_RGS14_PFC_Rn7_OD_SD5"

# %%
trial_info
# Out:
#                     2020-02-03_11-22-10_Pre-sleep  2020-02-03_12-07-28_Trial1  \
# Unit
# Samples                              8.100659e+07                9.991168e+06
# Cumulative Samples                   8.100659e+07                9.099776e+07
# Seconds                              2.700220e+03                3.330389e+02
# Cumulative Seconds                   2.700220e+03                3.033259e+03
# Minutes                              4.500366e+01                5.550649e+00
# Cumulative Minutes                   4.500366e+01                5.055431e+01
# Hours                                7.500610e-01                9.251081e-02
# Cumulative Hours                     7.500610e-01                8.425719e-01
#
#                     2020-02-03_12-13-07_Post_Trial1  \
# Unit
# Samples                                8.100966e+07
# Cumulative Samples                     1.720074e+08
# Seconds                                2.700322e+03
# Cumulative Seconds                     5.733581e+03
# Minutes                                4.500537e+01
# Cumulative Minutes                     9.555968e+01
# Hours                                  7.500895e-01
# Cumulative Hours                       1.592661e+00
#
#                     2020-02-03_12-58-15_Trial2  \
# Unit
# Samples                           9.989120e+06
# Cumulative Samples                1.819965e+08
# Seconds                           3.329707e+02
# Cumulative Seconds                6.066551e+03
# Minutes                           5.549511e+00
# Cumulative Minutes                1.011092e+02
# Hours                             9.249185e-02
# Cumulative Hours                  1.685153e+00
#
#                     2020-02-03_13-03-54_Post_Trial2  \
# Unit
# Samples                                8.114688e+07
# Cumulative Samples                     2.631434e+08
# Seconds                                2.704896e+03
# Cumulative Seconds                     8.771447e+03
# Minutes                                4.508160e+01
# Cumulative Minutes                     1.461908e+02
# Hours                                  7.513600e-01
# Cumulative Hours                       2.436513e+00
#
#                     2020-02-03_13-49-04_Trial3  \
# Unit
# Samples                           1.004851e+07
# Cumulative Samples                2.731919e+08
# Seconds                           3.349504e+02
# Cumulative Seconds                9.106398e+03
# Minutes                           5.582507e+00
# Cumulative Minutes                1.517733e+02
# Hours                             9.304178e-02
# Cumulative Hours                  2.529555e+00
#
#                     2020-02-03_13-54-44_Post_Trial3  \
# Unit
# Samples                                8.100864e+07
# Cumulative Samples                     3.542006e+08
# Seconds                                2.700288e+03
# Cumulative Seconds                     1.180669e+04
# Minutes                                4.500480e+01
# Cumulative Minutes                     1.967781e+02
# Hours                                  7.500800e-01
# Cumulative Hours                       3.279635e+00
#
#                     2020-02-03_14-39-49_Trial4  \
# Unit
# Samples                           1.036902e+07
# Cumulative Samples                3.645696e+08
# Seconds                           3.456341e+02
# Cumulative Seconds                1.215232e+04
# Minutes                           5.760569e+00
# Cumulative Minutes                2.025387e+02
# Hours                             9.600948e-02
# Cumulative Hours                  3.375644e+00
#
#                     2020-02-03_14-45-41_Post_Trial4  \
# Unit
# Samples                                8.825139e+07
# Cumulative Samples                     4.528210e+08
# Seconds                                2.941713e+03
# Cumulative Seconds                     1.509403e+04
# Minutes                                4.902855e+01
# Cumulative Minutes                     2.515672e+02
# Hours                                  8.171425e-01
# Cumulative Hours                       4.192787e+00
#
#                     2020-02-03_15-34-47_Trial5  \
# Unit
# Samples                           9.805824e+06
# Cumulative Samples                4.626268e+08
# Seconds                           3.268608e+02
# Cumulative Seconds                1.542089e+04
# Minutes                           5.447680e+00
# Cumulative Minutes                2.570149e+02
# Hours                             9.079467e-02
# Cumulative Hours                  4.283582e+00
#
#                     2020-02-03_15-40-17_Post_Trial5  \
# Unit
# Samples                                2.374881e+08
# Cumulative Samples                     7.001149e+08
# Seconds                                7.916271e+03
# Cumulative Seconds                     2.333716e+04
# Minutes                                1.319378e+02
# Cumulative Minutes                     3.889527e+02
# Hours                                  2.198964e+00
# Cumulative Hours                       6.482546e+00
#
#                     2020-02-03_17-54-59_Post_Trial5_2
# Unit
# Samples                                  7.905382e+07
# Cumulative Samples                       7.791688e+08
# Seconds                                  2.635127e+03
# Cumulative Seconds                       2.597229e+04
# Minutes                                  4.391879e+01
# Cumulative Minutes                       4.328715e+02
# Hours                                    7.319799e-01
# Cumulative Hours                         7.214526e+00

# %%
os.chdir(path)
trial_info = pd.read_excel('Trial_durations.xls', index_col = 0)  
trial_last_period_name = trial_info.columns[-1]
final_samples = trial_info[trial_last_period_name]["Cumulative Samples"]
samples_index_list = list(trial_info.loc["Cumulative Samples"])
fs = 30000
#Modified the minutes and samples by removing the tail
trial_info.loc["modified_minutes"] = [45.0, 5.0, 45.0, 5.0, 45.0, 5.0, 45.0, 5.0, 45.0, 5.0, 180.0]
trial_info.loc["modified_samples"] = trial_info.loc["modified_minutes"]* 60 * 30000

# %% [markdown]
# ### Change:
#
# - absolute_path_list
# - trial_name_list
# - project_folder_name

# %%
absolute_path_list = [path + "/cortex/Tetrode_6/phy_MS4",
                     path + "/cortex/Tetrode_7/phy_MS4",
                     path + "/cortex/Tetrode_8/phy_MS4",
                     path + "/cortex/Tetrode_9/phy_AGR",
                     path + "/cortex/Tetrode_11/phy_AGR",
                     path + "/cortex/Tetrode_12/phy_AGR",
                     path + "/cortex/Tetrode_13/phy_MS4",
                     path + "/cortex/Tetrode_14/phy_AGR",
                     path + "/cortex/Tetrode_15/phy_MS4"]
trial_name_list = list(trial_info.columns)

# %%
# get_neuron_name(trial_info, absolute_path_list, trial_name_list[0], project_folder_name)

# %%
for trial_name in trial_name_list:
    createFolder(path + '/' + date)
    final_matrix = iterate_all_file_for_a_trial(trial_info, absolute_path_list, trial_name, project_folder_name)
    createFolder(path + '/' + date)
    np.save(trial_name + "_actmat", final_matrix)
# Out:
# trial name isPre_sleep
# split_index is [0, 117771, 137101, 272440, 289614, 425742, 441388, 524806, 540885, 588275, 607531, 877461]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_7/phy_MS4
# split_index is [0, 73068, 86670, 200895, 212852, 297975, 307588, 358300, 369882, 396164, 410314, 567075]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_8/phy_MS4
# split_index is [0, 134721, 156175, 335609, 355761, 506653, 523973, 620075, 642423, 707225, 732506, 1115361]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_9/phy_AGR
# split_index is [0, 23823, 31376, 56300, 61889, 78132, 84095, 102994, 106817, 122377, 125342, 199295]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 115557, 123210, 226673, 235463, 310534, 320884, 375787, 384230, 406432, 411085, 510162]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 96078, 112400, 212571, 228221, 328780, 345399, 417956, 433414, 485752, 501081, 737613]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_13/phy_MS4
# split_index is [0, 290337, 330077, 614880, 649276, 865035, 888809, 1014561, 1037788, 1114439, 1144935, 1654547]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 9538, 10008, 18082, 18618, 36518, 37303, 48347, 49153, 59255, 59828, 123212]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 236862, 273068, 520774, 551893, 792995, 821321, 975191, 1003172, 1086521, 1118123, 1568737]
# row_index is 0
# row_index is 1
# row_index is 2
# trial name isTrial1
# split_index is [0, 117771, 137101, 272440, 289614, 425742, 441388, 524806, 540885, 588275, 607531, 877461]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_7/phy_MS4
# split_index is [0, 73068, 86670, 200895, 212852, 297975, 307588, 358300, 369882, 396164, 410314, 567075]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_8/phy_MS4
# split_index is [0, 134721, 156175, 335609, 355761, 506653, 523973, 620075, 642423, 707225, 732506, 1115361]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_9/phy_AGR
# split_index is [0, 23823, 31376, 56300, 61889, 78132, 84095, 102994, 106817, 122377, 125342, 199295]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 115557, 123210, 226673, 235463, 310534, 320884, 375787, 384230, 406432, 411085, 510162]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 96078, 112400, 212571, 228221, 328780, 345399, 417956, 433414, 485752, 501081, 737613]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_13/phy_MS4
# split_index is [0, 290337, 330077, 614880, 649276, 865035, 888809, 1014561, 1037788, 1114439, 1144935, 1654547]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 9538, 10008, 18082, 18618, 36518, 37303, 48347, 49153, 59255, 59828, 123212]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 236862, 273068, 520774, 551893, 792995, 821321, 975191, 1003172, 1086521, 1118123, 1568737]
# row_index is 0
# row_index is 1
# row_index is 2
# trial name isPost_Trial1
# split_index is [0, 117771, 137101, 272440, 289614, 425742, 441388, 524806, 540885, 588275, 607531, 877461]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_7/phy_MS4
# split_index is [0, 73068, 86670, 200895, 212852, 297975, 307588, 358300, 369882, 396164, 410314, 567075]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_8/phy_MS4
# split_index is [0, 134721, 156175, 335609, 355761, 506653, 523973, 620075, 642423, 707225, 732506, 1115361]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_9/phy_AGR
# split_index is [0, 23823, 31376, 56300, 61889, 78132, 84095, 102994, 106817, 122377, 125342, 199295]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 115557, 123210, 226673, 235463, 310534, 320884, 375787, 384230, 406432, 411085, 510162]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 96078, 112400, 212571, 228221, 328780, 345399, 417956, 433414, 485752, 501081, 737613]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_13/phy_MS4
# split_index is [0, 290337, 330077, 614880, 649276, 865035, 888809, 1014561, 1037788, 1114439, 1144935, 1654547]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 9538, 10008, 18082, 18618, 36518, 37303, 48347, 49153, 59255, 59828, 123212]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 236862, 273068, 520774, 551893, 792995, 821321, 975191, 1003172, 1086521, 1118123, 1568737]
# row_index is 0
# row_index is 1
# row_index is 2
# trial name isTrial2
# split_index is [0, 117771, 137101, 272440, 289614, 425742, 441388, 524806, 540885, 588275, 607531, 877461]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_7/phy_MS4
# split_index is [0, 73068, 86670, 200895, 212852, 297975, 307588, 358300, 369882, 396164, 410314, 567075]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_8/phy_MS4
# split_index is [0, 134721, 156175, 335609, 355761, 506653, 523973, 620075, 642423, 707225, 732506, 1115361]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_9/phy_AGR
# split_index is [0, 23823, 31376, 56300, 61889, 78132, 84095, 102994, 106817, 122377, 125342, 199295]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 115557, 123210, 226673, 235463, 310534, 320884, 375787, 384230, 406432, 411085, 510162]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 96078, 112400, 212571, 228221, 328780, 345399, 417956, 433414, 485752, 501081, 737613]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_13/phy_MS4
# split_index is [0, 290337, 330077, 614880, 649276, 865035, 888809, 1014561, 1037788, 1114439, 1144935, 1654547]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 9538, 10008, 18082, 18618, 36518, 37303, 48347, 49153, 59255, 59828, 123212]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 236862, 273068, 520774, 551893, 792995, 821321, 975191, 1003172, 1086521, 1118123, 1568737]
# row_index is 0
# row_index is 1
# row_index is 2
# trial name isPost_Trial2
# split_index is [0, 117771, 137101, 272440, 289614, 425742, 441388, 524806, 540885, 588275, 607531, 877461]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_7/phy_MS4
# split_index is [0, 73068, 86670, 200895, 212852, 297975, 307588, 358300, 369882, 396164, 410314, 567075]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_8/phy_MS4
# split_index is [0, 134721, 156175, 335609, 355761, 506653, 523973, 620075, 642423, 707225, 732506, 1115361]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_9/phy_AGR
# split_index is [0, 23823, 31376, 56300, 61889, 78132, 84095, 102994, 106817, 122377, 125342, 199295]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 115557, 123210, 226673, 235463, 310534, 320884, 375787, 384230, 406432, 411085, 510162]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 96078, 112400, 212571, 228221, 328780, 345399, 417956, 433414, 485752, 501081, 737613]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_13/phy_MS4
# split_index is [0, 290337, 330077, 614880, 649276, 865035, 888809, 1014561, 1037788, 1114439, 1144935, 1654547]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 9538, 10008, 18082, 18618, 36518, 37303, 48347, 49153, 59255, 59828, 123212]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 236862, 273068, 520774, 551893, 792995, 821321, 975191, 1003172, 1086521, 1118123, 1568737]
# row_index is 0
# row_index is 1
# row_index is 2
# trial name isTrial3
# split_index is [0, 117771, 137101, 272440, 289614, 425742, 441388, 524806, 540885, 588275, 607531, 877461]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_7/phy_MS4
# split_index is [0, 73068, 86670, 200895, 212852, 297975, 307588, 358300, 369882, 396164, 410314, 567075]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_8/phy_MS4
# split_index is [0, 134721, 156175, 335609, 355761, 506653, 523973, 620075, 642423, 707225, 732506, 1115361]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_9/phy_AGR
# split_index is [0, 23823, 31376, 56300, 61889, 78132, 84095, 102994, 106817, 122377, 125342, 199295]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 115557, 123210, 226673, 235463, 310534, 320884, 375787, 384230, 406432, 411085, 510162]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 96078, 112400, 212571, 228221, 328780, 345399, 417956, 433414, 485752, 501081, 737613]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_13/phy_MS4
# split_index is [0, 290337, 330077, 614880, 649276, 865035, 888809, 1014561, 1037788, 1114439, 1144935, 1654547]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 9538, 10008, 18082, 18618, 36518, 37303, 48347, 49153, 59255, 59828, 123212]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 236862, 273068, 520774, 551893, 792995, 821321, 975191, 1003172, 1086521, 1118123, 1568737]
# row_index is 0
# row_index is 1
# row_index is 2
# trial name isPost_Trial3
# split_index is [0, 117771, 137101, 272440, 289614, 425742, 441388, 524806, 540885, 588275, 607531, 877461]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_7/phy_MS4
# split_index is [0, 73068, 86670, 200895, 212852, 297975, 307588, 358300, 369882, 396164, 410314, 567075]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_8/phy_MS4
# split_index is [0, 134721, 156175, 335609, 355761, 506653, 523973, 620075, 642423, 707225, 732506, 1115361]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_9/phy_AGR
# split_index is [0, 23823, 31376, 56300, 61889, 78132, 84095, 102994, 106817, 122377, 125342, 199295]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 115557, 123210, 226673, 235463, 310534, 320884, 375787, 384230, 406432, 411085, 510162]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 96078, 112400, 212571, 228221, 328780, 345399, 417956, 433414, 485752, 501081, 737613]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_13/phy_MS4
# split_index is [0, 290337, 330077, 614880, 649276, 865035, 888809, 1014561, 1037788, 1114439, 1144935, 1654547]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 9538, 10008, 18082, 18618, 36518, 37303, 48347, 49153, 59255, 59828, 123212]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 236862, 273068, 520774, 551893, 792995, 821321, 975191, 1003172, 1086521, 1118123, 1568737]
# row_index is 0
# row_index is 1
# row_index is 2
# trial name isTrial4
# split_index is [0, 117771, 137101, 272440, 289614, 425742, 441388, 524806, 540885, 588275, 607531, 877461]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_7/phy_MS4
# split_index is [0, 73068, 86670, 200895, 212852, 297975, 307588, 358300, 369882, 396164, 410314, 567075]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_8/phy_MS4
# split_index is [0, 134721, 156175, 335609, 355761, 506653, 523973, 620075, 642423, 707225, 732506, 1115361]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_9/phy_AGR
# split_index is [0, 23823, 31376, 56300, 61889, 78132, 84095, 102994, 106817, 122377, 125342, 199295]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 115557, 123210, 226673, 235463, 310534, 320884, 375787, 384230, 406432, 411085, 510162]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 96078, 112400, 212571, 228221, 328780, 345399, 417956, 433414, 485752, 501081, 737613]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_13/phy_MS4
# split_index is [0, 290337, 330077, 614880, 649276, 865035, 888809, 1014561, 1037788, 1114439, 1144935, 1654547]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 9538, 10008, 18082, 18618, 36518, 37303, 48347, 49153, 59255, 59828, 123212]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 236862, 273068, 520774, 551893, 792995, 821321, 975191, 1003172, 1086521, 1118123, 1568737]
# row_index is 0
# row_index is 1
# row_index is 2
# trial name isPost_Trial4
# split_index is [0, 117771, 137101, 272440, 289614, 425742, 441388, 524806, 540885, 588275, 607531, 877461]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_7/phy_MS4
# split_index is [0, 73068, 86670, 200895, 212852, 297975, 307588, 358300, 369882, 396164, 410314, 567075]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_8/phy_MS4
# split_index is [0, 134721, 156175, 335609, 355761, 506653, 523973, 620075, 642423, 707225, 732506, 1115361]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_9/phy_AGR
# split_index is [0, 23823, 31376, 56300, 61889, 78132, 84095, 102994, 106817, 122377, 125342, 199295]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 115557, 123210, 226673, 235463, 310534, 320884, 375787, 384230, 406432, 411085, 510162]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 96078, 112400, 212571, 228221, 328780, 345399, 417956, 433414, 485752, 501081, 737613]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_13/phy_MS4
# split_index is [0, 290337, 330077, 614880, 649276, 865035, 888809, 1014561, 1037788, 1114439, 1144935, 1654547]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 9538, 10008, 18082, 18618, 36518, 37303, 48347, 49153, 59255, 59828, 123212]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 236862, 273068, 520774, 551893, 792995, 821321, 975191, 1003172, 1086521, 1118123, 1568737]
# row_index is 0
# row_index is 1
# row_index is 2
# trial name isTrial5
# split_index is [0, 117771, 137101, 272440, 289614, 425742, 441388, 524806, 540885, 588275, 607531, 877461]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_7/phy_MS4
# split_index is [0, 73068, 86670, 200895, 212852, 297975, 307588, 358300, 369882, 396164, 410314, 567075]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_8/phy_MS4
# split_index is [0, 134721, 156175, 335609, 355761, 506653, 523973, 620075, 642423, 707225, 732506, 1115361]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_9/phy_AGR
# split_index is [0, 23823, 31376, 56300, 61889, 78132, 84095, 102994, 106817, 122377, 125342, 199295]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 115557, 123210, 226673, 235463, 310534, 320884, 375787, 384230, 406432, 411085, 510162]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 96078, 112400, 212571, 228221, 328780, 345399, 417956, 433414, 485752, 501081, 737613]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_13/phy_MS4
# split_index is [0, 290337, 330077, 614880, 649276, 865035, 888809, 1014561, 1037788, 1114439, 1144935, 1654547]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 9538, 10008, 18082, 18618, 36518, 37303, 48347, 49153, 59255, 59828, 123212]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 236862, 273068, 520774, 551893, 792995, 821321, 975191, 1003172, 1086521, 1118123, 1568737]
# row_index is 0
# row_index is 1
# row_index is 2
# trial name isPost_Trial5
# split_index is [0, 117771, 137101, 272440, 289614, 425742, 441388, 524806, 540885, 588275, 607531, 877461]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_7/phy_MS4
# split_index is [0, 73068, 86670, 200895, 212852, 297975, 307588, 358300, 369882, 396164, 410314, 567075]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_8/phy_MS4
# split_index is [0, 134721, 156175, 335609, 355761, 506653, 523973, 620075, 642423, 707225, 732506, 1115361]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_9/phy_AGR
# split_index is [0, 23823, 31376, 56300, 61889, 78132, 84095, 102994, 106817, 122377, 125342, 199295]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 115557, 123210, 226673, 235463, 310534, 320884, 375787, 384230, 406432, 411085, 510162]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 96078, 112400, 212571, 228221, 328780, 345399, 417956, 433414, 485752, 501081, 737613]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_13/phy_MS4
# split_index is [0, 290337, 330077, 614880, 649276, 865035, 888809, 1014561, 1037788, 1114439, 1144935, 1654547]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 9538, 10008, 18082, 18618, 36518, 37303, 48347, 49153, 59255, 59828, 123212]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# /media/irene/GL14_RAT_FANO/Spikesorting/Rat_OS_Ephys_RGS14_rat7_373727/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020/Rat_OS_Ephys_RGS14_rat7_373727_SD5_OD_13-14_02_2020_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 236862, 273068, 520774, 551893, 792995, 821321, 975191, 1003172, 1086521, 1118123, 1568737]
# row_index is 0
# row_index is 1
# row_index is 2

# %%
actmat_neuron_name = get_neuron_name(trial_info, absolute_path_list, trial_name_list[0], project_folder_name )
createFolder(path + '/' + date)
np.save("actmat_neuron_name", actmat_neuron_name)
# Out:
# split_index is [0, 117771, 137101, 272440, 289614, 425742, 441388, 524806, 540885, 588275, 607531, 877461]
# row_index is 0
# row_index is 1
# row_index is 2
# split_index is [0, 73068, 86670, 200895, 212852, 297975, 307588, 358300, 369882, 396164, 410314, 567075]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# split_index is [0, 134721, 156175, 335609, 355761, 506653, 523973, 620075, 642423, 707225, 732506, 1115361]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# split_index is [0, 23823, 31376, 56300, 61889, 78132, 84095, 102994, 106817, 122377, 125342, 199295]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# split_index is [0, 115557, 123210, 226673, 235463, 310534, 320884, 375787, 384230, 406432, 411085, 510162]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# split_index is [0, 96078, 112400, 212571, 228221, 328780, 345399, 417956, 433414, 485752, 501081, 737613]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# split_index is [0, 290337, 330077, 614880, 649276, 865035, 888809, 1014561, 1037788, 1114439, 1144935, 1654547]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# split_index is [0, 9538, 10008, 18082, 18618, 36518, 37303, 48347, 49153, 59255, 59828, 123212]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# split_index is [0, 236862, 273068, 520774, 551893, 792995, 821321, 975191, 1003172, 1086521, 1118123, 1568737]
# row_index is 0
# row_index is 1
# row_index is 2

# %% [markdown]
# ### The code below is just for test purpose, do not run it

# %%
# spike_clusters = np.load("spike_clusters.npy")
# spike_times = np.load("spike_times.npy")
# set_neuron = set(spike_clusters)
# for neuron_x in set_neuron:
#     neuron_x_index =  [i for i,d in enumerate(spike_clusters) if d==neuron_x]
#     spike_times = spike_times.flatten()
#     neuron_x_map = (np.array([spike_times[index] for index in neuron_x_index])/750).astype(int)
#     neuron_x_map

# (np.array(spike_time_17)/750)[1]
