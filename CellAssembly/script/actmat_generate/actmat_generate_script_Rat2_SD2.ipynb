# %%
from actmat_generate import *
import os
import pandas as pd

# %% [markdown]
# ### Run the following script to generate actmat matrix
#
# - Change the path into the folder where you put the Trial_durations.xls file
# - Çhange the date into actual date performing the experiment

# %%
# path = "D:\Internship_Radbound\Cell_assembly_yuqin"
path = "/media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged"
date = "Rat2_SD2_OR"
project_folder_name = "RGS_PROJECT_RGS14_PFC_Rn2_OR_SD2_T"

# %%
os.chdir(path)
trial_info = pd.read_excel('Trial_durations.xls', index_col = 0)  
trial_last_period_name = trial_info.columns[-1]
final_samples = trial_info[trial_last_period_name]["Cumulative Samples"]
samples_index_list = list(trial_info.loc["Cumulative Samples"])
fs = 30000
#Modified the minutes and samples by removing the tail
trial_info.loc["modified_minutes"] = [45.0, 5.0, 45.0, 5.0, 45.0, 5.0, 45.0, 5.0, 45.0, 5.0, 180.0]
trial_info.loc["modified_samples"] = trial_info.loc["modified_minutes"]* 60 * 30000

# %%
trial_info
# Out:
#                     2018-07-26_09-54-35_Pre-sleep  2018-07-26_10-52-28_Trial1  \
# Unit
# Samples                              8.105472e+07                9.823232e+06
# Cumulative Samples                   8.105472e+07                9.087795e+07
# Seconds                              2.701824e+03                3.274411e+02
# Cumulative Seconds                   2.701824e+03                3.029265e+03
# Minutes                              4.503040e+01                5.457351e+00
# Cumulative Minutes                   4.503040e+01                5.048775e+01
# Hours                                7.505067e-01                9.095585e-02
# Cumulative Hours                     7.505067e-01                8.414625e-01
# modified_minutes                     4.500000e+01                5.000000e+00
# modified_samples                     8.100000e+07                9.000000e+06
#
#                     2018-07-26_10-58-00_Post-Trial1  \
# Unit
# Samples                                8.104243e+07
# Cumulative Samples                     1.719204e+08
# Seconds                                2.701414e+03
# Cumulative Seconds                     5.730679e+03
# Minutes                                4.502357e+01
# Cumulative Minutes                     9.551132e+01
# Hours                                  7.503929e-01
# Cumulative Hours                       1.591855e+00
# modified_minutes                       4.500000e+01
# modified_samples                       8.100000e+07
#
#                     2018-07-26_11-43-06_Trial2  \
# Unit
# Samples                           9.730048e+06
# Cumulative Samples                1.816504e+08
# Seconds                           3.243349e+02
# Cumulative Seconds                6.055014e+03
# Minutes                           5.405582e+00
# Cumulative Minutes                1.009169e+02
# Hours                             9.009304e-02
# Cumulative Hours                  1.681948e+00
# modified_minutes                  5.000000e+00
# modified_samples                  9.000000e+06
#
#                     2018-07-26_11-48-36_Post-Trial2  \
# Unit
# Samples                                8.101274e+07
# Cumulative Samples                     2.626632e+08
# Seconds                                2.700425e+03
# Cumulative Seconds                     8.755439e+03
# Minutes                                4.500708e+01
# Cumulative Minutes                     1.459240e+02
# Hours                                  7.501179e-01
# Cumulative Hours                       2.432066e+00
# modified_minutes                       4.500000e+01
# modified_samples                       8.100000e+07
#
#                     2018-07-26_12-33-41_Trial3  \
# Unit
# Samples                           9.935872e+06
# Cumulative Samples                2.725990e+08
# Seconds                           3.311957e+02
# Cumulative Seconds                9.086635e+03
# Minutes                           5.519929e+00
# Cumulative Minutes                1.514439e+02
# Hours                             9.199881e-02
# Cumulative Hours                  2.524065e+00
# modified_minutes                  5.000000e+00
# modified_samples                  9.000000e+06
#
#                     2018-07-26_12-39-16_Post-Trial3  \
# Unit
# Samples                                8.102093e+07
# Cumulative Samples                     3.536200e+08
# Seconds                                2.700698e+03
# Cumulative Seconds                     1.178733e+04
# Minutes                                4.501163e+01
# Cumulative Minutes                     1.964555e+02
# Hours                                  7.501938e-01
# Cumulative Hours                       3.274259e+00
# modified_minutes                       4.500000e+01
# modified_samples                       8.100000e+07
#
#                     2018-07-26_13-24-21_Trial4  \
# Unit
# Samples                           1.042227e+07
# Cumulative Samples                3.640422e+08
# Seconds                           3.474091e+02
# Cumulative Seconds                1.213474e+04
# Minutes                           5.790151e+00
# Cumulative Minutes                2.022457e+02
# Hours                             9.650252e-02
# Cumulative Hours                  3.370761e+00
# modified_minutes                  5.000000e+00
# modified_samples                  9.000000e+06
#
#                     2018-07-26_13-30-13_Post-Trial4  \
# Unit
# Samples                                8.101990e+07
# Cumulative Samples                     4.450621e+08
# Seconds                                2.700663e+03
# Cumulative Seconds                     1.483540e+04
# Minutes                                4.501106e+01
# Cumulative Minutes                     2.472567e+02
# Hours                                  7.501843e-01
# Cumulative Hours                       4.120946e+00
# modified_minutes                       4.500000e+01
# modified_samples                       8.100000e+07
#
#                     2018-07-26_14-15-18_Trial5  \
# Unit
# Samples                           9.683968e+06
# Cumulative Samples                4.547461e+08
# Seconds                           3.227989e+02
# Cumulative Seconds                1.515820e+04
# Minutes                           5.379982e+00
# Cumulative Minutes                2.526367e+02
# Hours                             8.966637e-02
# Cumulative Hours                  4.210612e+00
# modified_minutes                  5.000000e+00
# modified_samples                  9.000000e+06
#
#                     2018-07-26_14-20-46_Post-Trial5
# Unit
# Samples                                3.240550e+08
# Cumulative Samples                     7.788012e+08
# Seconds                                1.080183e+04
# Cumulative Seconds                     2.596004e+04
# Minutes                                1.800306e+02
# Cumulative Minutes                     4.326673e+02
# Hours                                  3.000510e+00
# Cumulative Hours                       7.211122e+00
# modified_minutes                       1.800000e+02
# modified_samples                       3.240000e+08

# %% [markdown]
# ### Change:
#
# - absolute_path_list
# - trial_name_list
# - project_folder_name

# %%
absolute_path_list = [path + "/cortex/Tetrode_8/phy_MS4",
                     path + "/cortex/Tetrode_9/phy_MS4",
                     path + "/cortex/Tetrode_10/phy_MS4",
                     path + "/cortex/Tetrode_12/phy_AGR",
                     path + "/cortex/Tetrode_13/phy_AGR",
                     path + "/cortex/Tetrode_14/phy_AGR",
                     path + "/cortex/Tetrode_15/phy_MS4",
                     path + "/cortex/Tetrode_16/phy_AGR"]
# absolute_path_list = [path + "/cortex/Tetrode_14/phy_AGR"]

trial_name_list = list(trial_info.columns)

# %%
# get_neuron_name(trial_info, absolute_path_list, trial_name_list[0], project_folder_name)

# %%
# iterate_all_file_for_a_trial(trial_info, absolute_path_list, trial_name_list[-2], project_folder_name)

# %%
for trial_name in trial_name_list:
    createFolder(path + '/' + date)
    final_matrix = iterate_all_file_for_a_trial(trial_info, absolute_path_list, trial_name, project_folder_name)
    createFolder(path + '/' + date)
    np.save(trial_name + "_actmat", final_matrix)
# Out:
# trial name is2018-07-26_09-54-35_Pre-sleep
# split_index is [0, 279374, 319928, 711109, 758465, 992509, 1038535, 1246565, 1298864, 1538528, 1587132, 2358985]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_9/phy_MS4
# split_index is [0, 230466, 264075, 612519, 656661, 860006, 905242, 1126901, 1178415, 1447986, 1503112, 2365097]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 324234, 367276, 768641, 829213, 1042761, 1088192, 1316409, 1380375, 1596287, 1636029, 2296196]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 32852, 37184, 81712, 87104, 113919, 119357, 145673, 151028, 178637, 183834, 316248]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 11706, 13593, 25156, 26509, 33999, 35441, 45030, 46955, 56152, 57968, 98830]
# row_index is 0
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 0, 0, 34586, 34586, 34586, 34586, 34587, 34588, 34588, 34588, 110168]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 305588, 340130, 717833, 760969, 992259, 1037037, 1292903, 1341330, 1575412, 1619132, 2473048]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_16/phy_AGR
# split_index is [0, 3933, 4252, 11232, 11506, 14564, 14976, 19617, 20196, 23734, 24137, 36643]
# row_index is 0
# trial name is2018-07-26_10-52-28_Trial1
# split_index is [0, 279374, 319928, 711109, 758465, 992509, 1038535, 1246565, 1298864, 1538528, 1587132, 2358985]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_9/phy_MS4
# split_index is [0, 230466, 264075, 612519, 656661, 860006, 905242, 1126901, 1178415, 1447986, 1503112, 2365097]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 324234, 367276, 768641, 829213, 1042761, 1088192, 1316409, 1380375, 1596287, 1636029, 2296196]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 32852, 37184, 81712, 87104, 113919, 119357, 145673, 151028, 178637, 183834, 316248]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 11706, 13593, 25156, 26509, 33999, 35441, 45030, 46955, 56152, 57968, 98830]
# row_index is 0
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 0, 0, 34586, 34586, 34586, 34586, 34587, 34588, 34588, 34588, 110168]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 305588, 340130, 717833, 760969, 992259, 1037037, 1292903, 1341330, 1575412, 1619132, 2473048]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_16/phy_AGR
# split_index is [0, 3933, 4252, 11232, 11506, 14564, 14976, 19617, 20196, 23734, 24137, 36643]
# row_index is 0
# trial name is2018-07-26_10-58-00_Post-Trial1
# split_index is [0, 279374, 319928, 711109, 758465, 992509, 1038535, 1246565, 1298864, 1538528, 1587132, 2358985]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_9/phy_MS4
# split_index is [0, 230466, 264075, 612519, 656661, 860006, 905242, 1126901, 1178415, 1447986, 1503112, 2365097]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 324234, 367276, 768641, 829213, 1042761, 1088192, 1316409, 1380375, 1596287, 1636029, 2296196]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 32852, 37184, 81712, 87104, 113919, 119357, 145673, 151028, 178637, 183834, 316248]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 11706, 13593, 25156, 26509, 33999, 35441, 45030, 46955, 56152, 57968, 98830]
# row_index is 0
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 0, 0, 34586, 34586, 34586, 34586, 34587, 34588, 34588, 34588, 110168]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 305588, 340130, 717833, 760969, 992259, 1037037, 1292903, 1341330, 1575412, 1619132, 2473048]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_16/phy_AGR
# split_index is [0, 3933, 4252, 11232, 11506, 14564, 14976, 19617, 20196, 23734, 24137, 36643]
# row_index is 0
# trial name is2018-07-26_11-43-06_Trial2
# split_index is [0, 279374, 319928, 711109, 758465, 992509, 1038535, 1246565, 1298864, 1538528, 1587132, 2358985]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_9/phy_MS4
# split_index is [0, 230466, 264075, 612519, 656661, 860006, 905242, 1126901, 1178415, 1447986, 1503112, 2365097]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 324234, 367276, 768641, 829213, 1042761, 1088192, 1316409, 1380375, 1596287, 1636029, 2296196]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 32852, 37184, 81712, 87104, 113919, 119357, 145673, 151028, 178637, 183834, 316248]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 11706, 13593, 25156, 26509, 33999, 35441, 45030, 46955, 56152, 57968, 98830]
# row_index is 0
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 0, 0, 34586, 34586, 34586, 34586, 34587, 34588, 34588, 34588, 110168]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 305588, 340130, 717833, 760969, 992259, 1037037, 1292903, 1341330, 1575412, 1619132, 2473048]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_16/phy_AGR
# split_index is [0, 3933, 4252, 11232, 11506, 14564, 14976, 19617, 20196, 23734, 24137, 36643]
# row_index is 0
# trial name is2018-07-26_11-48-36_Post-Trial2
# split_index is [0, 279374, 319928, 711109, 758465, 992509, 1038535, 1246565, 1298864, 1538528, 1587132, 2358985]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_9/phy_MS4
# split_index is [0, 230466, 264075, 612519, 656661, 860006, 905242, 1126901, 1178415, 1447986, 1503112, 2365097]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 324234, 367276, 768641, 829213, 1042761, 1088192, 1316409, 1380375, 1596287, 1636029, 2296196]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 32852, 37184, 81712, 87104, 113919, 119357, 145673, 151028, 178637, 183834, 316248]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 11706, 13593, 25156, 26509, 33999, 35441, 45030, 46955, 56152, 57968, 98830]
# row_index is 0
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 0, 0, 34586, 34586, 34586, 34586, 34587, 34588, 34588, 34588, 110168]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 305588, 340130, 717833, 760969, 992259, 1037037, 1292903, 1341330, 1575412, 1619132, 2473048]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_16/phy_AGR
# split_index is [0, 3933, 4252, 11232, 11506, 14564, 14976, 19617, 20196, 23734, 24137, 36643]
# row_index is 0
# trial name is2018-07-26_12-33-41_Trial3
# split_index is [0, 279374, 319928, 711109, 758465, 992509, 1038535, 1246565, 1298864, 1538528, 1587132, 2358985]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_9/phy_MS4
# split_index is [0, 230466, 264075, 612519, 656661, 860006, 905242, 1126901, 1178415, 1447986, 1503112, 2365097]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 324234, 367276, 768641, 829213, 1042761, 1088192, 1316409, 1380375, 1596287, 1636029, 2296196]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 32852, 37184, 81712, 87104, 113919, 119357, 145673, 151028, 178637, 183834, 316248]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 11706, 13593, 25156, 26509, 33999, 35441, 45030, 46955, 56152, 57968, 98830]
# row_index is 0
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 0, 0, 34586, 34586, 34586, 34586, 34587, 34588, 34588, 34588, 110168]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 305588, 340130, 717833, 760969, 992259, 1037037, 1292903, 1341330, 1575412, 1619132, 2473048]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_16/phy_AGR
# split_index is [0, 3933, 4252, 11232, 11506, 14564, 14976, 19617, 20196, 23734, 24137, 36643]
# row_index is 0
# trial name is2018-07-26_12-39-16_Post-Trial3
# split_index is [0, 279374, 319928, 711109, 758465, 992509, 1038535, 1246565, 1298864, 1538528, 1587132, 2358985]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_9/phy_MS4
# split_index is [0, 230466, 264075, 612519, 656661, 860006, 905242, 1126901, 1178415, 1447986, 1503112, 2365097]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 324234, 367276, 768641, 829213, 1042761, 1088192, 1316409, 1380375, 1596287, 1636029, 2296196]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 32852, 37184, 81712, 87104, 113919, 119357, 145673, 151028, 178637, 183834, 316248]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 11706, 13593, 25156, 26509, 33999, 35441, 45030, 46955, 56152, 57968, 98830]
# row_index is 0
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 0, 0, 34586, 34586, 34586, 34586, 34587, 34588, 34588, 34588, 110168]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 305588, 340130, 717833, 760969, 992259, 1037037, 1292903, 1341330, 1575412, 1619132, 2473048]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_16/phy_AGR
# split_index is [0, 3933, 4252, 11232, 11506, 14564, 14976, 19617, 20196, 23734, 24137, 36643]
# row_index is 0
# trial name is2018-07-26_13-24-21_Trial4
# split_index is [0, 279374, 319928, 711109, 758465, 992509, 1038535, 1246565, 1298864, 1538528, 1587132, 2358985]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_9/phy_MS4
# split_index is [0, 230466, 264075, 612519, 656661, 860006, 905242, 1126901, 1178415, 1447986, 1503112, 2365097]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 324234, 367276, 768641, 829213, 1042761, 1088192, 1316409, 1380375, 1596287, 1636029, 2296196]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 32852, 37184, 81712, 87104, 113919, 119357, 145673, 151028, 178637, 183834, 316248]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 11706, 13593, 25156, 26509, 33999, 35441, 45030, 46955, 56152, 57968, 98830]
# row_index is 0
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 0, 0, 34586, 34586, 34586, 34586, 34587, 34588, 34588, 34588, 110168]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 305588, 340130, 717833, 760969, 992259, 1037037, 1292903, 1341330, 1575412, 1619132, 2473048]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_16/phy_AGR
# split_index is [0, 3933, 4252, 11232, 11506, 14564, 14976, 19617, 20196, 23734, 24137, 36643]
# row_index is 0
# trial name is2018-07-26_13-30-13_Post-Trial4
# split_index is [0, 279374, 319928, 711109, 758465, 992509, 1038535, 1246565, 1298864, 1538528, 1587132, 2358985]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_9/phy_MS4
# split_index is [0, 230466, 264075, 612519, 656661, 860006, 905242, 1126901, 1178415, 1447986, 1503112, 2365097]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 324234, 367276, 768641, 829213, 1042761, 1088192, 1316409, 1380375, 1596287, 1636029, 2296196]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 32852, 37184, 81712, 87104, 113919, 119357, 145673, 151028, 178637, 183834, 316248]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 11706, 13593, 25156, 26509, 33999, 35441, 45030, 46955, 56152, 57968, 98830]
# row_index is 0
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 0, 0, 34586, 34586, 34586, 34586, 34587, 34588, 34588, 34588, 110168]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 305588, 340130, 717833, 760969, 992259, 1037037, 1292903, 1341330, 1575412, 1619132, 2473048]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_16/phy_AGR
# split_index is [0, 3933, 4252, 11232, 11506, 14564, 14976, 19617, 20196, 23734, 24137, 36643]
# row_index is 0
# trial name is2018-07-26_14-15-18_Trial5
# split_index is [0, 279374, 319928, 711109, 758465, 992509, 1038535, 1246565, 1298864, 1538528, 1587132, 2358985]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_9/phy_MS4
# split_index is [0, 230466, 264075, 612519, 656661, 860006, 905242, 1126901, 1178415, 1447986, 1503112, 2365097]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 324234, 367276, 768641, 829213, 1042761, 1088192, 1316409, 1380375, 1596287, 1636029, 2296196]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 32852, 37184, 81712, 87104, 113919, 119357, 145673, 151028, 178637, 183834, 316248]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 11706, 13593, 25156, 26509, 33999, 35441, 45030, 46955, 56152, 57968, 98830]
# row_index is 0
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 0, 0, 34586, 34586, 34586, 34586, 34587, 34588, 34588, 34588, 110168]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 305588, 340130, 717833, 760969, 992259, 1037037, 1292903, 1341330, 1575412, 1619132, 2473048]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_16/phy_AGR
# split_index is [0, 3933, 4252, 11232, 11506, 14564, 14976, 19617, 20196, 23734, 24137, 36643]
# row_index is 0
# trial name is2018-07-26_14-20-46_Post-Trial5
# split_index is [0, 279374, 319928, 711109, 758465, 992509, 1038535, 1246565, 1298864, 1538528, 1587132, 2358985]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_9/phy_MS4
# split_index is [0, 230466, 264075, 612519, 656661, 860006, 905242, 1126901, 1178415, 1447986, 1503112, 2365097]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 324234, 367276, 768641, 829213, 1042761, 1088192, 1316409, 1380375, 1596287, 1636029, 2296196]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 32852, 37184, 81712, 87104, 113919, 119357, 145673, 151028, 178637, 183834, 316248]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 11706, 13593, 25156, 26509, 33999, 35441, 45030, 46955, 56152, 57968, 98830]
# row_index is 0
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 0, 0, 34586, 34586, 34586, 34586, 34587, 34588, 34588, 34588, 110168]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 305588, 340130, 717833, 760969, 992259, 1037037, 1292903, 1341330, 1575412, 1619132, 2473048]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD2_OR_26-27_07_2018_merged/cortex/Tetrode_16/phy_AGR
# split_index is [0, 3933, 4252, 11232, 11506, 14564, 14976, 19617, 20196, 23734, 24137, 36643]
# row_index is 0

# %%
actmat_neuron_name = get_neuron_name(trial_info, absolute_path_list, trial_name_list[0], project_folder_name )
createFolder(path + '/' + date)
np.save("actmat_neuron_name", actmat_neuron_name)
# Out:
# split_index is [0, 279374, 319928, 711109, 758465, 992509, 1038535, 1246565, 1298864, 1538528, 1587132, 2358985]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# split_index is [0, 230466, 264075, 612519, 656661, 860006, 905242, 1126901, 1178415, 1447986, 1503112, 2365097]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# split_index is [0, 324234, 367276, 768641, 829213, 1042761, 1088192, 1316409, 1380375, 1596287, 1636029, 2296196]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# split_index is [0, 32852, 37184, 81712, 87104, 113919, 119357, 145673, 151028, 178637, 183834, 316248]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# split_index is [0, 11706, 13593, 25156, 26509, 33999, 35441, 45030, 46955, 56152, 57968, 98830]
# row_index is 0
# split_index is [0, 0, 0, 34586, 34586, 34586, 34586, 34587, 34588, 34588, 34588, 110168]
# row_index is 0
# row_index is 1
# row_index is 2
# split_index is [0, 305588, 340130, 717833, 760969, 992259, 1037037, 1292903, 1341330, 1575412, 1619132, 2473048]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# split_index is [0, 3933, 4252, 11232, 11506, 14564, 14976, 19617, 20196, 23734, 24137, 36643]
# row_index is 0

# %% [markdown]
# ### The code below is just for test purpose, do not run it

# %%
# spike_clusters = np.load("spike_clusters.npy")
# spike_times = np.load("spike_times.npy")
# set_neuron = set(spike_clusters)
# for neuron_x in set_neuron:
#     neuron_x_index =  [i for i,d in enumerate(spike_clusters) if d==neuron_x]
#     spike_times = spike_times.flatten()
#     neuron_x_map = (np.array([spike_times[index] for index in neuron_x_index])/750).astype(int)
#     neuron_x_map

# (np.array(spike_time_17)/750)[1]
