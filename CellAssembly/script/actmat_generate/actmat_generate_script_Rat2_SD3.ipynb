# %%
from actmat_generate import *
import os
import pandas as pd

# %% [markdown]
# ### Run the following script to generate actmat matrix
#
# - Change the path into the folder where you put the Trial_durations.xls file
# - Çhange the date into actual date performing the experiment

# %%
# path = "D:\Internship_Radbound\Cell_assembly_yuqin"
path = "/media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged"
date = "Rat2_SD3_CON_2"
project_folder_name = "RGS_PROJECT_RGS14_PFC_Rn2_CON_SD3"

# %%
os.chdir(path)
trial_info = pd.read_excel('Trial_durations.xls', index_col = 0)  
trial_last_period_name = trial_info.columns[-1]
final_samples = trial_info[trial_last_period_name]["Cumulative Samples"]
samples_index_list = list(trial_info.loc["Cumulative Samples"])
fs = 30000
#Modified the minutes and samples by removing the tail
trial_info.loc["modified_minutes"] = [45.0, 5.0, 45.0, 5.0, 45.0, 5.0, 45.0, 5.0, 45.0, 5.0, 180.0]
trial_info.loc["modified_samples"] = trial_info.loc["modified_minutes"]* 60 * 30000

# %%
trial_info
# Out:
#                     2018-07-28_11-22-47_Pre-sleep  2018-07-28_12-07-55_Trial1  \
# Unit
# Samples                              8.101478e+07                9.628672e+06
# Cumulative Samples                   8.101478e+07                9.064346e+07
# Seconds                              2.700493e+03                3.209557e+02
# Cumulative Seconds                   2.700493e+03                3.021449e+03
# Minutes                              4.500821e+01                5.349262e+00
# Cumulative Minutes                   4.500821e+01                5.035748e+01
# Hours                                7.501369e-01                8.915437e-02
# Cumulative Hours                     7.501369e-01                8.392913e-01
# modified_minutes                     4.500000e+01                5.000000e+00
# modified_samples                     8.100000e+07                9.000000e+06
#
#                     2018-07-28_12-13-20_Post-Trial1  \
# Unit
# Samples                                8.101376e+07
# Cumulative Samples                     1.716572e+08
# Seconds                                2.700459e+03
# Cumulative Seconds                     5.721907e+03
# Minutes                                4.500764e+01
# Cumulative Minutes                     9.536512e+01
# Hours                                  7.501274e-01
# Cumulative Hours                       1.589419e+00
# modified_minutes                       4.500000e+01
# modified_samples                       8.100000e+07
#
#                     2018-07-28_12-58-25_Trial2  \
# Unit
# Samples                           9.621504e+06
# Cumulative Samples                1.812787e+08
# Seconds                           3.207168e+02
# Cumulative Seconds                6.042624e+03
# Minutes                           5.345280e+00
# Cumulative Minutes                1.007104e+02
# Hours                             8.908800e-02
# Cumulative Hours                  1.678507e+00
# modified_minutes                  5.000000e+00
# modified_samples                  9.000000e+06
#
#                     2018-07-28_13-03-50_Post-Trial2  \
# Unit
# Samples                                8.820838e+07
# Cumulative Samples                     2.694871e+08
# Seconds                                2.940279e+03
# Cumulative Seconds                     8.982903e+03
# Minutes                                4.900466e+01
# Cumulative Minutes                     1.497151e+02
# Hours                                  8.167443e-01
# Cumulative Hours                       2.495251e+00
# modified_minutes                       4.500000e+01
# modified_samples                       8.100000e+07
#
#                     2018-07-28_13-52-56_Trial3  \
# Unit
# Samples                           9.921536e+06
# Cumulative Samples                2.794086e+08
# Seconds                           3.307179e+02
# Cumulative Seconds                9.313621e+03
# Minutes                           5.511964e+00
# Cumulative Minutes                1.552270e+02
# Hours                             9.186607e-02
# Cumulative Hours                  2.587117e+00
# modified_minutes                  5.000000e+00
# modified_samples                  9.000000e+06
#
#                     2018-07-28_13-58-31_Post-Trial3  \
# Unit
# Samples                                8.101274e+07
# Cumulative Samples                     3.604214e+08
# Seconds                                2.700425e+03
# Cumulative Seconds                     1.201405e+04
# Minutes                                4.500708e+01
# Cumulative Minutes                     2.002341e+02
# Hours                                  7.501179e-01
# Cumulative Hours                       3.337235e+00
# modified_minutes                       4.500000e+01
# modified_samples                       8.100000e+07
#
#                     2018-07-28_14-43-36_Trial4  \
# Unit
# Samples                           9.765888e+06
# Cumulative Samples                3.701873e+08
# Seconds                           3.255296e+02
# Cumulative Seconds                1.233958e+04
# Minutes                           5.425493e+00
# Cumulative Minutes                2.056596e+02
# Hours                             9.042489e-02
# Cumulative Hours                  3.427660e+00
# modified_minutes                  5.000000e+00
# modified_samples                  9.000000e+06
#
#                     2018-07-28_14-49-06_Post-Trial4  \
# Unit
# Samples                                8.103117e+07
# Cumulative Samples                     4.512184e+08
# Seconds                                2.701039e+03
# Cumulative Seconds                     1.504061e+04
# Minutes                                4.501732e+01
# Cumulative Minutes                     2.506769e+02
# Hours                                  7.502886e-01
# Cumulative Hours                       4.177948e+00
# modified_minutes                       4.500000e+01
# modified_samples                       8.100000e+07
#
#                     2018-07-28_15-34-11_Trial5  \
# Unit
# Samples                           1.044582e+07
# Cumulative Samples                4.616643e+08
# Seconds                           3.481941e+02
# Cumulative Seconds                1.538881e+04
# Minutes                           5.803236e+00
# Cumulative Minutes                2.564801e+02
# Hours                             9.672059e-02
# Cumulative Hours                  4.274669e+00
# modified_minutes                  5.000000e+00
# modified_samples                  9.000000e+06
#
#                     2018-07-28_15-40-04_Post-Trial5
# Unit
# Samples                                3.240397e+08
# Cumulative Samples                     7.857039e+08
# Seconds                                1.080132e+04
# Cumulative Seconds                     2.619013e+04
# Minutes                                1.800220e+02
# Cumulative Minutes                     4.365022e+02
# Hours                                  3.000367e+00
# Cumulative Hours                       7.275036e+00
# modified_minutes                       1.800000e+02
# modified_samples                       3.240000e+08

# %% [markdown]
# ### Change:
#
# - absolute_path_list
# - trial_name_list
# - project_folder_name

# %%
absolute_path_list = [path + "/cortex/Tetrode_8/phy_MS4",
                     path + "/cortex/Tetrode_9/phy_MS4",
                     path + "/cortex/Tetrode_10/phy_MS4",
                     path + "/cortex/Tetrode_12/phy_MS4",
                     path + "/cortex/Tetrode_13/phy_MS4",
                     path + "/cortex/Tetrode_14/phy_MS4",
                     path + "/cortex/Tetrode_15/phy_MS4",
                     path + "/cortex/Tetrode_16/phy_MS4"]
# absolute_path_list = [path + "/cortex/Tetrode_14/phy_AGR"]

trial_name_list = list(trial_info.columns)

# %%
# get_neuron_name(trial_info, absolute_path_list, trial_name_list[0], project_folder_name)

# %%
# iterate_all_file_for_a_trial(trial_info, absolute_path_list, trial_name_list[-2], project_folder_name)

# %%
for trial_name in trial_name_list:
    createFolder(path + '/' + date)
    final_matrix = iterate_all_file_for_a_trial(trial_info, absolute_path_list, trial_name, project_folder_name)
    createFolder(path + '/' + date)
    np.save(trial_name + "_actmat", final_matrix)
# Out:
# trial name is2018-07-28_11-22-47_Pre-sleep
# split_index is [0, 240373, 279992, 462001, 499890, 645760, 682055, 816159, 855081, 1104378, 1144103, 2115174]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_9/phy_MS4
# split_index is [0, 186268, 220085, 336283, 377935, 496016, 531726, 649370, 702153, 1024069, 1076543, 2308283]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 309243, 355472, 591696, 637430, 836428, 873728, 1033706, 1077072, 1353201, 1394076, 2252756]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_12/phy_MS4
# split_index is [0, 334842, 384727, 655582, 705316, 941795, 988517, 1213094, 1263373, 1600998, 1653742, 2980727]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_13/phy_MS4
# split_index is [0, 266905, 307110, 536120, 579921, 794754, 836533, 1028335, 1073030, 1365537, 1413438, 2677635]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_14/phy_MS4
# split_index is [0, 251276, 288385, 463826, 500189, 630306, 663112, 778198, 824414, 1059663, 1103916, 2156786]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 260833, 307788, 478748, 522723, 662196, 702762, 818323, 888002, 1174803, 1222882, 2274882]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_16/phy_MS4
# split_index is [0, 309948, 362366, 544858, 597853, 764991, 810013, 929802, 975639, 1262272, 1314827, 2171231]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# trial name is2018-07-28_12-07-55_Trial1
# split_index is [0, 240373, 279992, 462001, 499890, 645760, 682055, 816159, 855081, 1104378, 1144103, 2115174]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_9/phy_MS4
# split_index is [0, 186268, 220085, 336283, 377935, 496016, 531726, 649370, 702153, 1024069, 1076543, 2308283]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 309243, 355472, 591696, 637430, 836428, 873728, 1033706, 1077072, 1353201, 1394076, 2252756]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_12/phy_MS4
# split_index is [0, 334842, 384727, 655582, 705316, 941795, 988517, 1213094, 1263373, 1600998, 1653742, 2980727]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_13/phy_MS4
# split_index is [0, 266905, 307110, 536120, 579921, 794754, 836533, 1028335, 1073030, 1365537, 1413438, 2677635]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_14/phy_MS4
# split_index is [0, 251276, 288385, 463826, 500189, 630306, 663112, 778198, 824414, 1059663, 1103916, 2156786]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 260833, 307788, 478748, 522723, 662196, 702762, 818323, 888002, 1174803, 1222882, 2274882]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_16/phy_MS4
# split_index is [0, 309948, 362366, 544858, 597853, 764991, 810013, 929802, 975639, 1262272, 1314827, 2171231]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# trial name is2018-07-28_12-13-20_Post-Trial1
# split_index is [0, 240373, 279992, 462001, 499890, 645760, 682055, 816159, 855081, 1104378, 1144103, 2115174]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_9/phy_MS4
# split_index is [0, 186268, 220085, 336283, 377935, 496016, 531726, 649370, 702153, 1024069, 1076543, 2308283]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 309243, 355472, 591696, 637430, 836428, 873728, 1033706, 1077072, 1353201, 1394076, 2252756]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_12/phy_MS4
# split_index is [0, 334842, 384727, 655582, 705316, 941795, 988517, 1213094, 1263373, 1600998, 1653742, 2980727]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_13/phy_MS4
# split_index is [0, 266905, 307110, 536120, 579921, 794754, 836533, 1028335, 1073030, 1365537, 1413438, 2677635]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_14/phy_MS4
# split_index is [0, 251276, 288385, 463826, 500189, 630306, 663112, 778198, 824414, 1059663, 1103916, 2156786]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 260833, 307788, 478748, 522723, 662196, 702762, 818323, 888002, 1174803, 1222882, 2274882]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_16/phy_MS4
# split_index is [0, 309948, 362366, 544858, 597853, 764991, 810013, 929802, 975639, 1262272, 1314827, 2171231]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# trial name is2018-07-28_12-58-25_Trial2
# split_index is [0, 240373, 279992, 462001, 499890, 645760, 682055, 816159, 855081, 1104378, 1144103, 2115174]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_9/phy_MS4
# split_index is [0, 186268, 220085, 336283, 377935, 496016, 531726, 649370, 702153, 1024069, 1076543, 2308283]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 309243, 355472, 591696, 637430, 836428, 873728, 1033706, 1077072, 1353201, 1394076, 2252756]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_12/phy_MS4
# split_index is [0, 334842, 384727, 655582, 705316, 941795, 988517, 1213094, 1263373, 1600998, 1653742, 2980727]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_13/phy_MS4
# split_index is [0, 266905, 307110, 536120, 579921, 794754, 836533, 1028335, 1073030, 1365537, 1413438, 2677635]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_14/phy_MS4
# split_index is [0, 251276, 288385, 463826, 500189, 630306, 663112, 778198, 824414, 1059663, 1103916, 2156786]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 260833, 307788, 478748, 522723, 662196, 702762, 818323, 888002, 1174803, 1222882, 2274882]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_16/phy_MS4
# split_index is [0, 309948, 362366, 544858, 597853, 764991, 810013, 929802, 975639, 1262272, 1314827, 2171231]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# trial name is2018-07-28_13-03-50_Post-Trial2
# split_index is [0, 240373, 279992, 462001, 499890, 645760, 682055, 816159, 855081, 1104378, 1144103, 2115174]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_9/phy_MS4
# split_index is [0, 186268, 220085, 336283, 377935, 496016, 531726, 649370, 702153, 1024069, 1076543, 2308283]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 309243, 355472, 591696, 637430, 836428, 873728, 1033706, 1077072, 1353201, 1394076, 2252756]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_12/phy_MS4
# split_index is [0, 334842, 384727, 655582, 705316, 941795, 988517, 1213094, 1263373, 1600998, 1653742, 2980727]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_13/phy_MS4
# split_index is [0, 266905, 307110, 536120, 579921, 794754, 836533, 1028335, 1073030, 1365537, 1413438, 2677635]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_14/phy_MS4
# split_index is [0, 251276, 288385, 463826, 500189, 630306, 663112, 778198, 824414, 1059663, 1103916, 2156786]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 260833, 307788, 478748, 522723, 662196, 702762, 818323, 888002, 1174803, 1222882, 2274882]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_16/phy_MS4
# split_index is [0, 309948, 362366, 544858, 597853, 764991, 810013, 929802, 975639, 1262272, 1314827, 2171231]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# trial name is2018-07-28_13-52-56_Trial3
# split_index is [0, 240373, 279992, 462001, 499890, 645760, 682055, 816159, 855081, 1104378, 1144103, 2115174]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_9/phy_MS4
# split_index is [0, 186268, 220085, 336283, 377935, 496016, 531726, 649370, 702153, 1024069, 1076543, 2308283]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 309243, 355472, 591696, 637430, 836428, 873728, 1033706, 1077072, 1353201, 1394076, 2252756]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_12/phy_MS4
# split_index is [0, 334842, 384727, 655582, 705316, 941795, 988517, 1213094, 1263373, 1600998, 1653742, 2980727]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_13/phy_MS4
# split_index is [0, 266905, 307110, 536120, 579921, 794754, 836533, 1028335, 1073030, 1365537, 1413438, 2677635]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_14/phy_MS4
# split_index is [0, 251276, 288385, 463826, 500189, 630306, 663112, 778198, 824414, 1059663, 1103916, 2156786]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 260833, 307788, 478748, 522723, 662196, 702762, 818323, 888002, 1174803, 1222882, 2274882]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_16/phy_MS4
# split_index is [0, 309948, 362366, 544858, 597853, 764991, 810013, 929802, 975639, 1262272, 1314827, 2171231]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# trial name is2018-07-28_13-58-31_Post-Trial3
# split_index is [0, 240373, 279992, 462001, 499890, 645760, 682055, 816159, 855081, 1104378, 1144103, 2115174]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_9/phy_MS4
# split_index is [0, 186268, 220085, 336283, 377935, 496016, 531726, 649370, 702153, 1024069, 1076543, 2308283]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 309243, 355472, 591696, 637430, 836428, 873728, 1033706, 1077072, 1353201, 1394076, 2252756]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_12/phy_MS4
# split_index is [0, 334842, 384727, 655582, 705316, 941795, 988517, 1213094, 1263373, 1600998, 1653742, 2980727]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_13/phy_MS4
# split_index is [0, 266905, 307110, 536120, 579921, 794754, 836533, 1028335, 1073030, 1365537, 1413438, 2677635]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_14/phy_MS4
# split_index is [0, 251276, 288385, 463826, 500189, 630306, 663112, 778198, 824414, 1059663, 1103916, 2156786]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 260833, 307788, 478748, 522723, 662196, 702762, 818323, 888002, 1174803, 1222882, 2274882]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_16/phy_MS4
# split_index is [0, 309948, 362366, 544858, 597853, 764991, 810013, 929802, 975639, 1262272, 1314827, 2171231]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# trial name is2018-07-28_14-43-36_Trial4
# split_index is [0, 240373, 279992, 462001, 499890, 645760, 682055, 816159, 855081, 1104378, 1144103, 2115174]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_9/phy_MS4
# split_index is [0, 186268, 220085, 336283, 377935, 496016, 531726, 649370, 702153, 1024069, 1076543, 2308283]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 309243, 355472, 591696, 637430, 836428, 873728, 1033706, 1077072, 1353201, 1394076, 2252756]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_12/phy_MS4
# split_index is [0, 334842, 384727, 655582, 705316, 941795, 988517, 1213094, 1263373, 1600998, 1653742, 2980727]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_13/phy_MS4
# split_index is [0, 266905, 307110, 536120, 579921, 794754, 836533, 1028335, 1073030, 1365537, 1413438, 2677635]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_14/phy_MS4
# split_index is [0, 251276, 288385, 463826, 500189, 630306, 663112, 778198, 824414, 1059663, 1103916, 2156786]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 260833, 307788, 478748, 522723, 662196, 702762, 818323, 888002, 1174803, 1222882, 2274882]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_16/phy_MS4
# split_index is [0, 309948, 362366, 544858, 597853, 764991, 810013, 929802, 975639, 1262272, 1314827, 2171231]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# trial name is2018-07-28_14-49-06_Post-Trial4
# split_index is [0, 240373, 279992, 462001, 499890, 645760, 682055, 816159, 855081, 1104378, 1144103, 2115174]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_9/phy_MS4
# split_index is [0, 186268, 220085, 336283, 377935, 496016, 531726, 649370, 702153, 1024069, 1076543, 2308283]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 309243, 355472, 591696, 637430, 836428, 873728, 1033706, 1077072, 1353201, 1394076, 2252756]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_12/phy_MS4
# split_index is [0, 334842, 384727, 655582, 705316, 941795, 988517, 1213094, 1263373, 1600998, 1653742, 2980727]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_13/phy_MS4
# split_index is [0, 266905, 307110, 536120, 579921, 794754, 836533, 1028335, 1073030, 1365537, 1413438, 2677635]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_14/phy_MS4
# split_index is [0, 251276, 288385, 463826, 500189, 630306, 663112, 778198, 824414, 1059663, 1103916, 2156786]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 260833, 307788, 478748, 522723, 662196, 702762, 818323, 888002, 1174803, 1222882, 2274882]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_16/phy_MS4
# split_index is [0, 309948, 362366, 544858, 597853, 764991, 810013, 929802, 975639, 1262272, 1314827, 2171231]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# trial name is2018-07-28_15-34-11_Trial5
# split_index is [0, 240373, 279992, 462001, 499890, 645760, 682055, 816159, 855081, 1104378, 1144103, 2115174]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_9/phy_MS4
# split_index is [0, 186268, 220085, 336283, 377935, 496016, 531726, 649370, 702153, 1024069, 1076543, 2308283]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 309243, 355472, 591696, 637430, 836428, 873728, 1033706, 1077072, 1353201, 1394076, 2252756]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_12/phy_MS4
# split_index is [0, 334842, 384727, 655582, 705316, 941795, 988517, 1213094, 1263373, 1600998, 1653742, 2980727]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_13/phy_MS4
# split_index is [0, 266905, 307110, 536120, 579921, 794754, 836533, 1028335, 1073030, 1365537, 1413438, 2677635]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_14/phy_MS4
# split_index is [0, 251276, 288385, 463826, 500189, 630306, 663112, 778198, 824414, 1059663, 1103916, 2156786]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 260833, 307788, 478748, 522723, 662196, 702762, 818323, 888002, 1174803, 1222882, 2274882]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_16/phy_MS4
# split_index is [0, 309948, 362366, 544858, 597853, 764991, 810013, 929802, 975639, 1262272, 1314827, 2171231]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# trial name is2018-07-28_15-40-04_Post-Trial5
# split_index is [0, 240373, 279992, 462001, 499890, 645760, 682055, 816159, 855081, 1104378, 1144103, 2115174]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_9/phy_MS4
# split_index is [0, 186268, 220085, 336283, 377935, 496016, 531726, 649370, 702153, 1024069, 1076543, 2308283]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 309243, 355472, 591696, 637430, 836428, 873728, 1033706, 1077072, 1353201, 1394076, 2252756]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_12/phy_MS4
# split_index is [0, 334842, 384727, 655582, 705316, 941795, 988517, 1213094, 1263373, 1600998, 1653742, 2980727]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_13/phy_MS4
# split_index is [0, 266905, 307110, 536120, 579921, 794754, 836533, 1028335, 1073030, 1365537, 1413438, 2677635]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_14/phy_MS4
# split_index is [0, 251276, 288385, 463826, 500189, 630306, 663112, 778198, 824414, 1059663, 1103916, 2156786]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 260833, 307788, 478748, 522723, 662196, 702762, 818323, 888002, 1174803, 1222882, 2274882]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL04_RAT_HOMER_2/Spike_sorting/Rat_OS_Ephys_RGS14_Rat2_57987/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018/Rat_OS_Ephys_RGS14_Rat2_57987_SD3_CON_28-29_07_2018_merged/cortex/Tetrode_16/phy_MS4
# split_index is [0, 309948, 362366, 544858, 597853, 764991, 810013, 929802, 975639, 1262272, 1314827, 2171231]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4

# %%
actmat_neuron_name = get_neuron_name(trial_info, absolute_path_list, trial_name_list[0], project_folder_name )
createFolder(path + '/' + date)
np.save("actmat_neuron_name", actmat_neuron_name)
# Out:
# split_index is [0, 240373, 279992, 462001, 499890, 645760, 682055, 816159, 855081, 1104378, 1144103, 2115174]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# split_index is [0, 186268, 220085, 336283, 377935, 496016, 531726, 649370, 702153, 1024069, 1076543, 2308283]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# split_index is [0, 309243, 355472, 591696, 637430, 836428, 873728, 1033706, 1077072, 1353201, 1394076, 2252756]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# split_index is [0, 334842, 384727, 655582, 705316, 941795, 988517, 1213094, 1263373, 1600998, 1653742, 2980727]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# split_index is [0, 266905, 307110, 536120, 579921, 794754, 836533, 1028335, 1073030, 1365537, 1413438, 2677635]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# split_index is [0, 251276, 288385, 463826, 500189, 630306, 663112, 778198, 824414, 1059663, 1103916, 2156786]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# split_index is [0, 260833, 307788, 478748, 522723, 662196, 702762, 818323, 888002, 1174803, 1222882, 2274882]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# split_index is [0, 309948, 362366, 544858, 597853, 764991, 810013, 929802, 975639, 1262272, 1314827, 2171231]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4

# %% [markdown]
# ### The code below is just for test purpose, do not run it

# %%
# spike_clusters = np.load("spike_clusters.npy")
# spike_times = np.load("spike_times.npy")
# set_neuron = set(spike_clusters)
# for neuron_x in set_neuron:
#     neuron_x_index =  [i for i,d in enumerate(spike_clusters) if d==neuron_x]
#     spike_times = spike_times.flatten()
#     neuron_x_map = (np.array([spike_times[index] for index in neuron_x_index])/750).astype(int)
#     neuron_x_map

# (np.array(spike_time_17)/750)[1]
