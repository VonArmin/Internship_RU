# %%
from actmat_generate import *
import os
import pandas as pd

# %% [markdown]
# ### Run the following script to generate actmat matrix
#
# - Change the path into the folder where you put the Trial_durations.xls file
# - Çhange the date into actual date performing the experiment

# %%
# path = "D:\Internship_Radbound\Cell_assembly_yuqin"
path = "/media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged"
date = "Rat4_SD5_OD"
project_folder_name = "RGS_PROJECT_RGS14_PFC_Rn4_OD_SD5_T"

# %%
os.chdir(path)
trial_info = pd.read_excel('Trial_durations.xls', index_col = 0)  
trial_last_period_name = trial_info.columns[-1]
final_samples = trial_info[trial_last_period_name]["Cumulative Samples"]
samples_index_list = list(trial_info.loc["Cumulative Samples"])
fs = 30000
#Modified the minutes and samples by removing the tail
trial_info.loc["modified_minutes"] = [45.0, 5.0, 45.0, 5.0, 45.0, 5.0, 45.0, 5.0, 45.0, 5.0, 180.0]
trial_info.loc["modified_samples"] = trial_info.loc["modified_minutes"]* 60 * 30000

# %% [markdown]
# ### Change:
#
# - absolute_path_list
# - trial_name_list
# - project_folder_name

# %%
absolute_path_list = [path + "/cortex/Tetrode_1/phy_AGR",
                     path + "/cortex/Tetrode_2/phy_AGR",
                     path + "/cortex/Tetrode_3/phy_MS4",
                     path + "/cortex/Tetrode_10/phy_MS4",
                     path + "/cortex/Tetrode_11/phy_MS4",
                     path + "/cortex/Tetrode_12/phy_MS4",
                     path + "/cortex/Tetrode_13/phy_AGR",
                     path + "/cortex/Tetrode_15/phy_AGR",
                     path + "/cortex/Tetrode_16/phy_MS4"]
trial_name_list = list(trial_info.columns)

# %%
# get_neuron_name(trial_info, absolute_path_list, trial_name_list[0], project_folder_name)

# %%
for trial_name in trial_name_list:
    createFolder(path + '/' + date)
    final_matrix = iterate_all_file_for_a_trial(trial_info, absolute_path_list, trial_name, project_folder_name)
    createFolder(path + '/' + date)
    np.save(trial_name + "_actmat", final_matrix)
# Out:
# trial name isPre_sleep
# split_index is [0, 18389, 21011, 36853, 39210, 50523, 52507, 59474, 61890, 69887, 71695, 110072]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_2/phy_AGR
# split_index is [0, 2, 2, 185, 570, 1208, 1209, 1216, 1229, 1241, 1242, 1346]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_3/phy_MS4
# split_index is [0, 226554, 275286, 538878, 587470, 813179, 860458, 1056488, 1109470, 1340235, 1393971, 2588789]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 176463, 223495, 446725, 488531, 645344, 689734, 839722, 894845, 1105759, 1162735, 2163890]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_11/phy_MS4
# split_index is [0, 167497, 210885, 423512, 462153, 628512, 668943, 815144, 860139, 1048848, 1093580, 2056818]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_12/phy_MS4
# split_index is [0, 174964, 219579, 426634, 467204, 625024, 667331, 810975, 858317, 1024325, 1069139, 2006659]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 9550, 10379, 20253, 21009, 31421, 32588, 43226, 44585, 57592, 58834, 109008]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_15/phy_AGR
# split_index is [0, 22636, 25634, 48510, 50564, 74774, 76836, 102068, 103794, 132531, 136785, 254453]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# row_index is 56
# row_index is 57
# row_index is 58
# row_index is 59
# row_index is 60
# row_index is 61
# row_index is 62
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_16/phy_MS4
# split_index is [0, 188249, 232837, 453251, 495230, 668880, 711260, 869641, 915726, 1106433, 1157847, 2186323]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# trial name isTrial1
# split_index is [0, 18389, 21011, 36853, 39210, 50523, 52507, 59474, 61890, 69887, 71695, 110072]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_2/phy_AGR
# split_index is [0, 2, 2, 185, 570, 1208, 1209, 1216, 1229, 1241, 1242, 1346]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_3/phy_MS4
# split_index is [0, 226554, 275286, 538878, 587470, 813179, 860458, 1056488, 1109470, 1340235, 1393971, 2588789]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 176463, 223495, 446725, 488531, 645344, 689734, 839722, 894845, 1105759, 1162735, 2163890]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_11/phy_MS4
# split_index is [0, 167497, 210885, 423512, 462153, 628512, 668943, 815144, 860139, 1048848, 1093580, 2056818]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_12/phy_MS4
# split_index is [0, 174964, 219579, 426634, 467204, 625024, 667331, 810975, 858317, 1024325, 1069139, 2006659]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 9550, 10379, 20253, 21009, 31421, 32588, 43226, 44585, 57592, 58834, 109008]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_15/phy_AGR
# split_index is [0, 22636, 25634, 48510, 50564, 74774, 76836, 102068, 103794, 132531, 136785, 254453]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# row_index is 56
# row_index is 57
# row_index is 58
# row_index is 59
# row_index is 60
# row_index is 61
# row_index is 62
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_16/phy_MS4
# split_index is [0, 188249, 232837, 453251, 495230, 668880, 711260, 869641, 915726, 1106433, 1157847, 2186323]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# trial name isPost_Trial1
# split_index is [0, 18389, 21011, 36853, 39210, 50523, 52507, 59474, 61890, 69887, 71695, 110072]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_2/phy_AGR
# split_index is [0, 2, 2, 185, 570, 1208, 1209, 1216, 1229, 1241, 1242, 1346]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_3/phy_MS4
# split_index is [0, 226554, 275286, 538878, 587470, 813179, 860458, 1056488, 1109470, 1340235, 1393971, 2588789]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 176463, 223495, 446725, 488531, 645344, 689734, 839722, 894845, 1105759, 1162735, 2163890]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_11/phy_MS4
# split_index is [0, 167497, 210885, 423512, 462153, 628512, 668943, 815144, 860139, 1048848, 1093580, 2056818]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_12/phy_MS4
# split_index is [0, 174964, 219579, 426634, 467204, 625024, 667331, 810975, 858317, 1024325, 1069139, 2006659]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 9550, 10379, 20253, 21009, 31421, 32588, 43226, 44585, 57592, 58834, 109008]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_15/phy_AGR
# split_index is [0, 22636, 25634, 48510, 50564, 74774, 76836, 102068, 103794, 132531, 136785, 254453]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# row_index is 56
# row_index is 57
# row_index is 58
# row_index is 59
# row_index is 60
# row_index is 61
# row_index is 62
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_16/phy_MS4
# split_index is [0, 188249, 232837, 453251, 495230, 668880, 711260, 869641, 915726, 1106433, 1157847, 2186323]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# trial name isTrial2
# split_index is [0, 18389, 21011, 36853, 39210, 50523, 52507, 59474, 61890, 69887, 71695, 110072]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_2/phy_AGR
# split_index is [0, 2, 2, 185, 570, 1208, 1209, 1216, 1229, 1241, 1242, 1346]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_3/phy_MS4
# split_index is [0, 226554, 275286, 538878, 587470, 813179, 860458, 1056488, 1109470, 1340235, 1393971, 2588789]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 176463, 223495, 446725, 488531, 645344, 689734, 839722, 894845, 1105759, 1162735, 2163890]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_11/phy_MS4
# split_index is [0, 167497, 210885, 423512, 462153, 628512, 668943, 815144, 860139, 1048848, 1093580, 2056818]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_12/phy_MS4
# split_index is [0, 174964, 219579, 426634, 467204, 625024, 667331, 810975, 858317, 1024325, 1069139, 2006659]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 9550, 10379, 20253, 21009, 31421, 32588, 43226, 44585, 57592, 58834, 109008]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_15/phy_AGR
# split_index is [0, 22636, 25634, 48510, 50564, 74774, 76836, 102068, 103794, 132531, 136785, 254453]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# row_index is 56
# row_index is 57
# row_index is 58
# row_index is 59
# row_index is 60
# row_index is 61
# row_index is 62
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_16/phy_MS4
# split_index is [0, 188249, 232837, 453251, 495230, 668880, 711260, 869641, 915726, 1106433, 1157847, 2186323]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# trial name isPost_Trial2
# split_index is [0, 18389, 21011, 36853, 39210, 50523, 52507, 59474, 61890, 69887, 71695, 110072]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_2/phy_AGR
# split_index is [0, 2, 2, 185, 570, 1208, 1209, 1216, 1229, 1241, 1242, 1346]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_3/phy_MS4
# split_index is [0, 226554, 275286, 538878, 587470, 813179, 860458, 1056488, 1109470, 1340235, 1393971, 2588789]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 176463, 223495, 446725, 488531, 645344, 689734, 839722, 894845, 1105759, 1162735, 2163890]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_11/phy_MS4
# split_index is [0, 167497, 210885, 423512, 462153, 628512, 668943, 815144, 860139, 1048848, 1093580, 2056818]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_12/phy_MS4
# split_index is [0, 174964, 219579, 426634, 467204, 625024, 667331, 810975, 858317, 1024325, 1069139, 2006659]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 9550, 10379, 20253, 21009, 31421, 32588, 43226, 44585, 57592, 58834, 109008]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_15/phy_AGR
# split_index is [0, 22636, 25634, 48510, 50564, 74774, 76836, 102068, 103794, 132531, 136785, 254453]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# row_index is 56
# row_index is 57
# row_index is 58
# row_index is 59
# row_index is 60
# row_index is 61
# row_index is 62
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_16/phy_MS4
# split_index is [0, 188249, 232837, 453251, 495230, 668880, 711260, 869641, 915726, 1106433, 1157847, 2186323]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# trial name isTrial3
# split_index is [0, 18389, 21011, 36853, 39210, 50523, 52507, 59474, 61890, 69887, 71695, 110072]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_2/phy_AGR
# split_index is [0, 2, 2, 185, 570, 1208, 1209, 1216, 1229, 1241, 1242, 1346]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_3/phy_MS4
# split_index is [0, 226554, 275286, 538878, 587470, 813179, 860458, 1056488, 1109470, 1340235, 1393971, 2588789]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 176463, 223495, 446725, 488531, 645344, 689734, 839722, 894845, 1105759, 1162735, 2163890]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_11/phy_MS4
# split_index is [0, 167497, 210885, 423512, 462153, 628512, 668943, 815144, 860139, 1048848, 1093580, 2056818]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_12/phy_MS4
# split_index is [0, 174964, 219579, 426634, 467204, 625024, 667331, 810975, 858317, 1024325, 1069139, 2006659]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 9550, 10379, 20253, 21009, 31421, 32588, 43226, 44585, 57592, 58834, 109008]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_15/phy_AGR
# split_index is [0, 22636, 25634, 48510, 50564, 74774, 76836, 102068, 103794, 132531, 136785, 254453]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# row_index is 56
# row_index is 57
# row_index is 58
# row_index is 59
# row_index is 60
# row_index is 61
# row_index is 62
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_16/phy_MS4
# split_index is [0, 188249, 232837, 453251, 495230, 668880, 711260, 869641, 915726, 1106433, 1157847, 2186323]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# trial name isPost_Trial3
# split_index is [0, 18389, 21011, 36853, 39210, 50523, 52507, 59474, 61890, 69887, 71695, 110072]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_2/phy_AGR
# split_index is [0, 2, 2, 185, 570, 1208, 1209, 1216, 1229, 1241, 1242, 1346]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_3/phy_MS4
# split_index is [0, 226554, 275286, 538878, 587470, 813179, 860458, 1056488, 1109470, 1340235, 1393971, 2588789]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 176463, 223495, 446725, 488531, 645344, 689734, 839722, 894845, 1105759, 1162735, 2163890]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_11/phy_MS4
# split_index is [0, 167497, 210885, 423512, 462153, 628512, 668943, 815144, 860139, 1048848, 1093580, 2056818]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_12/phy_MS4
# split_index is [0, 174964, 219579, 426634, 467204, 625024, 667331, 810975, 858317, 1024325, 1069139, 2006659]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 9550, 10379, 20253, 21009, 31421, 32588, 43226, 44585, 57592, 58834, 109008]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_15/phy_AGR
# split_index is [0, 22636, 25634, 48510, 50564, 74774, 76836, 102068, 103794, 132531, 136785, 254453]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# row_index is 56
# row_index is 57
# row_index is 58
# row_index is 59
# row_index is 60
# row_index is 61
# row_index is 62
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_16/phy_MS4
# split_index is [0, 188249, 232837, 453251, 495230, 668880, 711260, 869641, 915726, 1106433, 1157847, 2186323]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# trial name isTrial4
# split_index is [0, 18389, 21011, 36853, 39210, 50523, 52507, 59474, 61890, 69887, 71695, 110072]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_2/phy_AGR
# split_index is [0, 2, 2, 185, 570, 1208, 1209, 1216, 1229, 1241, 1242, 1346]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_3/phy_MS4
# split_index is [0, 226554, 275286, 538878, 587470, 813179, 860458, 1056488, 1109470, 1340235, 1393971, 2588789]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 176463, 223495, 446725, 488531, 645344, 689734, 839722, 894845, 1105759, 1162735, 2163890]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_11/phy_MS4
# split_index is [0, 167497, 210885, 423512, 462153, 628512, 668943, 815144, 860139, 1048848, 1093580, 2056818]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_12/phy_MS4
# split_index is [0, 174964, 219579, 426634, 467204, 625024, 667331, 810975, 858317, 1024325, 1069139, 2006659]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 9550, 10379, 20253, 21009, 31421, 32588, 43226, 44585, 57592, 58834, 109008]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_15/phy_AGR
# split_index is [0, 22636, 25634, 48510, 50564, 74774, 76836, 102068, 103794, 132531, 136785, 254453]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# row_index is 56
# row_index is 57
# row_index is 58
# row_index is 59
# row_index is 60
# row_index is 61
# row_index is 62
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_16/phy_MS4
# split_index is [0, 188249, 232837, 453251, 495230, 668880, 711260, 869641, 915726, 1106433, 1157847, 2186323]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# trial name isPost_Trial4
# split_index is [0, 18389, 21011, 36853, 39210, 50523, 52507, 59474, 61890, 69887, 71695, 110072]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_2/phy_AGR
# split_index is [0, 2, 2, 185, 570, 1208, 1209, 1216, 1229, 1241, 1242, 1346]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_3/phy_MS4
# split_index is [0, 226554, 275286, 538878, 587470, 813179, 860458, 1056488, 1109470, 1340235, 1393971, 2588789]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 176463, 223495, 446725, 488531, 645344, 689734, 839722, 894845, 1105759, 1162735, 2163890]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_11/phy_MS4
# split_index is [0, 167497, 210885, 423512, 462153, 628512, 668943, 815144, 860139, 1048848, 1093580, 2056818]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_12/phy_MS4
# split_index is [0, 174964, 219579, 426634, 467204, 625024, 667331, 810975, 858317, 1024325, 1069139, 2006659]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 9550, 10379, 20253, 21009, 31421, 32588, 43226, 44585, 57592, 58834, 109008]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_15/phy_AGR
# split_index is [0, 22636, 25634, 48510, 50564, 74774, 76836, 102068, 103794, 132531, 136785, 254453]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# row_index is 56
# row_index is 57
# row_index is 58
# row_index is 59
# row_index is 60
# row_index is 61
# row_index is 62
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_16/phy_MS4
# split_index is [0, 188249, 232837, 453251, 495230, 668880, 711260, 869641, 915726, 1106433, 1157847, 2186323]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# trial name isTrial5
# split_index is [0, 18389, 21011, 36853, 39210, 50523, 52507, 59474, 61890, 69887, 71695, 110072]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_2/phy_AGR
# split_index is [0, 2, 2, 185, 570, 1208, 1209, 1216, 1229, 1241, 1242, 1346]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_3/phy_MS4
# split_index is [0, 226554, 275286, 538878, 587470, 813179, 860458, 1056488, 1109470, 1340235, 1393971, 2588789]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 176463, 223495, 446725, 488531, 645344, 689734, 839722, 894845, 1105759, 1162735, 2163890]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_11/phy_MS4
# split_index is [0, 167497, 210885, 423512, 462153, 628512, 668943, 815144, 860139, 1048848, 1093580, 2056818]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_12/phy_MS4
# split_index is [0, 174964, 219579, 426634, 467204, 625024, 667331, 810975, 858317, 1024325, 1069139, 2006659]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 9550, 10379, 20253, 21009, 31421, 32588, 43226, 44585, 57592, 58834, 109008]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_15/phy_AGR
# split_index is [0, 22636, 25634, 48510, 50564, 74774, 76836, 102068, 103794, 132531, 136785, 254453]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# row_index is 56
# row_index is 57
# row_index is 58
# row_index is 59
# row_index is 60
# row_index is 61
# row_index is 62
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_16/phy_MS4
# split_index is [0, 188249, 232837, 453251, 495230, 668880, 711260, 869641, 915726, 1106433, 1157847, 2186323]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# trial name isPost_Trial5
# split_index is [0, 18389, 21011, 36853, 39210, 50523, 52507, 59474, 61890, 69887, 71695, 110072]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_2/phy_AGR
# split_index is [0, 2, 2, 185, 570, 1208, 1209, 1216, 1229, 1241, 1242, 1346]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_3/phy_MS4
# split_index is [0, 226554, 275286, 538878, 587470, 813179, 860458, 1056488, 1109470, 1340235, 1393971, 2588789]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 176463, 223495, 446725, 488531, 645344, 689734, 839722, 894845, 1105759, 1162735, 2163890]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_11/phy_MS4
# split_index is [0, 167497, 210885, 423512, 462153, 628512, 668943, 815144, 860139, 1048848, 1093580, 2056818]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_12/phy_MS4
# split_index is [0, 174964, 219579, 426634, 467204, 625024, 667331, 810975, 858317, 1024325, 1069139, 2006659]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 9550, 10379, 20253, 21009, 31421, 32588, 43226, 44585, 57592, 58834, 109008]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_15/phy_AGR
# split_index is [0, 22636, 25634, 48510, 50564, 74774, 76836, 102068, 103794, 132531, 136785, 254453]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# row_index is 56
# row_index is 57
# row_index is 58
# row_index is 59
# row_index is 60
# row_index is 61
# row_index is 62
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019/OS_Ephys_RGS14_Rat4_357153_SD5_OD_07-08_11_2019_merged/cortex/Tetrode_16/phy_MS4
# split_index is [0, 188249, 232837, 453251, 495230, 668880, 711260, 869641, 915726, 1106433, 1157847, 2186323]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3

# %%
actmat_neuron_name = get_neuron_name(trial_info, absolute_path_list, trial_name_list[0], project_folder_name )
createFolder(path + '/' + date)
np.save("actmat_neuron_name", actmat_neuron_name)
# Out:
# split_index is [0, 18389, 21011, 36853, 39210, 50523, 52507, 59474, 61890, 69887, 71695, 110072]
# row_index is 0
# split_index is [0, 2, 2, 185, 570, 1208, 1209, 1216, 1229, 1241, 1242, 1346]
# row_index is 0
# split_index is [0, 226554, 275286, 538878, 587470, 813179, 860458, 1056488, 1109470, 1340235, 1393971, 2588789]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# split_index is [0, 176463, 223495, 446725, 488531, 645344, 689734, 839722, 894845, 1105759, 1162735, 2163890]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# split_index is [0, 167497, 210885, 423512, 462153, 628512, 668943, 815144, 860139, 1048848, 1093580, 2056818]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# split_index is [0, 174964, 219579, 426634, 467204, 625024, 667331, 810975, 858317, 1024325, 1069139, 2006659]
# row_index is 0
# row_index is 1
# row_index is 2
# split_index is [0, 9550, 10379, 20253, 21009, 31421, 32588, 43226, 44585, 57592, 58834, 109008]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# split_index is [0, 22636, 25634, 48510, 50564, 74774, 76836, 102068, 103794, 132531, 136785, 254453]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# row_index is 56
# row_index is 57
# row_index is 58
# row_index is 59
# row_index is 60
# row_index is 61
# row_index is 62
# split_index is [0, 188249, 232837, 453251, 495230, 668880, 711260, 869641, 915726, 1106433, 1157847, 2186323]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3

# %% [markdown]
# ### The code below is just for test purpose, do not run it

# %%
# spike_clusters = np.load("spike_clusters.npy")
# spike_times = np.load("spike_times.npy")
# set_neuron = set(spike_clusters)
# for neuron_x in set_neuron:
#     neuron_x_index =  [i for i,d in enumerate(spike_clusters) if d==neuron_x]
#     spike_times = spike_times.flatten()
#     neuron_x_map = (np.array([spike_times[index] for index in neuron_x_index])/750).astype(int)
#     neuron_x_map

# (np.array(spike_time_17)/750)[1]
