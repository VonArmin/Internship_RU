# %%
from actmat_generate import *
import os
import pandas as pd

# %% [markdown]
# ### Run the following script to generate actmat matrix
#
# - Change the path into the folder where you put the Trial_durations.xls file
# - Çhange the date into actual date performing the experiment

# %%
# path = "D:\Internship_Radbound\Cell_assembly_yuqin"
path = "/media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged"
date = "Rat6_SD8_OR"
project_folder_name = "RGS_PROJECT_RGS14_OR_Rn6_SD8"

# %%
os.chdir(path)
trial_info = pd.read_excel('Trial_durations.xls', index_col = 0)  
final_samples = trial_info["Post_Trial5"]["Cumulative Samples"]
samples_index_list = list(trial_info.loc["Cumulative Samples"])
fs = 30000
#Modified the minutes and samples by removing the tail
trial_info.loc["modified_minutes"] = [45.0, 5.0, 45.0, 5.0, 45.0, 5.0, 45.0, 5.0, 45.0, 5.0, 180.0]
trial_info.loc["modified_samples"] = trial_info.loc["modified_minutes"]* 60 * 30000

# %% [markdown]
# ### Change:
#
# - absolute_path_list
# - trial_name_list
# - project_folder_name

# %%
absolute_path_list = [path + "/cortex/Tetrode_6/phy_AGR",
                     path + "/cortex/Tetrode_7/phy_MS4",
                     path + "/cortex/Tetrode_8/phy_MS4",
                     path + "/cortex/Tetrode_9/phy_MS4",
                     path + "/cortex/Tetrode_10/phy_MS4",
                     path + "/cortex/Tetrode_11/phy_AGR",
                     path + "/cortex/Tetrode_12/phy_AGR",
                    path + "/cortex/Tetrode_13/phy_AGR",
                     path + "/cortex/Tetrode_14/phy_MS4",
                     path + "/cortex/Tetrode_15/phy_MS4"]
trial_name_list = list(trial_info.columns)

# %%
# get_neuron_name(trial_info, absolute_path_list, trial_name_list[0], project_folder_name)

# %%
for trial_name in trial_name_list:
    createFolder(path + '/' + date)
    final_matrix = iterate_all_file_for_a_trial(trial_info, absolute_path_list, trial_name, project_folder_name)
    createFolder(path + '/' + date)
    np.save(trial_name + "_actmat", final_matrix)
# Out:
# trial name isPre_Sleep
# split_index is [0, 106001, 107013, 111125, 112104, 117423, 119028, 645830, 721424, 897370, 915125, 957396]
# row_index is 0
# row_index is 1
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_7/phy_MS4
# split_index is [0, 249144, 281472, 503572, 537046, 729630, 766870, 941984, 972532, 1156648, 1195589, 1895274]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_8/phy_MS4
# split_index is [0, 191328, 216490, 367476, 394371, 506311, 536711, 667931, 696636, 827673, 859352, 1345314]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_9/phy_MS4
# split_index is [0, 372070, 422022, 742879, 789821, 1055668, 1101338, 1341671, 1378845, 1616878, 1655106, 2642356]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 180202, 205199, 386928, 415817, 560593, 594855, 722317, 752096, 886965, 914695, 1429664]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 83755, 93473, 160932, 170076, 227062, 233858, 279904, 287329, 338022, 346093, 563388]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 19087, 21180, 41469, 43275, 61051, 63017, 78238, 80419, 95170, 96965, 164530]
# row_index is 0
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 104520, 117207, 214637, 228645, 295664, 310546, 381070, 394345, 470820, 486221, 776609]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_14/phy_MS4
# split_index is [0, 283061, 318128, 545079, 576692, 755561, 789092, 948795, 990165, 1186608, 1229430, 1901679]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 285930, 321362, 563863, 603286, 800202, 838656, 1045339, 1089924, 1346925, 1381279, 1958655]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# trial name isTrial1
# split_index is [0, 106001, 107013, 111125, 112104, 117423, 119028, 645830, 721424, 897370, 915125, 957396]
# row_index is 0
# row_index is 1
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_7/phy_MS4
# split_index is [0, 249144, 281472, 503572, 537046, 729630, 766870, 941984, 972532, 1156648, 1195589, 1895274]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_8/phy_MS4
# split_index is [0, 191328, 216490, 367476, 394371, 506311, 536711, 667931, 696636, 827673, 859352, 1345314]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_9/phy_MS4
# split_index is [0, 372070, 422022, 742879, 789821, 1055668, 1101338, 1341671, 1378845, 1616878, 1655106, 2642356]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 180202, 205199, 386928, 415817, 560593, 594855, 722317, 752096, 886965, 914695, 1429664]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 83755, 93473, 160932, 170076, 227062, 233858, 279904, 287329, 338022, 346093, 563388]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 19087, 21180, 41469, 43275, 61051, 63017, 78238, 80419, 95170, 96965, 164530]
# row_index is 0
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 104520, 117207, 214637, 228645, 295664, 310546, 381070, 394345, 470820, 486221, 776609]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_14/phy_MS4
# split_index is [0, 283061, 318128, 545079, 576692, 755561, 789092, 948795, 990165, 1186608, 1229430, 1901679]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 285930, 321362, 563863, 603286, 800202, 838656, 1045339, 1089924, 1346925, 1381279, 1958655]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# trial name isPost_Trial1
# split_index is [0, 106001, 107013, 111125, 112104, 117423, 119028, 645830, 721424, 897370, 915125, 957396]
# row_index is 0
# row_index is 1
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_7/phy_MS4
# split_index is [0, 249144, 281472, 503572, 537046, 729630, 766870, 941984, 972532, 1156648, 1195589, 1895274]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_8/phy_MS4
# split_index is [0, 191328, 216490, 367476, 394371, 506311, 536711, 667931, 696636, 827673, 859352, 1345314]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_9/phy_MS4
# split_index is [0, 372070, 422022, 742879, 789821, 1055668, 1101338, 1341671, 1378845, 1616878, 1655106, 2642356]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 180202, 205199, 386928, 415817, 560593, 594855, 722317, 752096, 886965, 914695, 1429664]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 83755, 93473, 160932, 170076, 227062, 233858, 279904, 287329, 338022, 346093, 563388]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 19087, 21180, 41469, 43275, 61051, 63017, 78238, 80419, 95170, 96965, 164530]
# row_index is 0
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 104520, 117207, 214637, 228645, 295664, 310546, 381070, 394345, 470820, 486221, 776609]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_14/phy_MS4
# split_index is [0, 283061, 318128, 545079, 576692, 755561, 789092, 948795, 990165, 1186608, 1229430, 1901679]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 285930, 321362, 563863, 603286, 800202, 838656, 1045339, 1089924, 1346925, 1381279, 1958655]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# trial name isTrial2
# split_index is [0, 106001, 107013, 111125, 112104, 117423, 119028, 645830, 721424, 897370, 915125, 957396]
# row_index is 0
# row_index is 1
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_7/phy_MS4
# split_index is [0, 249144, 281472, 503572, 537046, 729630, 766870, 941984, 972532, 1156648, 1195589, 1895274]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_8/phy_MS4
# split_index is [0, 191328, 216490, 367476, 394371, 506311, 536711, 667931, 696636, 827673, 859352, 1345314]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_9/phy_MS4
# split_index is [0, 372070, 422022, 742879, 789821, 1055668, 1101338, 1341671, 1378845, 1616878, 1655106, 2642356]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 180202, 205199, 386928, 415817, 560593, 594855, 722317, 752096, 886965, 914695, 1429664]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 83755, 93473, 160932, 170076, 227062, 233858, 279904, 287329, 338022, 346093, 563388]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 19087, 21180, 41469, 43275, 61051, 63017, 78238, 80419, 95170, 96965, 164530]
# row_index is 0
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 104520, 117207, 214637, 228645, 295664, 310546, 381070, 394345, 470820, 486221, 776609]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_14/phy_MS4
# split_index is [0, 283061, 318128, 545079, 576692, 755561, 789092, 948795, 990165, 1186608, 1229430, 1901679]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 285930, 321362, 563863, 603286, 800202, 838656, 1045339, 1089924, 1346925, 1381279, 1958655]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# trial name isPost_Trial2
# split_index is [0, 106001, 107013, 111125, 112104, 117423, 119028, 645830, 721424, 897370, 915125, 957396]
# row_index is 0
# row_index is 1
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_7/phy_MS4
# split_index is [0, 249144, 281472, 503572, 537046, 729630, 766870, 941984, 972532, 1156648, 1195589, 1895274]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_8/phy_MS4
# split_index is [0, 191328, 216490, 367476, 394371, 506311, 536711, 667931, 696636, 827673, 859352, 1345314]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_9/phy_MS4
# split_index is [0, 372070, 422022, 742879, 789821, 1055668, 1101338, 1341671, 1378845, 1616878, 1655106, 2642356]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 180202, 205199, 386928, 415817, 560593, 594855, 722317, 752096, 886965, 914695, 1429664]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 83755, 93473, 160932, 170076, 227062, 233858, 279904, 287329, 338022, 346093, 563388]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 19087, 21180, 41469, 43275, 61051, 63017, 78238, 80419, 95170, 96965, 164530]
# row_index is 0
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 104520, 117207, 214637, 228645, 295664, 310546, 381070, 394345, 470820, 486221, 776609]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_14/phy_MS4
# split_index is [0, 283061, 318128, 545079, 576692, 755561, 789092, 948795, 990165, 1186608, 1229430, 1901679]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 285930, 321362, 563863, 603286, 800202, 838656, 1045339, 1089924, 1346925, 1381279, 1958655]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# trial name isTrial3
# split_index is [0, 106001, 107013, 111125, 112104, 117423, 119028, 645830, 721424, 897370, 915125, 957396]
# row_index is 0
# row_index is 1
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_7/phy_MS4
# split_index is [0, 249144, 281472, 503572, 537046, 729630, 766870, 941984, 972532, 1156648, 1195589, 1895274]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_8/phy_MS4
# split_index is [0, 191328, 216490, 367476, 394371, 506311, 536711, 667931, 696636, 827673, 859352, 1345314]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_9/phy_MS4
# split_index is [0, 372070, 422022, 742879, 789821, 1055668, 1101338, 1341671, 1378845, 1616878, 1655106, 2642356]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 180202, 205199, 386928, 415817, 560593, 594855, 722317, 752096, 886965, 914695, 1429664]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 83755, 93473, 160932, 170076, 227062, 233858, 279904, 287329, 338022, 346093, 563388]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 19087, 21180, 41469, 43275, 61051, 63017, 78238, 80419, 95170, 96965, 164530]
# row_index is 0
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 104520, 117207, 214637, 228645, 295664, 310546, 381070, 394345, 470820, 486221, 776609]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_14/phy_MS4
# split_index is [0, 283061, 318128, 545079, 576692, 755561, 789092, 948795, 990165, 1186608, 1229430, 1901679]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 285930, 321362, 563863, 603286, 800202, 838656, 1045339, 1089924, 1346925, 1381279, 1958655]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# trial name isPost_Trial3
# split_index is [0, 106001, 107013, 111125, 112104, 117423, 119028, 645830, 721424, 897370, 915125, 957396]
# row_index is 0
# row_index is 1
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_7/phy_MS4
# split_index is [0, 249144, 281472, 503572, 537046, 729630, 766870, 941984, 972532, 1156648, 1195589, 1895274]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_8/phy_MS4
# split_index is [0, 191328, 216490, 367476, 394371, 506311, 536711, 667931, 696636, 827673, 859352, 1345314]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_9/phy_MS4
# split_index is [0, 372070, 422022, 742879, 789821, 1055668, 1101338, 1341671, 1378845, 1616878, 1655106, 2642356]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 180202, 205199, 386928, 415817, 560593, 594855, 722317, 752096, 886965, 914695, 1429664]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 83755, 93473, 160932, 170076, 227062, 233858, 279904, 287329, 338022, 346093, 563388]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 19087, 21180, 41469, 43275, 61051, 63017, 78238, 80419, 95170, 96965, 164530]
# row_index is 0
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 104520, 117207, 214637, 228645, 295664, 310546, 381070, 394345, 470820, 486221, 776609]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_14/phy_MS4
# split_index is [0, 283061, 318128, 545079, 576692, 755561, 789092, 948795, 990165, 1186608, 1229430, 1901679]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 285930, 321362, 563863, 603286, 800202, 838656, 1045339, 1089924, 1346925, 1381279, 1958655]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# trial name isTrial4
# split_index is [0, 106001, 107013, 111125, 112104, 117423, 119028, 645830, 721424, 897370, 915125, 957396]
# row_index is 0
# row_index is 1
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_7/phy_MS4
# split_index is [0, 249144, 281472, 503572, 537046, 729630, 766870, 941984, 972532, 1156648, 1195589, 1895274]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_8/phy_MS4
# split_index is [0, 191328, 216490, 367476, 394371, 506311, 536711, 667931, 696636, 827673, 859352, 1345314]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_9/phy_MS4
# split_index is [0, 372070, 422022, 742879, 789821, 1055668, 1101338, 1341671, 1378845, 1616878, 1655106, 2642356]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 180202, 205199, 386928, 415817, 560593, 594855, 722317, 752096, 886965, 914695, 1429664]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 83755, 93473, 160932, 170076, 227062, 233858, 279904, 287329, 338022, 346093, 563388]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 19087, 21180, 41469, 43275, 61051, 63017, 78238, 80419, 95170, 96965, 164530]
# row_index is 0
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 104520, 117207, 214637, 228645, 295664, 310546, 381070, 394345, 470820, 486221, 776609]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_14/phy_MS4
# split_index is [0, 283061, 318128, 545079, 576692, 755561, 789092, 948795, 990165, 1186608, 1229430, 1901679]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 285930, 321362, 563863, 603286, 800202, 838656, 1045339, 1089924, 1346925, 1381279, 1958655]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# trial name isPost_Trial4
# split_index is [0, 106001, 107013, 111125, 112104, 117423, 119028, 645830, 721424, 897370, 915125, 957396]
# row_index is 0
# row_index is 1
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_7/phy_MS4
# split_index is [0, 249144, 281472, 503572, 537046, 729630, 766870, 941984, 972532, 1156648, 1195589, 1895274]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_8/phy_MS4
# split_index is [0, 191328, 216490, 367476, 394371, 506311, 536711, 667931, 696636, 827673, 859352, 1345314]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_9/phy_MS4
# split_index is [0, 372070, 422022, 742879, 789821, 1055668, 1101338, 1341671, 1378845, 1616878, 1655106, 2642356]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 180202, 205199, 386928, 415817, 560593, 594855, 722317, 752096, 886965, 914695, 1429664]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 83755, 93473, 160932, 170076, 227062, 233858, 279904, 287329, 338022, 346093, 563388]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 19087, 21180, 41469, 43275, 61051, 63017, 78238, 80419, 95170, 96965, 164530]
# row_index is 0
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 104520, 117207, 214637, 228645, 295664, 310546, 381070, 394345, 470820, 486221, 776609]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_14/phy_MS4
# split_index is [0, 283061, 318128, 545079, 576692, 755561, 789092, 948795, 990165, 1186608, 1229430, 1901679]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 285930, 321362, 563863, 603286, 800202, 838656, 1045339, 1089924, 1346925, 1381279, 1958655]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# trial name isTrial5
# split_index is [0, 106001, 107013, 111125, 112104, 117423, 119028, 645830, 721424, 897370, 915125, 957396]
# row_index is 0
# row_index is 1
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_7/phy_MS4
# split_index is [0, 249144, 281472, 503572, 537046, 729630, 766870, 941984, 972532, 1156648, 1195589, 1895274]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_8/phy_MS4
# split_index is [0, 191328, 216490, 367476, 394371, 506311, 536711, 667931, 696636, 827673, 859352, 1345314]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_9/phy_MS4
# split_index is [0, 372070, 422022, 742879, 789821, 1055668, 1101338, 1341671, 1378845, 1616878, 1655106, 2642356]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 180202, 205199, 386928, 415817, 560593, 594855, 722317, 752096, 886965, 914695, 1429664]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 83755, 93473, 160932, 170076, 227062, 233858, 279904, 287329, 338022, 346093, 563388]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 19087, 21180, 41469, 43275, 61051, 63017, 78238, 80419, 95170, 96965, 164530]
# row_index is 0
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 104520, 117207, 214637, 228645, 295664, 310546, 381070, 394345, 470820, 486221, 776609]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_14/phy_MS4
# split_index is [0, 283061, 318128, 545079, 576692, 755561, 789092, 948795, 990165, 1186608, 1229430, 1901679]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 285930, 321362, 563863, 603286, 800202, 838656, 1045339, 1089924, 1346925, 1381279, 1958655]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# trial name isPost_Trial5
# split_index is [0, 106001, 107013, 111125, 112104, 117423, 119028, 645830, 721424, 897370, 915125, 957396]
# row_index is 0
# row_index is 1
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_7/phy_MS4
# split_index is [0, 249144, 281472, 503572, 537046, 729630, 766870, 941984, 972532, 1156648, 1195589, 1895274]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_8/phy_MS4
# split_index is [0, 191328, 216490, 367476, 394371, 506311, 536711, 667931, 696636, 827673, 859352, 1345314]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_9/phy_MS4
# split_index is [0, 372070, 422022, 742879, 789821, 1055668, 1101338, 1341671, 1378845, 1616878, 1655106, 2642356]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 180202, 205199, 386928, 415817, 560593, 594855, 722317, 752096, 886965, 914695, 1429664]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 83755, 93473, 160932, 170076, 227062, 233858, 279904, 287329, 338022, 346093, 563388]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 19087, 21180, 41469, 43275, 61051, 63017, 78238, 80419, 95170, 96965, 164530]
# row_index is 0
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 104520, 117207, 214637, 228645, 295664, 310546, 381070, 394345, 470820, 486221, 776609]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_14/phy_MS4
# split_index is [0, 283061, 318128, 545079, 576692, 755561, 789092, 948795, 990165, 1186608, 1229430, 1901679]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# /media/irene/MD04_RAT_THETA/Spike_sorting/Rat_OS_Ephys_RGS14_rat6_373726/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020/Rat_OS_Ephys_RGS14_rat6_373726_SD8_OR_02-03_03_2020_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 285930, 321362, 563863, 603286, 800202, 838656, 1045339, 1089924, 1346925, 1381279, 1958655]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12

# %%
actmat_neuron_name = get_neuron_name(trial_info, absolute_path_list, trial_name_list[0], project_folder_name )
createFolder(path + '/' + date)
np.save("actmat_neuron_name", actmat_neuron_name)
# Out:
# split_index is [0, 106001, 107013, 111125, 112104, 117423, 119028, 645830, 721424, 897370, 915125, 957396]
# row_index is 0
# row_index is 1
# split_index is [0, 249144, 281472, 503572, 537046, 729630, 766870, 941984, 972532, 1156648, 1195589, 1895274]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# split_index is [0, 191328, 216490, 367476, 394371, 506311, 536711, 667931, 696636, 827673, 859352, 1345314]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# split_index is [0, 372070, 422022, 742879, 789821, 1055668, 1101338, 1341671, 1378845, 1616878, 1655106, 2642356]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# split_index is [0, 180202, 205199, 386928, 415817, 560593, 594855, 722317, 752096, 886965, 914695, 1429664]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# split_index is [0, 83755, 93473, 160932, 170076, 227062, 233858, 279904, 287329, 338022, 346093, 563388]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# split_index is [0, 19087, 21180, 41469, 43275, 61051, 63017, 78238, 80419, 95170, 96965, 164530]
# row_index is 0
# split_index is [0, 104520, 117207, 214637, 228645, 295664, 310546, 381070, 394345, 470820, 486221, 776609]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# split_index is [0, 283061, 318128, 545079, 576692, 755561, 789092, 948795, 990165, 1186608, 1229430, 1901679]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# split_index is [0, 285930, 321362, 563863, 603286, 800202, 838656, 1045339, 1089924, 1346925, 1381279, 1958655]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12

# %% [markdown]
# ### The code below is just for test purpose, do not run it

# %%
# spike_clusters = np.load("spike_clusters.npy")
# spike_times = np.load("spike_times.npy")
# set_neuron = set(spike_clusters)
# for neuron_x in set_neuron:
#     neuron_x_index =  [i for i,d in enumerate(spike_clusters) if d==neuron_x]
#     spike_times = spike_times.flatten()
#     neuron_x_map = (np.array([spike_times[index] for index in neuron_x_index])/750).astype(int)
#     neuron_x_map

# (np.array(spike_time_17)/750)[1]
