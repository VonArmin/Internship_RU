# %%
from actmat_generate import *
import os
import pandas as pd

# %% [markdown]
# ### Run the following script to generate actmat matrix
#
# - Change the path into the folder where you put the Trial_durations.xls file
# - Çhange the date into actual date performing the experiment

# %%
# path = "D:\Internship_Radbound\Cell_assembly_yuqin"
path = "/media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD3_OR_27-28_04_2020/OS_Ephys_RGS14_Rat8_378133_SD3_OR_27-28_04_2020_merged"
date = "Rat8_SD3_OR"
project_folder_name = "RGS_PROJECT_RGS14_PFC_Rn8_OR_SD3"

# %%
trial_info
# Out:
#                     Pre_sleep_truncated        Trial1   Post_Trial1  \
# Unit
# Samples                    8.108032e+07  9.833472e+06  8.101274e+07
# Cumulative Samples         8.108032e+07  9.091379e+07  1.719265e+08
# Seconds                    2.702677e+03  3.277824e+02  2.700425e+03
# Cumulative Seconds         2.702677e+03  3.030460e+03  5.730884e+03
# Minutes                    4.504462e+01  5.463040e+00  4.500708e+01
# Cumulative Minutes         4.504462e+01  5.050766e+01  9.551474e+01
# Hours                      7.507437e-01  9.105067e-02  7.501179e-01
# Cumulative Hours           7.507437e-01  8.417944e-01  1.591912e+00
#
#                           Trial2   Post_Trial2        Trial3   Post_Trial3  \
# Unit
# Samples             9.671680e+06  8.102093e+07  9.728000e+06  8.104755e+07
# Cumulative Samples  1.815982e+08  2.626191e+08  2.723471e+08  3.533947e+08
# Seconds             3.223893e+02  2.700698e+03  3.242667e+02  2.701585e+03
# Cumulative Seconds  6.053274e+03  8.753971e+03  9.078238e+03  1.177982e+04
# Minutes             5.373156e+00  4.501163e+01  5.404444e+00  4.502642e+01
# Cumulative Minutes  1.008879e+02  1.458995e+02  1.513040e+02  1.963304e+02
# Hours               8.955259e-02  7.501938e-01  9.007407e-02  7.504403e-01
# Cumulative Hours    1.681465e+00  2.431659e+00  2.521733e+00  3.272173e+00
#
#                           Trial4   Post_Trial4        Trial5   Post_Trial5  \
# Unit
# Samples             9.849856e+06  8.100762e+07  1.027482e+07  2.284278e+08
# Cumulative Samples  3.632445e+08  4.442522e+08  4.545270e+08  6.829548e+08
# Seconds             3.283285e+02  2.700254e+03  3.424939e+02  7.614259e+03
# Cumulative Seconds  1.210815e+04  1.480841e+04  1.515090e+04  2.276516e+04
# Minutes             5.472142e+00  4.500423e+01  5.708231e+00  1.269043e+02
# Cumulative Minutes  2.018025e+02  2.468068e+02  2.525150e+02  3.794193e+02
# Hours               9.120237e-02  7.500705e-01  9.513719e-02  2.115072e+00
# Cumulative Hours    3.363375e+00  4.113446e+00  4.208583e+00  6.323655e+00
#
#                     Post_Trial5_2
# Unit
# Samples              5.536358e+07
# Cumulative Samples   7.383183e+08
# Seconds              1.845453e+03
# Cumulative Seconds   2.461061e+04
# Minutes              3.075755e+01
# Cumulative Minutes   4.101769e+02
# Hours                5.126258e-01
# Cumulative Hours     6.836281e+00

# %%
os.chdir(path)
trial_info = pd.read_excel('Trial_durations.xls', index_col = 0)  
trial_last_period_name = trial_info.columns[-1]
final_samples = trial_info[trial_last_period_name]["Cumulative Samples"]
samples_index_list = list(trial_info.loc["Cumulative Samples"])
fs = 30000
#Modified the minutes and samples by removing the tail
trial_info.loc["modified_minutes"] = [45.0, 5.0, 45.0, 5.0, 45.0, 5.0, 45.0, 5.0, 45.0, 5.0, 180.0]
trial_info.loc["modified_samples"] = trial_info.loc["modified_minutes"]* 60 * 30000
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-f5c758562c42> in <module>
#       6 fs = 30000
#       7 #Modified the minutes and samples by removing the tail
# ----> 8 trial_info.loc["modified_minutes"] = [45.0, 5.0, 45.0, 5.0, 45.0, 5.0, 45.0, 5.0, 45.0, 5.0, 180.0]
#       9 trial_info.loc["modified_samples"] = trial_info.loc["modified_minutes"]* 60 * 30000
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     690
#     691         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 692         iloc._setitem_with_indexer(indexer, value, self.name)
#     693
#     694     def _validate_key(self, key, axis: int):
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1627
#    1628             if missing:
# -> 1629                 self._setitem_with_indexer_missing(indexer, value)
#    1630                 return
#    1631
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexing.py in _setitem_with_indexer_missing(self, indexer, value)
#    1916                     # must have conforming columns
#    1917                     if len(value) != len(self.obj.columns):
# -> 1918                         raise ValueError("cannot set a row with mismatched columns")
#    1919
#    1920                 value = Series(value, index=self.obj.columns, name=indexer)
#
# ValueError: cannot set a row with mismatched columns

# %% [markdown]
# ### Change:
#
# - absolute_path_list
# - trial_name_list
# - project_folder_name

# %%
absolute_path_list = [path + "/cortex/Tetrode_6/phy_MS4",
                     path + "/cortex/Tetrode_7/phy_AGR",
                     path + "/cortex/Tetrode_8/phy_MS4",
                     path + "/cortex/Tetrode_9/phy_AGR",
                      path + "/cortex/Tetrode_10/phy_AGR",
                     path + "/cortex/Tetrode_11/phy_AGR",
                     path + "/cortex/Tetrode_12/phy_AGR",
                     path + "/cortex/Tetrode_13/phy_AGR",
                      path + "/cortex/Tetrode_14/phy_AGR",
                     path + "/cortex/Tetrode_15/phy_AGR"]
trial_name_list = list(trial_info.columns)

# %%
# get_neuron_name(trial_info, absolute_path_list, trial_name_list[0], project_folder_name)

# %%
for trial_name in trial_name_list:
    createFolder(path + '/' + date)
    final_matrix = iterate_all_file_for_a_trial(trial_info, absolute_path_list, trial_name, project_folder_name)
    createFolder(path + '/' + date)
    np.save(trial_name + "_actmat", final_matrix)
# Out:
# trial name isPre_sleep
# split_index is [0, 235772, 274651, 436285, 468620, 642170, 678418, 833132, 865817, 986413, 1011572, 1737360]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_7/phy_AGR
# split_index is [0, 3885, 5453, 10653, 12048, 16315, 17218, 20538, 21261, 24515, 25079, 35575]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_8/phy_MS4
# split_index is [0, 256754, 299751, 496273, 536324, 730296, 770234, 950287, 993532, 1144877, 1173890, 2428360]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_9/phy_AGR
# split_index is [0, 14427, 16235, 30592, 32662, 48300, 50455, 64528, 66646, 80713, 82849, 138823]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# row_index is 56
# row_index is 57
# row_index is 58
# row_index is 59
# row_index is 60
# row_index is 61
# row_index is 62
# row_index is 63
# row_index is 64
# row_index is 65
# row_index is 66
# row_index is 67
# row_index is 68
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_10/phy_AGR
# split_index is [0, 3931, 4533, 9013, 9843, 14715, 15374, 19577, 20271, 24111, 25003, 41178]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 3375, 4099, 8586, 9489, 14993, 15980, 20740, 21796, 27169, 28159, 51290]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 197, 208, 317, 380, 726, 944, 1039, 1189, 1290, 1572, 2600]
# row_index is 0
# row_index is 1
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 50095, 53179, 96385, 100106, 135937, 139032, 165649, 169277, 191797, 195132, 342628]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 175, 185, 236, 276, 453, 558, 617, 722, 793, 942, 1497]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_15/phy_AGR
# split_index is [0, 132, 334, 599, 631, 30087, 33286, 53244, 53280, 53317, 53373, 57640]
# row_index is 0
# row_index is 1
# trial name isTrial1
# split_index is [0, 235772, 274651, 436285, 468620, 642170, 678418, 833132, 865817, 986413, 1011572, 1737360]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_7/phy_AGR
# split_index is [0, 3885, 5453, 10653, 12048, 16315, 17218, 20538, 21261, 24515, 25079, 35575]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_8/phy_MS4
# split_index is [0, 256754, 299751, 496273, 536324, 730296, 770234, 950287, 993532, 1144877, 1173890, 2428360]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_9/phy_AGR
# split_index is [0, 14427, 16235, 30592, 32662, 48300, 50455, 64528, 66646, 80713, 82849, 138823]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# row_index is 56
# row_index is 57
# row_index is 58
# row_index is 59
# row_index is 60
# row_index is 61
# row_index is 62
# row_index is 63
# row_index is 64
# row_index is 65
# row_index is 66
# row_index is 67
# row_index is 68
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_10/phy_AGR
# split_index is [0, 3931, 4533, 9013, 9843, 14715, 15374, 19577, 20271, 24111, 25003, 41178]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 3375, 4099, 8586, 9489, 14993, 15980, 20740, 21796, 27169, 28159, 51290]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 197, 208, 317, 380, 726, 944, 1039, 1189, 1290, 1572, 2600]
# row_index is 0
# row_index is 1
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 50095, 53179, 96385, 100106, 135937, 139032, 165649, 169277, 191797, 195132, 342628]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 175, 185, 236, 276, 453, 558, 617, 722, 793, 942, 1497]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_15/phy_AGR
# split_index is [0, 132, 334, 599, 631, 30087, 33286, 53244, 53280, 53317, 53373, 57640]
# row_index is 0
# row_index is 1
# trial name isPost_Trial1
# split_index is [0, 235772, 274651, 436285, 468620, 642170, 678418, 833132, 865817, 986413, 1011572, 1737360]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_7/phy_AGR
# split_index is [0, 3885, 5453, 10653, 12048, 16315, 17218, 20538, 21261, 24515, 25079, 35575]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_8/phy_MS4
# split_index is [0, 256754, 299751, 496273, 536324, 730296, 770234, 950287, 993532, 1144877, 1173890, 2428360]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_9/phy_AGR
# split_index is [0, 14427, 16235, 30592, 32662, 48300, 50455, 64528, 66646, 80713, 82849, 138823]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# row_index is 56
# row_index is 57
# row_index is 58
# row_index is 59
# row_index is 60
# row_index is 61
# row_index is 62
# row_index is 63
# row_index is 64
# row_index is 65
# row_index is 66
# row_index is 67
# row_index is 68
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_10/phy_AGR
# split_index is [0, 3931, 4533, 9013, 9843, 14715, 15374, 19577, 20271, 24111, 25003, 41178]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 3375, 4099, 8586, 9489, 14993, 15980, 20740, 21796, 27169, 28159, 51290]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 197, 208, 317, 380, 726, 944, 1039, 1189, 1290, 1572, 2600]
# row_index is 0
# row_index is 1
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 50095, 53179, 96385, 100106, 135937, 139032, 165649, 169277, 191797, 195132, 342628]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 175, 185, 236, 276, 453, 558, 617, 722, 793, 942, 1497]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_15/phy_AGR
# split_index is [0, 132, 334, 599, 631, 30087, 33286, 53244, 53280, 53317, 53373, 57640]
# row_index is 0
# row_index is 1
# trial name isTrial2
# split_index is [0, 235772, 274651, 436285, 468620, 642170, 678418, 833132, 865817, 986413, 1011572, 1737360]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_7/phy_AGR
# split_index is [0, 3885, 5453, 10653, 12048, 16315, 17218, 20538, 21261, 24515, 25079, 35575]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_8/phy_MS4
# split_index is [0, 256754, 299751, 496273, 536324, 730296, 770234, 950287, 993532, 1144877, 1173890, 2428360]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_9/phy_AGR
# split_index is [0, 14427, 16235, 30592, 32662, 48300, 50455, 64528, 66646, 80713, 82849, 138823]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# row_index is 56
# row_index is 57
# row_index is 58
# row_index is 59
# row_index is 60
# row_index is 61
# row_index is 62
# row_index is 63
# row_index is 64
# row_index is 65
# row_index is 66
# row_index is 67
# row_index is 68
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_10/phy_AGR
# split_index is [0, 3931, 4533, 9013, 9843, 14715, 15374, 19577, 20271, 24111, 25003, 41178]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 3375, 4099, 8586, 9489, 14993, 15980, 20740, 21796, 27169, 28159, 51290]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 197, 208, 317, 380, 726, 944, 1039, 1189, 1290, 1572, 2600]
# row_index is 0
# row_index is 1
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 50095, 53179, 96385, 100106, 135937, 139032, 165649, 169277, 191797, 195132, 342628]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 175, 185, 236, 276, 453, 558, 617, 722, 793, 942, 1497]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_15/phy_AGR
# split_index is [0, 132, 334, 599, 631, 30087, 33286, 53244, 53280, 53317, 53373, 57640]
# row_index is 0
# row_index is 1
# trial name isPost_Trial2
# split_index is [0, 235772, 274651, 436285, 468620, 642170, 678418, 833132, 865817, 986413, 1011572, 1737360]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_7/phy_AGR
# split_index is [0, 3885, 5453, 10653, 12048, 16315, 17218, 20538, 21261, 24515, 25079, 35575]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_8/phy_MS4
# split_index is [0, 256754, 299751, 496273, 536324, 730296, 770234, 950287, 993532, 1144877, 1173890, 2428360]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_9/phy_AGR
# split_index is [0, 14427, 16235, 30592, 32662, 48300, 50455, 64528, 66646, 80713, 82849, 138823]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# row_index is 56
# row_index is 57
# row_index is 58
# row_index is 59
# row_index is 60
# row_index is 61
# row_index is 62
# row_index is 63
# row_index is 64
# row_index is 65
# row_index is 66
# row_index is 67
# row_index is 68
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_10/phy_AGR
# split_index is [0, 3931, 4533, 9013, 9843, 14715, 15374, 19577, 20271, 24111, 25003, 41178]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 3375, 4099, 8586, 9489, 14993, 15980, 20740, 21796, 27169, 28159, 51290]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 197, 208, 317, 380, 726, 944, 1039, 1189, 1290, 1572, 2600]
# row_index is 0
# row_index is 1
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 50095, 53179, 96385, 100106, 135937, 139032, 165649, 169277, 191797, 195132, 342628]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 175, 185, 236, 276, 453, 558, 617, 722, 793, 942, 1497]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_15/phy_AGR
# split_index is [0, 132, 334, 599, 631, 30087, 33286, 53244, 53280, 53317, 53373, 57640]
# row_index is 0
# row_index is 1
# trial name isTrial3
# split_index is [0, 235772, 274651, 436285, 468620, 642170, 678418, 833132, 865817, 986413, 1011572, 1737360]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_7/phy_AGR
# split_index is [0, 3885, 5453, 10653, 12048, 16315, 17218, 20538, 21261, 24515, 25079, 35575]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_8/phy_MS4
# split_index is [0, 256754, 299751, 496273, 536324, 730296, 770234, 950287, 993532, 1144877, 1173890, 2428360]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_9/phy_AGR
# split_index is [0, 14427, 16235, 30592, 32662, 48300, 50455, 64528, 66646, 80713, 82849, 138823]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# row_index is 56
# row_index is 57
# row_index is 58
# row_index is 59
# row_index is 60
# row_index is 61
# row_index is 62
# row_index is 63
# row_index is 64
# row_index is 65
# row_index is 66
# row_index is 67
# row_index is 68
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_10/phy_AGR
# split_index is [0, 3931, 4533, 9013, 9843, 14715, 15374, 19577, 20271, 24111, 25003, 41178]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 3375, 4099, 8586, 9489, 14993, 15980, 20740, 21796, 27169, 28159, 51290]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 197, 208, 317, 380, 726, 944, 1039, 1189, 1290, 1572, 2600]
# row_index is 0
# row_index is 1
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 50095, 53179, 96385, 100106, 135937, 139032, 165649, 169277, 191797, 195132, 342628]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 175, 185, 236, 276, 453, 558, 617, 722, 793, 942, 1497]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_15/phy_AGR
# split_index is [0, 132, 334, 599, 631, 30087, 33286, 53244, 53280, 53317, 53373, 57640]
# row_index is 0
# row_index is 1
# trial name isPost_Trial3
# split_index is [0, 235772, 274651, 436285, 468620, 642170, 678418, 833132, 865817, 986413, 1011572, 1737360]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_7/phy_AGR
# split_index is [0, 3885, 5453, 10653, 12048, 16315, 17218, 20538, 21261, 24515, 25079, 35575]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_8/phy_MS4
# split_index is [0, 256754, 299751, 496273, 536324, 730296, 770234, 950287, 993532, 1144877, 1173890, 2428360]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_9/phy_AGR
# split_index is [0, 14427, 16235, 30592, 32662, 48300, 50455, 64528, 66646, 80713, 82849, 138823]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# row_index is 56
# row_index is 57
# row_index is 58
# row_index is 59
# row_index is 60
# row_index is 61
# row_index is 62
# row_index is 63
# row_index is 64
# row_index is 65
# row_index is 66
# row_index is 67
# row_index is 68
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_10/phy_AGR
# split_index is [0, 3931, 4533, 9013, 9843, 14715, 15374, 19577, 20271, 24111, 25003, 41178]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 3375, 4099, 8586, 9489, 14993, 15980, 20740, 21796, 27169, 28159, 51290]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 197, 208, 317, 380, 726, 944, 1039, 1189, 1290, 1572, 2600]
# row_index is 0
# row_index is 1
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 50095, 53179, 96385, 100106, 135937, 139032, 165649, 169277, 191797, 195132, 342628]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 175, 185, 236, 276, 453, 558, 617, 722, 793, 942, 1497]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_15/phy_AGR
# split_index is [0, 132, 334, 599, 631, 30087, 33286, 53244, 53280, 53317, 53373, 57640]
# row_index is 0
# row_index is 1
# trial name isTrial4
# split_index is [0, 235772, 274651, 436285, 468620, 642170, 678418, 833132, 865817, 986413, 1011572, 1737360]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_7/phy_AGR
# split_index is [0, 3885, 5453, 10653, 12048, 16315, 17218, 20538, 21261, 24515, 25079, 35575]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_8/phy_MS4
# split_index is [0, 256754, 299751, 496273, 536324, 730296, 770234, 950287, 993532, 1144877, 1173890, 2428360]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_9/phy_AGR
# split_index is [0, 14427, 16235, 30592, 32662, 48300, 50455, 64528, 66646, 80713, 82849, 138823]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# row_index is 56
# row_index is 57
# row_index is 58
# row_index is 59
# row_index is 60
# row_index is 61
# row_index is 62
# row_index is 63
# row_index is 64
# row_index is 65
# row_index is 66
# row_index is 67
# row_index is 68
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_10/phy_AGR
# split_index is [0, 3931, 4533, 9013, 9843, 14715, 15374, 19577, 20271, 24111, 25003, 41178]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 3375, 4099, 8586, 9489, 14993, 15980, 20740, 21796, 27169, 28159, 51290]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 197, 208, 317, 380, 726, 944, 1039, 1189, 1290, 1572, 2600]
# row_index is 0
# row_index is 1
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 50095, 53179, 96385, 100106, 135937, 139032, 165649, 169277, 191797, 195132, 342628]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 175, 185, 236, 276, 453, 558, 617, 722, 793, 942, 1497]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_15/phy_AGR
# split_index is [0, 132, 334, 599, 631, 30087, 33286, 53244, 53280, 53317, 53373, 57640]
# row_index is 0
# row_index is 1
# trial name isPost_Trial4
# split_index is [0, 235772, 274651, 436285, 468620, 642170, 678418, 833132, 865817, 986413, 1011572, 1737360]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_7/phy_AGR
# split_index is [0, 3885, 5453, 10653, 12048, 16315, 17218, 20538, 21261, 24515, 25079, 35575]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_8/phy_MS4
# split_index is [0, 256754, 299751, 496273, 536324, 730296, 770234, 950287, 993532, 1144877, 1173890, 2428360]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_9/phy_AGR
# split_index is [0, 14427, 16235, 30592, 32662, 48300, 50455, 64528, 66646, 80713, 82849, 138823]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# row_index is 56
# row_index is 57
# row_index is 58
# row_index is 59
# row_index is 60
# row_index is 61
# row_index is 62
# row_index is 63
# row_index is 64
# row_index is 65
# row_index is 66
# row_index is 67
# row_index is 68
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_10/phy_AGR
# split_index is [0, 3931, 4533, 9013, 9843, 14715, 15374, 19577, 20271, 24111, 25003, 41178]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 3375, 4099, 8586, 9489, 14993, 15980, 20740, 21796, 27169, 28159, 51290]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 197, 208, 317, 380, 726, 944, 1039, 1189, 1290, 1572, 2600]
# row_index is 0
# row_index is 1
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 50095, 53179, 96385, 100106, 135937, 139032, 165649, 169277, 191797, 195132, 342628]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 175, 185, 236, 276, 453, 558, 617, 722, 793, 942, 1497]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_15/phy_AGR
# split_index is [0, 132, 334, 599, 631, 30087, 33286, 53244, 53280, 53317, 53373, 57640]
# row_index is 0
# row_index is 1
# trial name isTrial5
# split_index is [0, 235772, 274651, 436285, 468620, 642170, 678418, 833132, 865817, 986413, 1011572, 1737360]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_7/phy_AGR
# split_index is [0, 3885, 5453, 10653, 12048, 16315, 17218, 20538, 21261, 24515, 25079, 35575]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_8/phy_MS4
# split_index is [0, 256754, 299751, 496273, 536324, 730296, 770234, 950287, 993532, 1144877, 1173890, 2428360]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_9/phy_AGR
# split_index is [0, 14427, 16235, 30592, 32662, 48300, 50455, 64528, 66646, 80713, 82849, 138823]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# row_index is 56
# row_index is 57
# row_index is 58
# row_index is 59
# row_index is 60
# row_index is 61
# row_index is 62
# row_index is 63
# row_index is 64
# row_index is 65
# row_index is 66
# row_index is 67
# row_index is 68
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_10/phy_AGR
# split_index is [0, 3931, 4533, 9013, 9843, 14715, 15374, 19577, 20271, 24111, 25003, 41178]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 3375, 4099, 8586, 9489, 14993, 15980, 20740, 21796, 27169, 28159, 51290]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 197, 208, 317, 380, 726, 944, 1039, 1189, 1290, 1572, 2600]
# row_index is 0
# row_index is 1
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 50095, 53179, 96385, 100106, 135937, 139032, 165649, 169277, 191797, 195132, 342628]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 175, 185, 236, 276, 453, 558, 617, 722, 793, 942, 1497]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_15/phy_AGR
# split_index is [0, 132, 334, 599, 631, 30087, 33286, 53244, 53280, 53317, 53373, 57640]
# row_index is 0
# row_index is 1
# trial name isPost_Trial5
# split_index is [0, 235772, 274651, 436285, 468620, 642170, 678418, 833132, 865817, 986413, 1011572, 1737360]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_7/phy_AGR
# split_index is [0, 3885, 5453, 10653, 12048, 16315, 17218, 20538, 21261, 24515, 25079, 35575]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_8/phy_MS4
# split_index is [0, 256754, 299751, 496273, 536324, 730296, 770234, 950287, 993532, 1144877, 1173890, 2428360]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_9/phy_AGR
# split_index is [0, 14427, 16235, 30592, 32662, 48300, 50455, 64528, 66646, 80713, 82849, 138823]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# row_index is 56
# row_index is 57
# row_index is 58
# row_index is 59
# row_index is 60
# row_index is 61
# row_index is 62
# row_index is 63
# row_index is 64
# row_index is 65
# row_index is 66
# row_index is 67
# row_index is 68
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_10/phy_AGR
# split_index is [0, 3931, 4533, 9013, 9843, 14715, 15374, 19577, 20271, 24111, 25003, 41178]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 3375, 4099, 8586, 9489, 14993, 15980, 20740, 21796, 27169, 28159, 51290]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 197, 208, 317, 380, 726, 944, 1039, 1189, 1290, 1572, 2600]
# row_index is 0
# row_index is 1
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 50095, 53179, 96385, 100106, 135937, 139032, 165649, 169277, 191797, 195132, 342628]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 175, 185, 236, 276, 453, 558, 617, 722, 793, 942, 1497]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020/OS_Ephys_RGS14_Rat8_378133_SD2_CON_23-24_04_2020_merged/cortex/Tetrode_15/phy_AGR
# split_index is [0, 132, 334, 599, 631, 30087, 33286, 53244, 53280, 53317, 53373, 57640]
# row_index is 0
# row_index is 1

# %%
actmat_neuron_name = get_neuron_name(trial_info, absolute_path_list, trial_name_list[0], project_folder_name )
createFolder(path + '/' + date)
np.save("actmat_neuron_name", actmat_neuron_name)
# Out:
# split_index is [0, 235772, 274651, 436285, 468620, 642170, 678418, 833132, 865817, 986413, 1011572, 1737360]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# split_index is [0, 3885, 5453, 10653, 12048, 16315, 17218, 20538, 21261, 24515, 25079, 35575]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# split_index is [0, 256754, 299751, 496273, 536324, 730296, 770234, 950287, 993532, 1144877, 1173890, 2428360]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# split_index is [0, 14427, 16235, 30592, 32662, 48300, 50455, 64528, 66646, 80713, 82849, 138823]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# row_index is 56
# row_index is 57
# row_index is 58
# row_index is 59
# row_index is 60
# row_index is 61
# row_index is 62
# row_index is 63
# row_index is 64
# row_index is 65
# row_index is 66
# row_index is 67
# row_index is 68
# split_index is [0, 3931, 4533, 9013, 9843, 14715, 15374, 19577, 20271, 24111, 25003, 41178]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# split_index is [0, 3375, 4099, 8586, 9489, 14993, 15980, 20740, 21796, 27169, 28159, 51290]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# split_index is [0, 197, 208, 317, 380, 726, 944, 1039, 1189, 1290, 1572, 2600]
# row_index is 0
# row_index is 1
# split_index is [0, 50095, 53179, 96385, 100106, 135937, 139032, 165649, 169277, 191797, 195132, 342628]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# split_index is [0, 175, 185, 236, 276, 453, 558, 617, 722, 793, 942, 1497]
# row_index is 0
# split_index is [0, 132, 334, 599, 631, 30087, 33286, 53244, 53280, 53317, 53373, 57640]
# row_index is 0
# row_index is 1

# %% [markdown]
# ### The code below is just for test purpose, do not run it

# %%
# spike_clusters = np.load("spike_clusters.npy")
# spike_times = np.load("spike_times.npy")
# set_neuron = set(spike_clusters)
# for neuron_x in set_neuron:
#     neuron_x_index =  [i for i,d in enumerate(spike_clusters) if d==neuron_x]
#     spike_times = spike_times.flatten()
#     neuron_x_map = (np.array([spike_times[index] for index in neuron_x_index])/750).astype(int)
#     neuron_x_map

# (np.array(spike_time_17)/750)[1]
