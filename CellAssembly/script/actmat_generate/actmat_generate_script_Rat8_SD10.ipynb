# %%
from actmat_generate import *
import os
import pandas as pd

# %% [markdown]
# ### Run the following script to generate actmat matrix
#
# - Change the path into the folder where you put the Trial_durations.xls file
# - Çhange the date into actual date performing the experiment

# %%
# path = "D:\Internship_Radbound\Cell_assembly_yuqin"
path = "/media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged"
date = "Rat8_SD10_HC"
project_folder_name = "RGS_PROJECT_RGS14_PFC_Rn8_HC_SD10"

# %%
os.chdir(path)
trial_info = pd.read_excel('Trial_durations.xls', index_col = 0)  
trial_last_period_name = trial_info.columns[-1]
final_samples = trial_info[trial_last_period_name]["Cumulative Samples"]
samples_index_list = list(trial_info.loc["Cumulative Samples"])
fs = 30000
#Modified the minutes and samples by removing the tail
trial_info.loc["modified_minutes"] = [45.0, 5.0, 45.0, 5.0, 45.0, 5.0, 45.0, 5.0, 45.0, 5.0, 180.0]
trial_info.loc["modified_samples"] = trial_info.loc["modified_minutes"]* 60 * 30000

# %% [markdown]
# ### Change:
#
# - absolute_path_list
# - trial_name_list
# - project_folder_name

# %%
absolute_path_list = [path + "/cortex/Tetrode_6/phy_MS4",
                     path + "/cortex/Tetrode_7/phy_AGR",
                     path + "/cortex/Tetrode_8/phy_AGR",
                     path + "/cortex/Tetrode_9/phy_MS4",
                      path + "/cortex/Tetrode_10/phy_AGR",
                     path + "/cortex/Tetrode_11/phy_AGR",
                     path + "/cortex/Tetrode_12/phy_MS4",
                     path + "/cortex/Tetrode_13/phy_MS4",
                      path + "/cortex/Tetrode_14/phy_AGR",
                     path + "/cortex/Tetrode_15/phy_MS4"]
trial_name_list = list(trial_info.columns)

# %%
# get_neuron_name(trial_info, absolute_path_list, trial_name_list[0], project_folder_name)

# %%
for trial_name in trial_name_list:
    createFolder(path + '/' + date)
    final_matrix = iterate_all_file_for_a_trial(trial_info, absolute_path_list, trial_name, project_folder_name)
    createFolder(path + '/' + date)
    np.save(trial_name + "_actmat", final_matrix)
# Out:
# trial name isPre_sleep_truncated
# split_index is [0, 238204, 266195, 528000, 553978, 768403, 800505, 1026744, 1050828, 1224190, 1249133, 2136195]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_7/phy_AGR
# split_index is [0, 5367, 6778, 12282, 12812, 18166, 18835, 24767, 25507, 30848, 31333, 50390]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_8/phy_AGR
# split_index is [0, 12703, 13921, 21729, 22624, 28967, 31200, 39444, 39445, 41464, 50334, 52980, 88749]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_9/phy_MS4
# split_index is [0, 112438, 124479, 237499, 248188, 344114, 357067, 456295, 466490, 541560, 553553, 1021378]
# row_index is 0
# row_index is 1
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_10/phy_AGR
# split_index is [0, 4117, 4695, 8367, 8822, 13063, 13882, 18686, 19889, 24594, 25344, 41549]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 11023, 13216, 22760, 24608, 32943, 33932, 43978, 46642, 58293, 59565, 115300]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_12/phy_MS4
# split_index is [0, 215034, 238583, 336699, 348510, 487976, 512243, 689602, 701024, 810952, 833208, 1407728]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_13/phy_MS4
# split_index is [0, 231141, 250901, 392343, 416973, 570685, 594697, 731887, 750416, 855016, 874840, 1484989]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 24990, 28596, 50405, 53358, 76013, 77605, 92962, 94895, 112607, 114014, 213120]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 242547, 262817, 412421, 430616, 603935, 629785, 797818, 816463, 962722, 983904, 1688471]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# trial name isTrial1
# split_index is [0, 238204, 266195, 528000, 553978, 768403, 800505, 1026744, 1050828, 1224190, 1249133, 2136195]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_7/phy_AGR
# split_index is [0, 5367, 6778, 12282, 12812, 18166, 18835, 24767, 25507, 30848, 31333, 50390]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_8/phy_AGR
# split_index is [0, 12703, 13921, 21729, 22624, 28967, 31200, 39444, 39445, 41464, 50334, 52980, 88749]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_9/phy_MS4
# split_index is [0, 112438, 124479, 237499, 248188, 344114, 357067, 456295, 466490, 541560, 553553, 1021378]
# row_index is 0
# row_index is 1
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_10/phy_AGR
# split_index is [0, 4117, 4695, 8367, 8822, 13063, 13882, 18686, 19889, 24594, 25344, 41549]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 11023, 13216, 22760, 24608, 32943, 33932, 43978, 46642, 58293, 59565, 115300]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_12/phy_MS4
# split_index is [0, 215034, 238583, 336699, 348510, 487976, 512243, 689602, 701024, 810952, 833208, 1407728]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_13/phy_MS4
# split_index is [0, 231141, 250901, 392343, 416973, 570685, 594697, 731887, 750416, 855016, 874840, 1484989]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 24990, 28596, 50405, 53358, 76013, 77605, 92962, 94895, 112607, 114014, 213120]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 242547, 262817, 412421, 430616, 603935, 629785, 797818, 816463, 962722, 983904, 1688471]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# trial name isPost_Trial1
# split_index is [0, 238204, 266195, 528000, 553978, 768403, 800505, 1026744, 1050828, 1224190, 1249133, 2136195]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_7/phy_AGR
# split_index is [0, 5367, 6778, 12282, 12812, 18166, 18835, 24767, 25507, 30848, 31333, 50390]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_8/phy_AGR
# split_index is [0, 12703, 13921, 21729, 22624, 28967, 31200, 39444, 39445, 41464, 50334, 52980, 88749]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_9/phy_MS4
# split_index is [0, 112438, 124479, 237499, 248188, 344114, 357067, 456295, 466490, 541560, 553553, 1021378]
# row_index is 0
# row_index is 1
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_10/phy_AGR
# split_index is [0, 4117, 4695, 8367, 8822, 13063, 13882, 18686, 19889, 24594, 25344, 41549]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 11023, 13216, 22760, 24608, 32943, 33932, 43978, 46642, 58293, 59565, 115300]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_12/phy_MS4
# split_index is [0, 215034, 238583, 336699, 348510, 487976, 512243, 689602, 701024, 810952, 833208, 1407728]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_13/phy_MS4
# split_index is [0, 231141, 250901, 392343, 416973, 570685, 594697, 731887, 750416, 855016, 874840, 1484989]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 24990, 28596, 50405, 53358, 76013, 77605, 92962, 94895, 112607, 114014, 213120]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 242547, 262817, 412421, 430616, 603935, 629785, 797818, 816463, 962722, 983904, 1688471]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# trial name isTrial2
# split_index is [0, 238204, 266195, 528000, 553978, 768403, 800505, 1026744, 1050828, 1224190, 1249133, 2136195]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_7/phy_AGR
# split_index is [0, 5367, 6778, 12282, 12812, 18166, 18835, 24767, 25507, 30848, 31333, 50390]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_8/phy_AGR
# split_index is [0, 12703, 13921, 21729, 22624, 28967, 31200, 39444, 39445, 41464, 50334, 52980, 88749]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_9/phy_MS4
# split_index is [0, 112438, 124479, 237499, 248188, 344114, 357067, 456295, 466490, 541560, 553553, 1021378]
# row_index is 0
# row_index is 1
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_10/phy_AGR
# split_index is [0, 4117, 4695, 8367, 8822, 13063, 13882, 18686, 19889, 24594, 25344, 41549]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 11023, 13216, 22760, 24608, 32943, 33932, 43978, 46642, 58293, 59565, 115300]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_12/phy_MS4
# split_index is [0, 215034, 238583, 336699, 348510, 487976, 512243, 689602, 701024, 810952, 833208, 1407728]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_13/phy_MS4
# split_index is [0, 231141, 250901, 392343, 416973, 570685, 594697, 731887, 750416, 855016, 874840, 1484989]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 24990, 28596, 50405, 53358, 76013, 77605, 92962, 94895, 112607, 114014, 213120]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 242547, 262817, 412421, 430616, 603935, 629785, 797818, 816463, 962722, 983904, 1688471]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# trial name isPost_Trial2
# split_index is [0, 238204, 266195, 528000, 553978, 768403, 800505, 1026744, 1050828, 1224190, 1249133, 2136195]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_7/phy_AGR
# split_index is [0, 5367, 6778, 12282, 12812, 18166, 18835, 24767, 25507, 30848, 31333, 50390]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_8/phy_AGR
# split_index is [0, 12703, 13921, 21729, 22624, 28967, 31200, 39444, 39445, 41464, 50334, 52980, 88749]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_9/phy_MS4
# split_index is [0, 112438, 124479, 237499, 248188, 344114, 357067, 456295, 466490, 541560, 553553, 1021378]
# row_index is 0
# row_index is 1
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_10/phy_AGR
# split_index is [0, 4117, 4695, 8367, 8822, 13063, 13882, 18686, 19889, 24594, 25344, 41549]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 11023, 13216, 22760, 24608, 32943, 33932, 43978, 46642, 58293, 59565, 115300]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_12/phy_MS4
# split_index is [0, 215034, 238583, 336699, 348510, 487976, 512243, 689602, 701024, 810952, 833208, 1407728]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_13/phy_MS4
# split_index is [0, 231141, 250901, 392343, 416973, 570685, 594697, 731887, 750416, 855016, 874840, 1484989]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 24990, 28596, 50405, 53358, 76013, 77605, 92962, 94895, 112607, 114014, 213120]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 242547, 262817, 412421, 430616, 603935, 629785, 797818, 816463, 962722, 983904, 1688471]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# trial name isTrial3
# split_index is [0, 238204, 266195, 528000, 553978, 768403, 800505, 1026744, 1050828, 1224190, 1249133, 2136195]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_7/phy_AGR
# split_index is [0, 5367, 6778, 12282, 12812, 18166, 18835, 24767, 25507, 30848, 31333, 50390]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_8/phy_AGR
# split_index is [0, 12703, 13921, 21729, 22624, 28967, 31200, 39444, 39445, 41464, 50334, 52980, 88749]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_9/phy_MS4
# split_index is [0, 112438, 124479, 237499, 248188, 344114, 357067, 456295, 466490, 541560, 553553, 1021378]
# row_index is 0
# row_index is 1
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_10/phy_AGR
# split_index is [0, 4117, 4695, 8367, 8822, 13063, 13882, 18686, 19889, 24594, 25344, 41549]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 11023, 13216, 22760, 24608, 32943, 33932, 43978, 46642, 58293, 59565, 115300]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_12/phy_MS4
# split_index is [0, 215034, 238583, 336699, 348510, 487976, 512243, 689602, 701024, 810952, 833208, 1407728]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_13/phy_MS4
# split_index is [0, 231141, 250901, 392343, 416973, 570685, 594697, 731887, 750416, 855016, 874840, 1484989]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 24990, 28596, 50405, 53358, 76013, 77605, 92962, 94895, 112607, 114014, 213120]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 242547, 262817, 412421, 430616, 603935, 629785, 797818, 816463, 962722, 983904, 1688471]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# trial name isPost_Trial3
# split_index is [0, 238204, 266195, 528000, 553978, 768403, 800505, 1026744, 1050828, 1224190, 1249133, 2136195]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_7/phy_AGR
# split_index is [0, 5367, 6778, 12282, 12812, 18166, 18835, 24767, 25507, 30848, 31333, 50390]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_8/phy_AGR
# split_index is [0, 12703, 13921, 21729, 22624, 28967, 31200, 39444, 39445, 41464, 50334, 52980, 88749]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_9/phy_MS4
# split_index is [0, 112438, 124479, 237499, 248188, 344114, 357067, 456295, 466490, 541560, 553553, 1021378]
# row_index is 0
# row_index is 1
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_10/phy_AGR
# split_index is [0, 4117, 4695, 8367, 8822, 13063, 13882, 18686, 19889, 24594, 25344, 41549]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 11023, 13216, 22760, 24608, 32943, 33932, 43978, 46642, 58293, 59565, 115300]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_12/phy_MS4
# split_index is [0, 215034, 238583, 336699, 348510, 487976, 512243, 689602, 701024, 810952, 833208, 1407728]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_13/phy_MS4
# split_index is [0, 231141, 250901, 392343, 416973, 570685, 594697, 731887, 750416, 855016, 874840, 1484989]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 24990, 28596, 50405, 53358, 76013, 77605, 92962, 94895, 112607, 114014, 213120]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 242547, 262817, 412421, 430616, 603935, 629785, 797818, 816463, 962722, 983904, 1688471]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# trial name isTrial4
# split_index is [0, 238204, 266195, 528000, 553978, 768403, 800505, 1026744, 1050828, 1224190, 1249133, 2136195]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_7/phy_AGR
# split_index is [0, 5367, 6778, 12282, 12812, 18166, 18835, 24767, 25507, 30848, 31333, 50390]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_8/phy_AGR
# split_index is [0, 12703, 13921, 21729, 22624, 28967, 31200, 39444, 39445, 41464, 50334, 52980, 88749]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_9/phy_MS4
# split_index is [0, 112438, 124479, 237499, 248188, 344114, 357067, 456295, 466490, 541560, 553553, 1021378]
# row_index is 0
# row_index is 1
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_10/phy_AGR
# split_index is [0, 4117, 4695, 8367, 8822, 13063, 13882, 18686, 19889, 24594, 25344, 41549]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 11023, 13216, 22760, 24608, 32943, 33932, 43978, 46642, 58293, 59565, 115300]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_12/phy_MS4
# split_index is [0, 215034, 238583, 336699, 348510, 487976, 512243, 689602, 701024, 810952, 833208, 1407728]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_13/phy_MS4
# split_index is [0, 231141, 250901, 392343, 416973, 570685, 594697, 731887, 750416, 855016, 874840, 1484989]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 24990, 28596, 50405, 53358, 76013, 77605, 92962, 94895, 112607, 114014, 213120]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 242547, 262817, 412421, 430616, 603935, 629785, 797818, 816463, 962722, 983904, 1688471]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# trial name isPost_Trial4
# split_index is [0, 238204, 266195, 528000, 553978, 768403, 800505, 1026744, 1050828, 1224190, 1249133, 2136195]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_7/phy_AGR
# split_index is [0, 5367, 6778, 12282, 12812, 18166, 18835, 24767, 25507, 30848, 31333, 50390]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_8/phy_AGR
# split_index is [0, 12703, 13921, 21729, 22624, 28967, 31200, 39444, 39445, 41464, 50334, 52980, 88749]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_9/phy_MS4
# split_index is [0, 112438, 124479, 237499, 248188, 344114, 357067, 456295, 466490, 541560, 553553, 1021378]
# row_index is 0
# row_index is 1
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_10/phy_AGR
# split_index is [0, 4117, 4695, 8367, 8822, 13063, 13882, 18686, 19889, 24594, 25344, 41549]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 11023, 13216, 22760, 24608, 32943, 33932, 43978, 46642, 58293, 59565, 115300]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_12/phy_MS4
# split_index is [0, 215034, 238583, 336699, 348510, 487976, 512243, 689602, 701024, 810952, 833208, 1407728]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_13/phy_MS4
# split_index is [0, 231141, 250901, 392343, 416973, 570685, 594697, 731887, 750416, 855016, 874840, 1484989]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 24990, 28596, 50405, 53358, 76013, 77605, 92962, 94895, 112607, 114014, 213120]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_15/phy_MS4
# split_index is [0, 242547, 262817, 412421, 430616, 603935, 629785, 797818, 816463, 962722, 983904, 1688471]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# trial name isTrial5
# split_index is [0, 238204, 266195, 528000, 553978, 768403, 800505, 1026744, 1050828, 1224190, 1249133, 2136195]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_7/phy_AGR
# split_index is [0, 5367, 6778, 12282, 12812, 18166, 18835, 24767, 25507, 30848, 31333, 50390]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020/OS_Ephys_RGS14_Rat8_378133_SD10_HC_15_05_2020_merged/cortex/Tetrode_8/phy_AGR
# split_index is [0, 12703, 13921, 21729, 22624, 28967, 31200, 39444, 39445, 41464, 50334, 52980, 88749]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-7a09272bb48c> in <module>
#       1 for trial_name in trial_name_list:
#       2     createFolder(path + '/' + date)
# ----> 3     final_matrix = iterate_all_file_for_a_trial(trial_info, absolute_path_list, trial_name, project_folder_name)
#       4     createFolder(path + '/' + date)
#       5     np.save(trial_name + "_actmat", final_matrix)
#
# ~/Desktop/cell_assembly_script/GenzelLab_cell_assembly/ready_to_use/actmat_generate.py in iterate_all_file_for_a_trial(trial_info, absolute_path_list, trial_name, project_file_name)
#     143     for path_index in range(1, len(absolute_path_list)):
#     144         print(absolute_path_list[path_index])
# --> 145         matrix, neuron_id = get_actmat_for_a_trial(trial_info, absolute_path_list[path_index], trial_name, project_file_name)
#     146         actmat = np.concatenate((actmat, matrix), axis=0)
#     147         # neuron_id_all.append(neuron_id)
#
# ~/Desktop/cell_assembly_script/GenzelLab_cell_assembly/ready_to_use/actmat_generate.py in get_actmat_for_a_trial(trial_info, absolute_path, trial_name, project_file_name)
#     122     spike_times, spike_clusters = trunk_samples(trial_info, spike_clusters, spike_times, trial_name)
#     123     step_size, bins, NData = get_matrix_structure(trial_info, spike_times, cluster_df, trial_name)
# --> 124     actmat = get_single_filled_matrix(spike_times, spike_clusters, NData, step_size, bins)
#     125     neuron_id = []
#     126     for row_index in range(len(actmat)):
#
# ~/Desktop/cell_assembly_script/GenzelLab_cell_assembly/ready_to_use/actmat_generate.py in get_single_filled_matrix(spike_times, spike_clusters, NData, step_size, bins)
#     108         neuron_id = spike_clusters[index]
#     109         bin_index = int((spike_times[index] - bins[0]) / step_size)
# --> 110         NData[neuron_id][bin_index] += 1
#     111     return NData
#     112
#
# IndexError: index -107989 is out of bounds for axis 0 with size 12001

# %%
actmat_neuron_name = get_neuron_name(trial_info, absolute_path_list, trial_name_list[0], project_folder_name )
createFolder(path + '/' + date)
np.save("actmat_neuron_name", actmat_neuron_name)

# %% [markdown]
# ### The code below is just for test purpose, do not run it

# %%
# spike_clusters = np.load("spike_clusters.npy")
# spike_times = np.load("spike_times.npy")
# set_neuron = set(spike_clusters)
# for neuron_x in set_neuron:
#     neuron_x_index =  [i for i,d in enumerate(spike_clusters) if d==neuron_x]
#     spike_times = spike_times.flatten()
#     neuron_x_map = (np.array([spike_times[index] for index in neuron_x_index])/750).astype(int)
#     neuron_x_map

# (np.array(spike_time_17)/750)[1]
