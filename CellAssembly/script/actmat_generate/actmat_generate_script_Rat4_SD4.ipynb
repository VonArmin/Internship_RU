# %%
from actmat_generate import *
import os
import pandas as pd

# %% [markdown]
# ### Run the following script to generate actmat matrix
#
# - Change the path into the folder where you put the Trial_durations.xls file
# - Çhange the date into actual date performing the experiment

# %%
# path = "D:\Internship_Radbound\Cell_assembly_yuqin"
path = "/media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged"
date = "Rat4_SD4_HC_05_11_2019"
project_folder_name = "RGS_PROJECT_RGS14_PFC_Rn4_HC_SD4_T"

# %%
os.chdir(path)
trial_info = pd.read_excel('Trial_durations.xls', index_col = 0)  
trial_last_period_name = trial_info.columns[-1]
final_samples = trial_info[trial_last_period_name]["Cumulative Samples"]
samples_index_list = list(trial_info.loc["Cumulative Samples"])
fs = 30000
#Modified the minutes and samples by removing the tail
trial_info.loc["modified_minutes"] = [45.0, 5.0, 45.0, 5.0, 45.0, 5.0, 45.0, 5.0, 45.0, 5.0, 180.0]
trial_info.loc["modified_samples"] = trial_info.loc["modified_minutes"]* 60 * 30000

# %% [markdown]
# ### Change:
#
# - absolute_path_list
# - trial_name_list
# - project_folder_name

# %%
absolute_path_list = [path + "/cortex/Tetrode_1/phy_AGR",
                     path + "/cortex/Tetrode_2/phy_MS4",
                     path + "/cortex/Tetrode_3/phy_MS4",
                     path + "/cortex/Tetrode_10/phy_MS4",
                     path + "/cortex/Tetrode_11/phy_MS4",
                     path + "/cortex/Tetrode_12/phy_AGR",
                     path + "/cortex/Tetrode_13/phy_AGR",
                     path + "/cortex/Tetrode_15/phy_AGR",
                     path + "/cortex/Tetrode_16/phy_MS4"]
trial_name_list = list(trial_info.columns)

# %%
# get_neuron_name(trial_info, absolute_path_list, trial_name_list[0], project_folder_name)

# %%
for trial_name in trial_name_list:
    createFolder(path + '/' + date)
    final_matrix = iterate_all_file_for_a_trial(trial_info, absolute_path_list, trial_name, project_folder_name)
    createFolder(path + '/' + date)
    np.save(trial_name + "_actmat", final_matrix)
# Out:
# trial name isPre_sleep
# split_index is [0, 800, 925, 2876, 3011, 5173, 5569, 7847, 8181, 10094, 10314, 27965]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_2/phy_MS4
# split_index is [0, 393205, 437885, 659906, 697296, 900756, 940280, 1150050, 1190684, 1547787, 1589015, 2684989]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_3/phy_MS4
# split_index is [0, 449693, 500480, 773535, 815469, 1064361, 1110304, 1349866, 1396420, 1782365, 1830795, 3096145]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 420989, 467104, 695407, 735021, 926952, 968935, 1155168, 1197490, 1553439, 1596507, 2652317]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_11/phy_MS4
# split_index is [0, 375658, 419679, 643757, 677939, 873347, 909353, 1087697, 1123479, 1449947, 1488903, 2588742]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 423, 461, 944, 994, 1611, 1659, 2554, 2583, 3266, 3299, 6733]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 10623, 11816, 21925, 23553, 34431, 35824, 48259, 49493, 62404, 63888, 123213]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# row_index is 56
# row_index is 57
# row_index is 58
# row_index is 59
# row_index is 60
# row_index is 61
# row_index is 62
# row_index is 63
# row_index is 64
# row_index is 65
# row_index is 66
# row_index is 67
# row_index is 68
# row_index is 69
# row_index is 70
# row_index is 71
# row_index is 72
# row_index is 73
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_15/phy_AGR
# split_index is [0, 119226, 133066, 224257, 234436, 312832, 323380, 399404, 412211, 530411, 543668, 951701]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_16/phy_MS4
# split_index is [0, 385694, 430687, 666374, 704727, 905541, 947960, 1147898, 1190323, 1546480, 1590612, 2682033]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# trial name isTrial1
# split_index is [0, 800, 925, 2876, 3011, 5173, 5569, 7847, 8181, 10094, 10314, 27965]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_2/phy_MS4
# split_index is [0, 393205, 437885, 659906, 697296, 900756, 940280, 1150050, 1190684, 1547787, 1589015, 2684989]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_3/phy_MS4
# split_index is [0, 449693, 500480, 773535, 815469, 1064361, 1110304, 1349866, 1396420, 1782365, 1830795, 3096145]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 420989, 467104, 695407, 735021, 926952, 968935, 1155168, 1197490, 1553439, 1596507, 2652317]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_11/phy_MS4
# split_index is [0, 375658, 419679, 643757, 677939, 873347, 909353, 1087697, 1123479, 1449947, 1488903, 2588742]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 423, 461, 944, 994, 1611, 1659, 2554, 2583, 3266, 3299, 6733]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 10623, 11816, 21925, 23553, 34431, 35824, 48259, 49493, 62404, 63888, 123213]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# row_index is 56
# row_index is 57
# row_index is 58
# row_index is 59
# row_index is 60
# row_index is 61
# row_index is 62
# row_index is 63
# row_index is 64
# row_index is 65
# row_index is 66
# row_index is 67
# row_index is 68
# row_index is 69
# row_index is 70
# row_index is 71
# row_index is 72
# row_index is 73
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_15/phy_AGR
# split_index is [0, 119226, 133066, 224257, 234436, 312832, 323380, 399404, 412211, 530411, 543668, 951701]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_16/phy_MS4
# split_index is [0, 385694, 430687, 666374, 704727, 905541, 947960, 1147898, 1190323, 1546480, 1590612, 2682033]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# trial name isPost_Trial1
# split_index is [0, 800, 925, 2876, 3011, 5173, 5569, 7847, 8181, 10094, 10314, 27965]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_2/phy_MS4
# split_index is [0, 393205, 437885, 659906, 697296, 900756, 940280, 1150050, 1190684, 1547787, 1589015, 2684989]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_3/phy_MS4
# split_index is [0, 449693, 500480, 773535, 815469, 1064361, 1110304, 1349866, 1396420, 1782365, 1830795, 3096145]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 420989, 467104, 695407, 735021, 926952, 968935, 1155168, 1197490, 1553439, 1596507, 2652317]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_11/phy_MS4
# split_index is [0, 375658, 419679, 643757, 677939, 873347, 909353, 1087697, 1123479, 1449947, 1488903, 2588742]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 423, 461, 944, 994, 1611, 1659, 2554, 2583, 3266, 3299, 6733]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 10623, 11816, 21925, 23553, 34431, 35824, 48259, 49493, 62404, 63888, 123213]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# row_index is 56
# row_index is 57
# row_index is 58
# row_index is 59
# row_index is 60
# row_index is 61
# row_index is 62
# row_index is 63
# row_index is 64
# row_index is 65
# row_index is 66
# row_index is 67
# row_index is 68
# row_index is 69
# row_index is 70
# row_index is 71
# row_index is 72
# row_index is 73
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_15/phy_AGR
# split_index is [0, 119226, 133066, 224257, 234436, 312832, 323380, 399404, 412211, 530411, 543668, 951701]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_16/phy_MS4
# split_index is [0, 385694, 430687, 666374, 704727, 905541, 947960, 1147898, 1190323, 1546480, 1590612, 2682033]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# trial name isTrial2
# split_index is [0, 800, 925, 2876, 3011, 5173, 5569, 7847, 8181, 10094, 10314, 27965]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_2/phy_MS4
# split_index is [0, 393205, 437885, 659906, 697296, 900756, 940280, 1150050, 1190684, 1547787, 1589015, 2684989]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_3/phy_MS4
# split_index is [0, 449693, 500480, 773535, 815469, 1064361, 1110304, 1349866, 1396420, 1782365, 1830795, 3096145]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 420989, 467104, 695407, 735021, 926952, 968935, 1155168, 1197490, 1553439, 1596507, 2652317]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_11/phy_MS4
# split_index is [0, 375658, 419679, 643757, 677939, 873347, 909353, 1087697, 1123479, 1449947, 1488903, 2588742]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 423, 461, 944, 994, 1611, 1659, 2554, 2583, 3266, 3299, 6733]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 10623, 11816, 21925, 23553, 34431, 35824, 48259, 49493, 62404, 63888, 123213]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# row_index is 56
# row_index is 57
# row_index is 58
# row_index is 59
# row_index is 60
# row_index is 61
# row_index is 62
# row_index is 63
# row_index is 64
# row_index is 65
# row_index is 66
# row_index is 67
# row_index is 68
# row_index is 69
# row_index is 70
# row_index is 71
# row_index is 72
# row_index is 73
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_15/phy_AGR
# split_index is [0, 119226, 133066, 224257, 234436, 312832, 323380, 399404, 412211, 530411, 543668, 951701]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_16/phy_MS4
# split_index is [0, 385694, 430687, 666374, 704727, 905541, 947960, 1147898, 1190323, 1546480, 1590612, 2682033]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# trial name isPost_Trial2
# split_index is [0, 800, 925, 2876, 3011, 5173, 5569, 7847, 8181, 10094, 10314, 27965]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_2/phy_MS4
# split_index is [0, 393205, 437885, 659906, 697296, 900756, 940280, 1150050, 1190684, 1547787, 1589015, 2684989]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_3/phy_MS4
# split_index is [0, 449693, 500480, 773535, 815469, 1064361, 1110304, 1349866, 1396420, 1782365, 1830795, 3096145]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 420989, 467104, 695407, 735021, 926952, 968935, 1155168, 1197490, 1553439, 1596507, 2652317]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_11/phy_MS4
# split_index is [0, 375658, 419679, 643757, 677939, 873347, 909353, 1087697, 1123479, 1449947, 1488903, 2588742]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 423, 461, 944, 994, 1611, 1659, 2554, 2583, 3266, 3299, 6733]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 10623, 11816, 21925, 23553, 34431, 35824, 48259, 49493, 62404, 63888, 123213]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# row_index is 56
# row_index is 57
# row_index is 58
# row_index is 59
# row_index is 60
# row_index is 61
# row_index is 62
# row_index is 63
# row_index is 64
# row_index is 65
# row_index is 66
# row_index is 67
# row_index is 68
# row_index is 69
# row_index is 70
# row_index is 71
# row_index is 72
# row_index is 73
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_15/phy_AGR
# split_index is [0, 119226, 133066, 224257, 234436, 312832, 323380, 399404, 412211, 530411, 543668, 951701]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_16/phy_MS4
# split_index is [0, 385694, 430687, 666374, 704727, 905541, 947960, 1147898, 1190323, 1546480, 1590612, 2682033]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# trial name isTrial3
# split_index is [0, 800, 925, 2876, 3011, 5173, 5569, 7847, 8181, 10094, 10314, 27965]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_2/phy_MS4
# split_index is [0, 393205, 437885, 659906, 697296, 900756, 940280, 1150050, 1190684, 1547787, 1589015, 2684989]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_3/phy_MS4
# split_index is [0, 449693, 500480, 773535, 815469, 1064361, 1110304, 1349866, 1396420, 1782365, 1830795, 3096145]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 420989, 467104, 695407, 735021, 926952, 968935, 1155168, 1197490, 1553439, 1596507, 2652317]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_11/phy_MS4
# split_index is [0, 375658, 419679, 643757, 677939, 873347, 909353, 1087697, 1123479, 1449947, 1488903, 2588742]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 423, 461, 944, 994, 1611, 1659, 2554, 2583, 3266, 3299, 6733]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 10623, 11816, 21925, 23553, 34431, 35824, 48259, 49493, 62404, 63888, 123213]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# row_index is 56
# row_index is 57
# row_index is 58
# row_index is 59
# row_index is 60
# row_index is 61
# row_index is 62
# row_index is 63
# row_index is 64
# row_index is 65
# row_index is 66
# row_index is 67
# row_index is 68
# row_index is 69
# row_index is 70
# row_index is 71
# row_index is 72
# row_index is 73
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_15/phy_AGR
# split_index is [0, 119226, 133066, 224257, 234436, 312832, 323380, 399404, 412211, 530411, 543668, 951701]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_16/phy_MS4
# split_index is [0, 385694, 430687, 666374, 704727, 905541, 947960, 1147898, 1190323, 1546480, 1590612, 2682033]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# trial name isPost_Trial3
# split_index is [0, 800, 925, 2876, 3011, 5173, 5569, 7847, 8181, 10094, 10314, 27965]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_2/phy_MS4
# split_index is [0, 393205, 437885, 659906, 697296, 900756, 940280, 1150050, 1190684, 1547787, 1589015, 2684989]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_3/phy_MS4
# split_index is [0, 449693, 500480, 773535, 815469, 1064361, 1110304, 1349866, 1396420, 1782365, 1830795, 3096145]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 420989, 467104, 695407, 735021, 926952, 968935, 1155168, 1197490, 1553439, 1596507, 2652317]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_11/phy_MS4
# split_index is [0, 375658, 419679, 643757, 677939, 873347, 909353, 1087697, 1123479, 1449947, 1488903, 2588742]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 423, 461, 944, 994, 1611, 1659, 2554, 2583, 3266, 3299, 6733]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 10623, 11816, 21925, 23553, 34431, 35824, 48259, 49493, 62404, 63888, 123213]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# row_index is 56
# row_index is 57
# row_index is 58
# row_index is 59
# row_index is 60
# row_index is 61
# row_index is 62
# row_index is 63
# row_index is 64
# row_index is 65
# row_index is 66
# row_index is 67
# row_index is 68
# row_index is 69
# row_index is 70
# row_index is 71
# row_index is 72
# row_index is 73
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_15/phy_AGR
# split_index is [0, 119226, 133066, 224257, 234436, 312832, 323380, 399404, 412211, 530411, 543668, 951701]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_16/phy_MS4
# split_index is [0, 385694, 430687, 666374, 704727, 905541, 947960, 1147898, 1190323, 1546480, 1590612, 2682033]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# trial name isTrial4
# split_index is [0, 800, 925, 2876, 3011, 5173, 5569, 7847, 8181, 10094, 10314, 27965]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_2/phy_MS4
# split_index is [0, 393205, 437885, 659906, 697296, 900756, 940280, 1150050, 1190684, 1547787, 1589015, 2684989]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_3/phy_MS4
# split_index is [0, 449693, 500480, 773535, 815469, 1064361, 1110304, 1349866, 1396420, 1782365, 1830795, 3096145]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 420989, 467104, 695407, 735021, 926952, 968935, 1155168, 1197490, 1553439, 1596507, 2652317]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_11/phy_MS4
# split_index is [0, 375658, 419679, 643757, 677939, 873347, 909353, 1087697, 1123479, 1449947, 1488903, 2588742]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 423, 461, 944, 994, 1611, 1659, 2554, 2583, 3266, 3299, 6733]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 10623, 11816, 21925, 23553, 34431, 35824, 48259, 49493, 62404, 63888, 123213]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# row_index is 56
# row_index is 57
# row_index is 58
# row_index is 59
# row_index is 60
# row_index is 61
# row_index is 62
# row_index is 63
# row_index is 64
# row_index is 65
# row_index is 66
# row_index is 67
# row_index is 68
# row_index is 69
# row_index is 70
# row_index is 71
# row_index is 72
# row_index is 73
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_15/phy_AGR
# split_index is [0, 119226, 133066, 224257, 234436, 312832, 323380, 399404, 412211, 530411, 543668, 951701]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_16/phy_MS4
# split_index is [0, 385694, 430687, 666374, 704727, 905541, 947960, 1147898, 1190323, 1546480, 1590612, 2682033]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# trial name isPost_Trial4
# split_index is [0, 800, 925, 2876, 3011, 5173, 5569, 7847, 8181, 10094, 10314, 27965]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_2/phy_MS4
# split_index is [0, 393205, 437885, 659906, 697296, 900756, 940280, 1150050, 1190684, 1547787, 1589015, 2684989]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_3/phy_MS4
# split_index is [0, 449693, 500480, 773535, 815469, 1064361, 1110304, 1349866, 1396420, 1782365, 1830795, 3096145]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 420989, 467104, 695407, 735021, 926952, 968935, 1155168, 1197490, 1553439, 1596507, 2652317]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_11/phy_MS4
# split_index is [0, 375658, 419679, 643757, 677939, 873347, 909353, 1087697, 1123479, 1449947, 1488903, 2588742]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 423, 461, 944, 994, 1611, 1659, 2554, 2583, 3266, 3299, 6733]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 10623, 11816, 21925, 23553, 34431, 35824, 48259, 49493, 62404, 63888, 123213]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# row_index is 56
# row_index is 57
# row_index is 58
# row_index is 59
# row_index is 60
# row_index is 61
# row_index is 62
# row_index is 63
# row_index is 64
# row_index is 65
# row_index is 66
# row_index is 67
# row_index is 68
# row_index is 69
# row_index is 70
# row_index is 71
# row_index is 72
# row_index is 73
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_15/phy_AGR
# split_index is [0, 119226, 133066, 224257, 234436, 312832, 323380, 399404, 412211, 530411, 543668, 951701]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_16/phy_MS4
# split_index is [0, 385694, 430687, 666374, 704727, 905541, 947960, 1147898, 1190323, 1546480, 1590612, 2682033]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# trial name isTrial5
# split_index is [0, 800, 925, 2876, 3011, 5173, 5569, 7847, 8181, 10094, 10314, 27965]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_2/phy_MS4
# split_index is [0, 393205, 437885, 659906, 697296, 900756, 940280, 1150050, 1190684, 1547787, 1589015, 2684989]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_3/phy_MS4
# split_index is [0, 449693, 500480, 773535, 815469, 1064361, 1110304, 1349866, 1396420, 1782365, 1830795, 3096145]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 420989, 467104, 695407, 735021, 926952, 968935, 1155168, 1197490, 1553439, 1596507, 2652317]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_11/phy_MS4
# split_index is [0, 375658, 419679, 643757, 677939, 873347, 909353, 1087697, 1123479, 1449947, 1488903, 2588742]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 423, 461, 944, 994, 1611, 1659, 2554, 2583, 3266, 3299, 6733]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 10623, 11816, 21925, 23553, 34431, 35824, 48259, 49493, 62404, 63888, 123213]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# row_index is 56
# row_index is 57
# row_index is 58
# row_index is 59
# row_index is 60
# row_index is 61
# row_index is 62
# row_index is 63
# row_index is 64
# row_index is 65
# row_index is 66
# row_index is 67
# row_index is 68
# row_index is 69
# row_index is 70
# row_index is 71
# row_index is 72
# row_index is 73
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_15/phy_AGR
# split_index is [0, 119226, 133066, 224257, 234436, 312832, 323380, 399404, 412211, 530411, 543668, 951701]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_16/phy_MS4
# split_index is [0, 385694, 430687, 666374, 704727, 905541, 947960, 1147898, 1190323, 1546480, 1590612, 2682033]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# trial name isPost_Trial5
# split_index is [0, 800, 925, 2876, 3011, 5173, 5569, 7847, 8181, 10094, 10314, 27965]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_2/phy_MS4
# split_index is [0, 393205, 437885, 659906, 697296, 900756, 940280, 1150050, 1190684, 1547787, 1589015, 2684989]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_3/phy_MS4
# split_index is [0, 449693, 500480, 773535, 815469, 1064361, 1110304, 1349866, 1396420, 1782365, 1830795, 3096145]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_10/phy_MS4
# split_index is [0, 420989, 467104, 695407, 735021, 926952, 968935, 1155168, 1197490, 1553439, 1596507, 2652317]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_11/phy_MS4
# split_index is [0, 375658, 419679, 643757, 677939, 873347, 909353, 1087697, 1123479, 1449947, 1488903, 2588742]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_12/phy_AGR
# split_index is [0, 423, 461, 944, 994, 1611, 1659, 2554, 2583, 3266, 3299, 6733]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_13/phy_AGR
# split_index is [0, 10623, 11816, 21925, 23553, 34431, 35824, 48259, 49493, 62404, 63888, 123213]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# row_index is 56
# row_index is 57
# row_index is 58
# row_index is 59
# row_index is 60
# row_index is 61
# row_index is 62
# row_index is 63
# row_index is 64
# row_index is 65
# row_index is 66
# row_index is 67
# row_index is 68
# row_index is 69
# row_index is 70
# row_index is 71
# row_index is 72
# row_index is 73
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_15/phy_AGR
# split_index is [0, 119226, 133066, 224257, 234436, 312832, 323380, 399404, 412211, 530411, 543668, 951701]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat4_357153/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019/OS_Ephys_RGS14_Rat4_357153_SD4_HC_05_11_2019_merged/cortex/Tetrode_16/phy_MS4
# split_index is [0, 385694, 430687, 666374, 704727, 905541, 947960, 1147898, 1190323, 1546480, 1590612, 2682033]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3

# %%
actmat_neuron_name = get_neuron_name(trial_info, absolute_path_list, trial_name_list[0], project_folder_name )
createFolder(path + '/' + date)
np.save("actmat_neuron_name", actmat_neuron_name)
# Out:
# split_index is [0, 800, 925, 2876, 3011, 5173, 5569, 7847, 8181, 10094, 10314, 27965]
# row_index is 0
# split_index is [0, 393205, 437885, 659906, 697296, 900756, 940280, 1150050, 1190684, 1547787, 1589015, 2684989]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# split_index is [0, 449693, 500480, 773535, 815469, 1064361, 1110304, 1349866, 1396420, 1782365, 1830795, 3096145]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# split_index is [0, 420989, 467104, 695407, 735021, 926952, 968935, 1155168, 1197490, 1553439, 1596507, 2652317]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# split_index is [0, 375658, 419679, 643757, 677939, 873347, 909353, 1087697, 1123479, 1449947, 1488903, 2588742]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# split_index is [0, 423, 461, 944, 994, 1611, 1659, 2554, 2583, 3266, 3299, 6733]
# row_index is 0
# split_index is [0, 10623, 11816, 21925, 23553, 34431, 35824, 48259, 49493, 62404, 63888, 123213]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# row_index is 39
# row_index is 40
# row_index is 41
# row_index is 42
# row_index is 43
# row_index is 44
# row_index is 45
# row_index is 46
# row_index is 47
# row_index is 48
# row_index is 49
# row_index is 50
# row_index is 51
# row_index is 52
# row_index is 53
# row_index is 54
# row_index is 55
# row_index is 56
# row_index is 57
# row_index is 58
# row_index is 59
# row_index is 60
# row_index is 61
# row_index is 62
# row_index is 63
# row_index is 64
# row_index is 65
# row_index is 66
# row_index is 67
# row_index is 68
# row_index is 69
# row_index is 70
# row_index is 71
# row_index is 72
# row_index is 73
# split_index is [0, 119226, 133066, 224257, 234436, 312832, 323380, 399404, 412211, 530411, 543668, 951701]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# split_index is [0, 385694, 430687, 666374, 704727, 905541, 947960, 1147898, 1190323, 1546480, 1590612, 2682033]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3

# %% [markdown]
# ### The code below is just for test purpose, do not run it

# %%
# spike_clusters = np.load("spike_clusters.npy")
# spike_times = np.load("spike_times.npy")
# set_neuron = set(spike_clusters)
# for neuron_x in set_neuron:
#     neuron_x_index =  [i for i,d in enumerate(spike_clusters) if d==neuron_x]
#     spike_times = spike_times.flatten()
#     neuron_x_map = (np.array([spike_times[index] for index in neuron_x_index])/750).astype(int)
#     neuron_x_map

# (np.array(spike_time_17)/750)[1]
