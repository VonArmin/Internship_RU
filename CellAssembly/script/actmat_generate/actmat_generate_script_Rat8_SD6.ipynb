# %%
from actmat_generate import *
import os
import pandas as pd

# %% [markdown]
# ### Run the following script to generate actmat matrix
#
# - Change the path into the folder where you put the Trial_durations.xls file
# - Çhange the date into actual date performing the experiment

# %%
# path = "D:\Internship_Radbound\Cell_assembly_yuqin"
path = "/media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged"
date = "Rat8_SD6_OD"
project_folder_name = "RGS_PROJECT_RGS14_PFC_Rn8_OD_SD6"

# %%
os.chdir(path)
trial_info = pd.read_excel('Trial_durations.xls', index_col = 0)  
trial_last_period_name = trial_info.columns[-1]
final_samples = trial_info[trial_last_period_name]["Cumulative Samples"]
samples_index_list = list(trial_info.loc["Cumulative Samples"])
fs = 30000
#Modified the minutes and samples by removing the tail
trial_info.loc["modified_minutes"] = [45.0, 5.0, 45.0, 5.0, 45.0, 5.0, 45.0, 5.0, 45.0, 5.0, 180.0]
trial_info.loc["modified_samples"] = trial_info.loc["modified_minutes"]* 60 * 30000

# %% [markdown]
# ### Change:
#
# - absolute_path_list
# - trial_name_list
# - project_folder_name

# %%
absolute_path_list = [path + "/cortex/Tetrode_6/phy_MS4",
                     path + "/cortex/Tetrode_7/phy_AGR",
                     path + "/cortex/Tetrode_8/phy_MS4",
                     path + "/cortex/Tetrode_9/phy_AGR",
                      path + "/cortex/Tetrode_10/phy_AGR",
                     path + "/cortex/Tetrode_11/phy_AGR",
                     path + "/cortex/Tetrode_12/phy_MS4",
                     path + "/cortex/Tetrode_13/phy_MS4",
                      path + "/cortex/Tetrode_14/phy_AGR",
                     path + "/cortex/Tetrode_15/phy_AGR"]
trial_name_list = list(trial_info.columns)

# %%
# get_neuron_name(trial_info, absolute_path_list, trial_name_list[0], project_folder_name)

# %%
for trial_name in trial_name_list:
    createFolder(path + '/' + date)
    final_matrix = iterate_all_file_for_a_trial(trial_info, absolute_path_list, trial_name, project_folder_name)
    createFolder(path + '/' + date)
    np.save(trial_name + "_actmat", final_matrix)
# Out:
# trial name isPre_sleep_truncated
# split_index is [0, 252520, 280840, 472393, 497695, 652580, 683787, 824876, 850846, 1024415, 1052489, 1658139]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_7/phy_AGR
# split_index is [0, 2751, 4096, 7253, 7909, 10889, 11413, 14363, 14675, 17008, 17452, 25441]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_8/phy_MS4
# split_index is [0, 254398, 279875, 423640, 444851, 567005, 595336, 741732, 762040, 905043, 929251, 1475518]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_9/phy_AGR
# split_index is [0, 10112, 11810, 22308, 24255, 33340, 34891, 44392, 45482, 55229, 56255, 94996]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_10/phy_AGR
# split_index is [0, 6228, 6878, 13264, 13916, 20386, 20852, 27154, 27639, 34147, 34705, 64808]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 10582, 12519, 20861, 22641, 31885, 33449, 42733, 44229, 54691, 56121, 96604]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_12/phy_MS4
# split_index is [0, 219555, 243168, 377373, 401457, 538666, 566332, 690944, 715650, 876668, 905125, 1631157]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_13/phy_MS4
# split_index is [0, 184213, 201326, 278177, 295699, 372371, 393471, 478171, 495118, 617244, 644642, 1139139]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 1291, 1394, 2655, 2832, 5011, 5162, 8703, 9173, 12607, 12747, 121598]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_15/phy_AGR
# split_index is [0, 30779, 33735, 49313, 51846, 69631, 71985, 90781, 92562, 111419, 114328, 165472]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# trial name isTrial1
# split_index is [0, 252520, 280840, 472393, 497695, 652580, 683787, 824876, 850846, 1024415, 1052489, 1658139]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_7/phy_AGR
# split_index is [0, 2751, 4096, 7253, 7909, 10889, 11413, 14363, 14675, 17008, 17452, 25441]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_8/phy_MS4
# split_index is [0, 254398, 279875, 423640, 444851, 567005, 595336, 741732, 762040, 905043, 929251, 1475518]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_9/phy_AGR
# split_index is [0, 10112, 11810, 22308, 24255, 33340, 34891, 44392, 45482, 55229, 56255, 94996]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_10/phy_AGR
# split_index is [0, 6228, 6878, 13264, 13916, 20386, 20852, 27154, 27639, 34147, 34705, 64808]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 10582, 12519, 20861, 22641, 31885, 33449, 42733, 44229, 54691, 56121, 96604]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_12/phy_MS4
# split_index is [0, 219555, 243168, 377373, 401457, 538666, 566332, 690944, 715650, 876668, 905125, 1631157]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_13/phy_MS4
# split_index is [0, 184213, 201326, 278177, 295699, 372371, 393471, 478171, 495118, 617244, 644642, 1139139]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 1291, 1394, 2655, 2832, 5011, 5162, 8703, 9173, 12607, 12747, 121598]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_15/phy_AGR
# split_index is [0, 30779, 33735, 49313, 51846, 69631, 71985, 90781, 92562, 111419, 114328, 165472]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# trial name isPost_Trial1_truncated
# split_index is [0, 252520, 280840, 472393, 497695, 652580, 683787, 824876, 850846, 1024415, 1052489, 1658139]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_7/phy_AGR
# split_index is [0, 2751, 4096, 7253, 7909, 10889, 11413, 14363, 14675, 17008, 17452, 25441]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_8/phy_MS4
# split_index is [0, 254398, 279875, 423640, 444851, 567005, 595336, 741732, 762040, 905043, 929251, 1475518]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_9/phy_AGR
# split_index is [0, 10112, 11810, 22308, 24255, 33340, 34891, 44392, 45482, 55229, 56255, 94996]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_10/phy_AGR
# split_index is [0, 6228, 6878, 13264, 13916, 20386, 20852, 27154, 27639, 34147, 34705, 64808]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 10582, 12519, 20861, 22641, 31885, 33449, 42733, 44229, 54691, 56121, 96604]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_12/phy_MS4
# split_index is [0, 219555, 243168, 377373, 401457, 538666, 566332, 690944, 715650, 876668, 905125, 1631157]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_13/phy_MS4
# split_index is [0, 184213, 201326, 278177, 295699, 372371, 393471, 478171, 495118, 617244, 644642, 1139139]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 1291, 1394, 2655, 2832, 5011, 5162, 8703, 9173, 12607, 12747, 121598]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_15/phy_AGR
# split_index is [0, 30779, 33735, 49313, 51846, 69631, 71985, 90781, 92562, 111419, 114328, 165472]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# trial name isTrial2
# split_index is [0, 252520, 280840, 472393, 497695, 652580, 683787, 824876, 850846, 1024415, 1052489, 1658139]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_7/phy_AGR
# split_index is [0, 2751, 4096, 7253, 7909, 10889, 11413, 14363, 14675, 17008, 17452, 25441]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_8/phy_MS4
# split_index is [0, 254398, 279875, 423640, 444851, 567005, 595336, 741732, 762040, 905043, 929251, 1475518]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_9/phy_AGR
# split_index is [0, 10112, 11810, 22308, 24255, 33340, 34891, 44392, 45482, 55229, 56255, 94996]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_10/phy_AGR
# split_index is [0, 6228, 6878, 13264, 13916, 20386, 20852, 27154, 27639, 34147, 34705, 64808]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 10582, 12519, 20861, 22641, 31885, 33449, 42733, 44229, 54691, 56121, 96604]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_12/phy_MS4
# split_index is [0, 219555, 243168, 377373, 401457, 538666, 566332, 690944, 715650, 876668, 905125, 1631157]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_13/phy_MS4
# split_index is [0, 184213, 201326, 278177, 295699, 372371, 393471, 478171, 495118, 617244, 644642, 1139139]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 1291, 1394, 2655, 2832, 5011, 5162, 8703, 9173, 12607, 12747, 121598]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_15/phy_AGR
# split_index is [0, 30779, 33735, 49313, 51846, 69631, 71985, 90781, 92562, 111419, 114328, 165472]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# trial name isPost_Trial2
# split_index is [0, 252520, 280840, 472393, 497695, 652580, 683787, 824876, 850846, 1024415, 1052489, 1658139]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_7/phy_AGR
# split_index is [0, 2751, 4096, 7253, 7909, 10889, 11413, 14363, 14675, 17008, 17452, 25441]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_8/phy_MS4
# split_index is [0, 254398, 279875, 423640, 444851, 567005, 595336, 741732, 762040, 905043, 929251, 1475518]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_9/phy_AGR
# split_index is [0, 10112, 11810, 22308, 24255, 33340, 34891, 44392, 45482, 55229, 56255, 94996]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_10/phy_AGR
# split_index is [0, 6228, 6878, 13264, 13916, 20386, 20852, 27154, 27639, 34147, 34705, 64808]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 10582, 12519, 20861, 22641, 31885, 33449, 42733, 44229, 54691, 56121, 96604]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_12/phy_MS4
# split_index is [0, 219555, 243168, 377373, 401457, 538666, 566332, 690944, 715650, 876668, 905125, 1631157]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_13/phy_MS4
# split_index is [0, 184213, 201326, 278177, 295699, 372371, 393471, 478171, 495118, 617244, 644642, 1139139]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 1291, 1394, 2655, 2832, 5011, 5162, 8703, 9173, 12607, 12747, 121598]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_15/phy_AGR
# split_index is [0, 30779, 33735, 49313, 51846, 69631, 71985, 90781, 92562, 111419, 114328, 165472]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# trial name isTrial3
# split_index is [0, 252520, 280840, 472393, 497695, 652580, 683787, 824876, 850846, 1024415, 1052489, 1658139]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_7/phy_AGR
# split_index is [0, 2751, 4096, 7253, 7909, 10889, 11413, 14363, 14675, 17008, 17452, 25441]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_8/phy_MS4
# split_index is [0, 254398, 279875, 423640, 444851, 567005, 595336, 741732, 762040, 905043, 929251, 1475518]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_9/phy_AGR
# split_index is [0, 10112, 11810, 22308, 24255, 33340, 34891, 44392, 45482, 55229, 56255, 94996]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_10/phy_AGR
# split_index is [0, 6228, 6878, 13264, 13916, 20386, 20852, 27154, 27639, 34147, 34705, 64808]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 10582, 12519, 20861, 22641, 31885, 33449, 42733, 44229, 54691, 56121, 96604]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_12/phy_MS4
# split_index is [0, 219555, 243168, 377373, 401457, 538666, 566332, 690944, 715650, 876668, 905125, 1631157]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_13/phy_MS4
# split_index is [0, 184213, 201326, 278177, 295699, 372371, 393471, 478171, 495118, 617244, 644642, 1139139]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 1291, 1394, 2655, 2832, 5011, 5162, 8703, 9173, 12607, 12747, 121598]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_15/phy_AGR
# split_index is [0, 30779, 33735, 49313, 51846, 69631, 71985, 90781, 92562, 111419, 114328, 165472]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# trial name isPost_Trial3
# split_index is [0, 252520, 280840, 472393, 497695, 652580, 683787, 824876, 850846, 1024415, 1052489, 1658139]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_7/phy_AGR
# split_index is [0, 2751, 4096, 7253, 7909, 10889, 11413, 14363, 14675, 17008, 17452, 25441]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_8/phy_MS4
# split_index is [0, 254398, 279875, 423640, 444851, 567005, 595336, 741732, 762040, 905043, 929251, 1475518]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_9/phy_AGR
# split_index is [0, 10112, 11810, 22308, 24255, 33340, 34891, 44392, 45482, 55229, 56255, 94996]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_10/phy_AGR
# split_index is [0, 6228, 6878, 13264, 13916, 20386, 20852, 27154, 27639, 34147, 34705, 64808]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 10582, 12519, 20861, 22641, 31885, 33449, 42733, 44229, 54691, 56121, 96604]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_12/phy_MS4
# split_index is [0, 219555, 243168, 377373, 401457, 538666, 566332, 690944, 715650, 876668, 905125, 1631157]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_13/phy_MS4
# split_index is [0, 184213, 201326, 278177, 295699, 372371, 393471, 478171, 495118, 617244, 644642, 1139139]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 1291, 1394, 2655, 2832, 5011, 5162, 8703, 9173, 12607, 12747, 121598]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_15/phy_AGR
# split_index is [0, 30779, 33735, 49313, 51846, 69631, 71985, 90781, 92562, 111419, 114328, 165472]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# trial name isTrial4
# split_index is [0, 252520, 280840, 472393, 497695, 652580, 683787, 824876, 850846, 1024415, 1052489, 1658139]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_7/phy_AGR
# split_index is [0, 2751, 4096, 7253, 7909, 10889, 11413, 14363, 14675, 17008, 17452, 25441]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_8/phy_MS4
# split_index is [0, 254398, 279875, 423640, 444851, 567005, 595336, 741732, 762040, 905043, 929251, 1475518]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_9/phy_AGR
# split_index is [0, 10112, 11810, 22308, 24255, 33340, 34891, 44392, 45482, 55229, 56255, 94996]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_10/phy_AGR
# split_index is [0, 6228, 6878, 13264, 13916, 20386, 20852, 27154, 27639, 34147, 34705, 64808]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 10582, 12519, 20861, 22641, 31885, 33449, 42733, 44229, 54691, 56121, 96604]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_12/phy_MS4
# split_index is [0, 219555, 243168, 377373, 401457, 538666, 566332, 690944, 715650, 876668, 905125, 1631157]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_13/phy_MS4
# split_index is [0, 184213, 201326, 278177, 295699, 372371, 393471, 478171, 495118, 617244, 644642, 1139139]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 1291, 1394, 2655, 2832, 5011, 5162, 8703, 9173, 12607, 12747, 121598]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_15/phy_AGR
# split_index is [0, 30779, 33735, 49313, 51846, 69631, 71985, 90781, 92562, 111419, 114328, 165472]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# trial name isPost_Trial4
# split_index is [0, 252520, 280840, 472393, 497695, 652580, 683787, 824876, 850846, 1024415, 1052489, 1658139]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_7/phy_AGR
# split_index is [0, 2751, 4096, 7253, 7909, 10889, 11413, 14363, 14675, 17008, 17452, 25441]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_8/phy_MS4
# split_index is [0, 254398, 279875, 423640, 444851, 567005, 595336, 741732, 762040, 905043, 929251, 1475518]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_9/phy_AGR
# split_index is [0, 10112, 11810, 22308, 24255, 33340, 34891, 44392, 45482, 55229, 56255, 94996]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_10/phy_AGR
# split_index is [0, 6228, 6878, 13264, 13916, 20386, 20852, 27154, 27639, 34147, 34705, 64808]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 10582, 12519, 20861, 22641, 31885, 33449, 42733, 44229, 54691, 56121, 96604]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_12/phy_MS4
# split_index is [0, 219555, 243168, 377373, 401457, 538666, 566332, 690944, 715650, 876668, 905125, 1631157]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_13/phy_MS4
# split_index is [0, 184213, 201326, 278177, 295699, 372371, 393471, 478171, 495118, 617244, 644642, 1139139]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 1291, 1394, 2655, 2832, 5011, 5162, 8703, 9173, 12607, 12747, 121598]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_15/phy_AGR
# split_index is [0, 30779, 33735, 49313, 51846, 69631, 71985, 90781, 92562, 111419, 114328, 165472]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# trial name isTrial5
# split_index is [0, 252520, 280840, 472393, 497695, 652580, 683787, 824876, 850846, 1024415, 1052489, 1658139]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_7/phy_AGR
# split_index is [0, 2751, 4096, 7253, 7909, 10889, 11413, 14363, 14675, 17008, 17452, 25441]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_8/phy_MS4
# split_index is [0, 254398, 279875, 423640, 444851, 567005, 595336, 741732, 762040, 905043, 929251, 1475518]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_9/phy_AGR
# split_index is [0, 10112, 11810, 22308, 24255, 33340, 34891, 44392, 45482, 55229, 56255, 94996]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_10/phy_AGR
# split_index is [0, 6228, 6878, 13264, 13916, 20386, 20852, 27154, 27639, 34147, 34705, 64808]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 10582, 12519, 20861, 22641, 31885, 33449, 42733, 44229, 54691, 56121, 96604]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_12/phy_MS4
# split_index is [0, 219555, 243168, 377373, 401457, 538666, 566332, 690944, 715650, 876668, 905125, 1631157]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_13/phy_MS4
# split_index is [0, 184213, 201326, 278177, 295699, 372371, 393471, 478171, 495118, 617244, 644642, 1139139]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 1291, 1394, 2655, 2832, 5011, 5162, 8703, 9173, 12607, 12747, 121598]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_15/phy_AGR
# split_index is [0, 30779, 33735, 49313, 51846, 69631, 71985, 90781, 92562, 111419, 114328, 165472]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# trial name isPost_Trial5
# split_index is [0, 252520, 280840, 472393, 497695, 652580, 683787, 824876, 850846, 1024415, 1052489, 1658139]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_7/phy_AGR
# split_index is [0, 2751, 4096, 7253, 7909, 10889, 11413, 14363, 14675, 17008, 17452, 25441]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_8/phy_MS4
# split_index is [0, 254398, 279875, 423640, 444851, 567005, 595336, 741732, 762040, 905043, 929251, 1475518]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_9/phy_AGR
# split_index is [0, 10112, 11810, 22308, 24255, 33340, 34891, 44392, 45482, 55229, 56255, 94996]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_10/phy_AGR
# split_index is [0, 6228, 6878, 13264, 13916, 20386, 20852, 27154, 27639, 34147, 34705, 64808]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_11/phy_AGR
# split_index is [0, 10582, 12519, 20861, 22641, 31885, 33449, 42733, 44229, 54691, 56121, 96604]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_12/phy_MS4
# split_index is [0, 219555, 243168, 377373, 401457, 538666, 566332, 690944, 715650, 876668, 905125, 1631157]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_13/phy_MS4
# split_index is [0, 184213, 201326, 278177, 295699, 372371, 393471, 478171, 495118, 617244, 644642, 1139139]
# row_index is 0
# row_index is 1
# row_index is 2
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_14/phy_AGR
# split_index is [0, 1291, 1394, 2655, 2832, 5011, 5162, 8703, 9173, 12607, 12747, 121598]
# row_index is 0
# /media/irene/GL13_RAT_BURSTY/Spike_sorting/Rat_OS_Ephys_RGS14_rat8_378133/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020/OS_Ephys_RGS14_Rat8_378133_SD6_OD_04-05_05_2020_merged/cortex/Tetrode_15/phy_AGR
# split_index is [0, 30779, 33735, 49313, 51846, 69631, 71985, 90781, 92562, 111419, 114328, 165472]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19

# %%
actmat_neuron_name = get_neuron_name(trial_info, absolute_path_list, trial_name_list[0], project_folder_name )
createFolder(path + '/' + date)
np.save("actmat_neuron_name", actmat_neuron_name)
# Out:
# split_index is [0, 252520, 280840, 472393, 497695, 652580, 683787, 824876, 850846, 1024415, 1052489, 1658139]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# split_index is [0, 2751, 4096, 7253, 7909, 10889, 11413, 14363, 14675, 17008, 17452, 25441]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# split_index is [0, 254398, 279875, 423640, 444851, 567005, 595336, 741732, 762040, 905043, 929251, 1475518]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# split_index is [0, 10112, 11810, 22308, 24255, 33340, 34891, 44392, 45482, 55229, 56255, 94996]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# split_index is [0, 6228, 6878, 13264, 13916, 20386, 20852, 27154, 27639, 34147, 34705, 64808]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19
# row_index is 20
# row_index is 21
# row_index is 22
# row_index is 23
# row_index is 24
# row_index is 25
# row_index is 26
# row_index is 27
# row_index is 28
# row_index is 29
# row_index is 30
# row_index is 31
# row_index is 32
# row_index is 33
# row_index is 34
# row_index is 35
# row_index is 36
# row_index is 37
# row_index is 38
# split_index is [0, 10582, 12519, 20861, 22641, 31885, 33449, 42733, 44229, 54691, 56121, 96604]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# split_index is [0, 219555, 243168, 377373, 401457, 538666, 566332, 690944, 715650, 876668, 905125, 1631157]
# row_index is 0
# row_index is 1
# row_index is 2
# split_index is [0, 184213, 201326, 278177, 295699, 372371, 393471, 478171, 495118, 617244, 644642, 1139139]
# row_index is 0
# row_index is 1
# row_index is 2
# split_index is [0, 1291, 1394, 2655, 2832, 5011, 5162, 8703, 9173, 12607, 12747, 121598]
# row_index is 0
# split_index is [0, 30779, 33735, 49313, 51846, 69631, 71985, 90781, 92562, 111419, 114328, 165472]
# row_index is 0
# row_index is 1
# row_index is 2
# row_index is 3
# row_index is 4
# row_index is 5
# row_index is 6
# row_index is 7
# row_index is 8
# row_index is 9
# row_index is 10
# row_index is 11
# row_index is 12
# row_index is 13
# row_index is 14
# row_index is 15
# row_index is 16
# row_index is 17
# row_index is 18
# row_index is 19

# %% [markdown]
# ### The code below is just for test purpose, do not run it

# %%
# spike_clusters = np.load("spike_clusters.npy")
# spike_times = np.load("spike_times.npy")
# set_neuron = set(spike_clusters)
# for neuron_x in set_neuron:
#     neuron_x_index =  [i for i,d in enumerate(spike_clusters) if d==neuron_x]
#     spike_times = spike_times.flatten()
#     neuron_x_map = (np.array([spike_times[index] for index in neuron_x_index])/750).astype(int)
#     neuron_x_map

# (np.array(spike_time_17)/750)[1]
